# %%
import requests

API_KEY = "76fc507d-66dd-44b8-b5eb-c350f65fa1c7"
url = "https://api.harvardartmuseums.org/classification"

params = {
    "apikey": API_KEY,
    "size": 100
}

response = requests.get(url, params)
response
# Out:
# <Response [200]>

# %%
# STEP 2: CLASSIFICATIONS WHERE OBJECT COUNT >= 2500

# convert response to JSON format
data = response.json()

# loop through each record and filter
print("Classifications with object count >= 2500:\n")

for record in data.get("records", []):
    if record.get("objectcount", 0) >= 2500:
        print(record.get("name"), "-", record.get("objectcount"))
# Out:
# Classifications with object count >= 2500:
#
# Accessories (non-art) - 2862
# Photographs - 85836
# Drawings - 33961
# Prints - 72253
# Paintings - 6863
# Sculpture - 6643
# Coins - 20270
# Vessels - 6223
# Textile Arts - 3446
# Archival Material - 15737
# Fragments - 5218
# Manuscripts - 5001
# Seals - 5899
# Straus Materials - 5128

# %%
# STEP 3: FETCH OBJECT RECORDS FOR A CHOSEN CLASSIFICATION

# choose a classification from the previous output 
classification = "Vessels"

# API endpoint for object data
url = "https://api.harvardartmuseums.org/object"

# page size and starting page
page = 1
page_size = 100

# empty list to store all records
all_records = []

# run until you collect about 2500 records (25 pages × 100)
while len(all_records) < 2500:
    params = {
        "apikey": API_KEY,
        "classification": classification,
        "size": page_size,
        "page": page
    }

    response = requests.get(url, params=params)
    if response.status_code != 200:
        print("Request failed at page", page)
        break

    data = response.json()
    records = data.get("records", [])

    # stop if no more data
    if not records:
        print("No more records found.")
        break

    # add new records to list
    all_records.extend(records)
    print(f"Fetched page {page} | Total records so far: {len(all_records)}")

    page += 1

# final record count
print("\nTotal records fetched:", len(all_records))
# Out:
# Fetched page 1 | Total records so far: 100
# Fetched page 2 | Total records so far: 200
# Fetched page 3 | Total records so far: 300
# Fetched page 4 | Total records so far: 400
# Fetched page 5 | Total records so far: 500
# Fetched page 6 | Total records so far: 600
# Fetched page 7 | Total records so far: 700
# Fetched page 8 | Total records so far: 800
# Fetched page 9 | Total records so far: 900
# Fetched page 10 | Total records so far: 1000
# Fetched page 11 | Total records so far: 1100
# Fetched page 12 | Total records so far: 1200
# Fetched page 13 | Total records so far: 1300
# Fetched page 14 | Total records so far: 1400
# Fetched page 15 | Total records so far: 1500
# Fetched page 16 | Total records so far: 1600
# Fetched page 17 | Total records so far: 1700
# Fetched page 18 | Total records so far: 1800
# Fetched page 19 | Total records so far: 1900
# Fetched page 20 | Total records so far: 2000
# Fetched page 21 | Total records so far: 2100
# Fetched page 22 | Total records so far: 2200
# Fetched page 23 | Total records so far: 2300
# Fetched page 24 | Total records so far: 2400
# Fetched page 25 | Total records so far: 2500
#
# Total records fetched: 2500

# %%
# STEP 4: SPLIT THE DATA INTO 3 PARTS — METADATA, MEDIA, COLORS

metadata = []
media = []
colors = []

for i in all_records:
    # METADATA section
    metadata.append(dict(
        id=i.get("id"),
        title=i.get("title"),
        culture=i.get("culture"),
        period=i.get("period"),
        century=i.get("century"),
        medium=i.get("medium"),
        dimensions=i.get("dimensions"),
        description=i.get("description"),
        department=i.get("department"),
        classification=i.get("classification"),
        accessionyear=i.get("accessionyear"),
        accessionmethod=i.get("accessionmethod")
    ))

    # MEDIA section
    media.append(dict(
        objectid=i.get("id"),
        imagecount=i.get("imagecount"),
        mediacount=i.get("mediacount"),
        colorcount=i.get("colorcount"),
        rank=i.get("rank"),
        datebegin=i.get("datebegin"),
        dateend=i.get("dateend")
    ))

    # COLORS section (list inside each record)
    if i.get("colors"):
        for j in i["colors"]:
            colors.append(dict(
                objectid=i.get("id"),
                color=j.get("color"),
                spectrum=j.get("spectrum"),
                hue=j.get("hue"),
                percent=j.get("percent"),
                css3=j.get("css3")
            ))

print("Metadata records collected:", len(metadata))
print("Media records collected:", len(media))
print("Color records collected:", len(colors))
# Out:
# Metadata records collected: 2500
# Media records collected: 2500
# Color records collected: 22051

# %%
# !python -m pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %%
import pymysql
my_db=pymysql.connect(
host ="localhost",
    user="root",
    password=""
    )
print("connection sucessfull.")

my_cursor = my_db.cursor()

# Database creation
my_cursor.execute("CREATE DATABASE IF NOT EXISTS harvard")

print(" Database 'harvard' created or already exists.")
# Out:
# connection sucessfull.
#  Database 'harvard' created or already exists.

# %%
my_db = pymysql.connect(
    host="localhost",
    user="root",
    password="",
    database="harvard"
)

my_cursor = my_db.cursor()
print("Connected to 'harvard' database.")
# Out:
# Connected to 'harvard' database.

# %% [markdown]
#  Create Table: artifact_metadata

# %%
my_cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_metadata (
    id INTEGER PRIMARY KEY,
    title TEXT,
    culture TEXT,
    period TEXT,
    century TEXT,
    medium TEXT,
    dimensions TEXT,
    description TEXT,
    department TEXT,
    classification TEXT,
    accessionyear INTEGER,
    accessionmethod TEXT
)
""")

print("Table 'artifact_metadata' created successfully.")
# Out:
# Table 'artifact_metadata' created successfully.

# %% [markdown]
#  Create Table: artifact_media :

# %%
my_cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_media (
    objectid INT PRIMARY KEY,
    imagecount INT,
    mediacount INT,
    colorcount INT,
    rank INT,
    datebegin INT,
    dateend INT,
    FOREIGN KEY (objectid) REFERENCES artifact_metadata(id)
)
""")

print(" Table 'artifact_media' created successfully.")
# Out:
#  Table 'artifact_media' created successfully.

# %% [markdown]
#  Create Table: artifact_colors

# %%
 

my_cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_colors (
    objectid INTEGER NOT NULL,
    color TEXT,
    spectrum TEXT,
    hue TEXT,
    percent REAL,
    css3 TEXT,
    FOREIGN KEY (objectid) REFERENCES artifact_metadata(id),
    PRIMARY KEY (objectid, color(50))
)
""")

print(" Table 'artifact_colors' created successfully.")
# Out:
#  Table 'artifact_colors' created successfully.

# %%
# fetched Api data:
import requests

API_KEY = "76fc507d-66dd-44b8-b5eb-c350f65fa1c7"
url = "https://api.harvardartmuseums.org/object"

metadata = []
media = []
colors = []

page = 1
while len(metadata) < 2500:
    params = {
        "apikey": API_KEY,
        "size": 100,
        "page": page
    }

    response = requests.get(url, params=params)
    data = response.json()

    for i in data['records']:
        metadata.append(dict(
            id=i.get('id'),
            title=i.get('title'),
            culture=i.get('culture'),
            period=i.get('period'),
            century=i.get('century'),
            medium=i.get('medium'),
            dimensions=i.get('dimensions'),
            description=i.get('description'),
            department=i.get('department'),
            classification=i.get('classification'),
            accessionyear=i.get('accessionyear'),
            accessionmethod=i.get('accessionmethod')
        ))

        media.append(dict(
            objectid=i.get('id'),
            imagecount=i.get('imagecount'),
            mediacount=i.get('mediacount'),
            colorcount=i.get('colorcount'),
            rank=i.get('rank'),
            datebegin=i.get('datebegin'),
            dateend=i.get('dateend')
        ))

        color_details = i.get('colors')
        if color_details:
            for j in color_details:
                colors.append(dict(
                    objectid=i.get('id'),
                    color=j.get('color'),
                    spectrum=j.get('spectrum'),
                    hue=j.get('hue'),
                    percent=j.get('percent'),
                    css3=j.get('css3')
                ))

        if len(metadata) >= 2500:
            break

    print("Fetched records:", len(metadata))
    page += 1

print("Total metadata records:", len(metadata))
print("Total media records:", len(media))
print("Total color records:", len(colors))
# Out:
# Fetched records: 100
# Fetched records: 200
# Fetched records: 300
# Fetched records: 400
# Fetched records: 500
# Fetched records: 600
# Fetched records: 700
# Fetched records: 800
# Fetched records: 900
# Fetched records: 1000
# Fetched records: 1100
# Fetched records: 1200
# Fetched records: 1300
# Fetched records: 1400
# Fetched records: 1500
# Fetched records: 1600
# Fetched records: 1700
# Fetched records: 1800
# Fetched records: 1900
# Fetched records: 2000
# Fetched records: 2100
# Fetched records: 2200
# Fetched records: 2300
# Fetched records: 2400
# Fetched records: 2500
# Total metadata records: 2500
# Total media records: 2500
# Total color records: 17010

# %%
inserted_count = 0

for record in metadata:
    insert_query = """
    INSERT IGNORE INTO artifact_metadata (
        id, title, culture, period, century, medium, dimensions,
        description, department, classification, accessionyear, accessionmethod
    ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    values = (
        record.get("id"), record.get("title"), record.get("culture"), record.get("period"),
        record.get("century"), record.get("medium"), record.get("dimensions"),
        record.get("description"), record.get("department"), record.get("classification"),
        record.get("accessionyear"), record.get("accessionmethod")
    )

    try:
        my_cursor.execute(insert_query, values)
        inserted_count += 1
    except Exception as e:
        print("Skipped:", e)

my_db.commit()
print("Inserted into artifact_metadata:", inserted_count)
# Out:
# Inserted into artifact_metadata: 2500

# %%
#Data Insert in Table 2: artifact_media
inserted_count = 0

for record in media:
    insert_query = """
    INSERT IGNORE INTO artifact_media (
        objectid, imagecount, mediacount, colorcount, rank, datebegin, dateend
    ) VALUES (%s, %s, %s, %s, %s, %s, %s)
    """
    values = (
        record.get("objectid"), record.get("imagecount", 0), record.get("mediacount", 0),
        record.get("colorcount", 0), record.get("rank", 0),
        record.get("datebegin", 0), record.get("dateend", 0)
    )

    try:
        my_cursor.execute(insert_query, values)
        inserted_count += 1
    except Exception as e:
        print("Skipped:", e)

my_db.commit()
print("Inserted into artifact_media:", inserted_count)
# Out:
# Inserted into artifact_media: 2500

# %%
#Data Insert in Table 3: artifact_colors
inserted_count = 0

for record in colors:
    insert_query = """
    INSERT IGNORE INTO artifact_colors (
        objectid, color, spectrum, hue, percent, css3
    ) VALUES (%s, %s, %s, %s, %s, %s)
    """
    values = (
        record.get("objectid"), record.get("color"), record.get("spectrum"),
        record.get("hue"), record.get("percent"), record.get("css3")
    )

    try:
        my_cursor.execute(insert_query, values)
        inserted_count += 1
    except Exception as e:
        print("Skipped:", e)

my_db.commit()
print("Inserted into artifact_colors:", inserted_count)
# Out:
# Inserted into artifact_colors: 17010

# %% [markdown]
#  SQL Queries

# %%
query = """
SELECT title
FROM artifact_metadata
WHERE century = '11th century'
  AND culture = 'Byzantine';
"""
my_cursor.execute(query)
results = my_cursor.fetchall()
for row in results:
    print(row[0])
# Out:
# Seal of Kosmas, Bishop of Proussa
# Seal of Sergios chartoularios and kommerkiarios of Presthlavitza (XI c.)
# Seal of (John) protoproedros (of the protosynkelloi and metropolitan) of Side (XI c.)
# Seal of Nikephoros patrikios and strategos of the Kibyrraiotai (XIth c.)

# %%
#2. What are the unique cultures represented in the artifacts?
query = """
SELECT DISTINCT culture
FROM artifact_metadata
WHERE culture IS NOT NULL
ORDER BY culture;
"""

my_cursor.execute(query)
cultures = [row[0] for row in my_cursor.fetchall()]
print(cultures)
# Out:
# ['American', 'American?', 'Anatolian', 'Arab', 'Austrian', 'Belgian', 'Brazilian', 'British', 'British, English', 'British, Scottish', 'British?', 'Byzantine', 'Canadian', 'Central Asian?', 'Chinese', 'Chinese?', 'Coptic', 'Cycladic', 'Danish', 'Dutch', 'Dutch?', 'East Asian', 'Egyptian', 'Etruscan', 'European', 'European?', 'Flemish', 'French', 'French?', 'German', 'German?', 'Graeco-Roman', 'Greek', 'Hellenistic', 'Indian', 'Islamic', 'Italian', 'Italian?', 'Japanese', 'Korean', 'Mexican', 'Minoan', 'Moroccan', 'Mughal', 'Mycenaean', 'Near Eastern', 'Netherlandish', 'Parthian', 'Persian', 'Roman', 'Roman Imperial', 'Roman Provincial', 'Roman Republican', 'Russian', 'Siculo-Punic', 'Spanish', 'Sumerian', 'Swedish', 'Swiss', 'Syrian', 'Turkish', 'Unidentified culture', 'Uzbek']

# %%
#3. List all artifacts from the Archaic Period.

query = """
SELECT id, title, culture, century, medium, classification
FROM artifact_metadata
WHERE period LIKE '%Archaic%';
"""
my_cursor.execute(query)
results = my_cursor.fetchall()

if results:
    for row in results:
        print(row)
else:
    print("No artifacts found for Archaic Period")
# Out:
# (4618, 'Obol of Himera, Sicily', 'Greek', '5th century BCE', 'Silver', 'Coins')
# (4867, 'Basin Handle with Lion and Snake Heads', 'Greek', '6th century BCE', 'Bronze', 'Vessels')
# (71082, 'Didrachm of Selinous (Sicily)', 'Greek', '6th century BCE', 'Silver', 'Coins')
# (71145, 'Didrachm of Selinous (Sicily)', 'Greek', '6th century BCE', 'Silver', 'Coins')
# (71147, 'Didrachm of Selinous (Sicily)', 'Greek', '6th century BCE', 'Silver', 'Coins')

# %%
#4. List artifact titles ordered by accession year in descending order
query = """
SELECT title, accessionyear
FROM artifact_metadata
WHERE accessionyear IS NOT NULL
ORDER BY accessionyear DESC;
"""

my_cursor.execute(query)
results = my_cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Standing Draped Man Carrying a Large Bundle on His Shoulder', 2024)
# ('Allegory of the Triumph of the Netherlands over Spain', 2021)
# ('Bust-length Portrait of a Young Woman, Facing Left', 2018)
# ('Saints Prosdocimus, Justina, Daniel, and Anthony of Padua in Glory with a View of the Prato della Valle, Padua', 2018)
# ('Globular, Wide-Mouthed Jar with Two Loop Handles and Pale Lavender Splash', 2016)
# ('Large Circular Bowl with Five Large Russet Splashes against a Ground of Russet Flecks', 2016)
# ('Broad-Shouldered, "Hanging Jar" with Vertical Lip, Wide Mouth, and Landscape Décor', 2016)
# ('Globular Jar with Rounded Bottom and Flaring Lip', 2016)
# ('Small Jade Sculpture in the Form of a Recumbent Ram', 2016)
# ('Small Water Coupe in the Form of a Spotted Frog', 2016)
# ('"Eye" Bead with Aqua and White Swirls', 2016)
# ('Small Tea Bowl with Decoration of Moon, Clouds, and Blossoming Plum', 2016)
# ('Medicine Buddha (Chinese, Yaoshi Rulai) Seated on a Lotus Pedestal and Holding a Small Medicine Jar in His Left Hand', 2016)
# ('Standing Lokapala Guardian Figure with Proper Right Arm Raised', 2016)
# ('Plaque: Wild Goat and Deer', 2016)
# ('Circular Covered Box with Peony Décor', 2015)
# ('Large Circular Bowl', 2015)
# ('Five-Prong Vajra (Gokosho), or Buddhist Thunderbolt', 2014)
# ('Nyoirin Kannon above a Landscape', 2014)
# ('Buddha at Birth (Tanjō Butsu)', 2014)
# ('Chakra (Rimpō), or Wheel of the Buddhist Law', 2014)
# ('Frog-Shaped Water Dropper', 2014)
# ('Sanskrit Diamond World Mandala (Shuji Kongokai mandara)', 2014)
# ('Circular Eaves-End Rooftile with Design of Sanskrit Syllable for Buddha Amitabha (Amida)', 2014)
# ('Godai Myōō with Nyōirin Kannon and Aizen Myōō', 2014)
# ("Finial for a Buddhist Monk's Staff (Shakujō) with Pagodas, Vases, and Sun & Moon", 2014)
# ('Invocation Sheet (Nembutsu)', 2014)
# ('Seated Bodhisattva of Wisdom with Five Tufts of Hair (Gokei Monju)', 2014)
# ('Circular Eaves-End Rooftile with Design of Pagoda (Gorinto) and Sanskrit Syllable for Buddha Vairochana (Dainichi), from Shōtō-ji (subtemple of Hōshō-ji), Kyoto', 2014)
# ('Archiform Pendent Eaves-End Rooftile with Three-Prong Vajra (Sankosho) Design, from Rokuharamitsu-ji\r\n', 2014)
# ('Circular Eaves-End Rooftile with Lotus Design, from Minamishaga Hai-ji', 2014)
# ('Printed Images (inbutsu) of Buddha Amitabha (Amida), from Jōruri-ji, Kyoto', 2014)
# ('Printed Images (Imbutsu) of Acalanâtha (Fudō Myōō), from Kyōōgokoku-ji (Tō-ji), Kyoto', 2014)
# ('Rice-Grain Pagoda with Sanskrit character for "Dainichi" written on one side, from Murō-ji', 2014)
# ('Five-Part Pagoda, from Rokuharamitsu-ji', 2014)
# ('Pagoda', 2014)
# ('Temple Rooftile with Pagoda Design, from Hōshō-ji', 2014)
# ("Finial for a Buddhist Monk's Staff (Shakujo) with Six Pagodas", 2014)
# ('Circular Impressed Disk', 2012)
# ('Intaglio: Maritime Scene', 2012)
# ('Intaglio: Harpocrates on a Boat Surrounded by Animals', 2012)
# ('Intaglio: Eagle Holding a Wreath and Perched on a Mountain', 2012)
# ('Intaglio: Hanging Figure Attacked by a Lion and Eagle, with Eros', 2012)
# ('Intaglio: Lion', 2012)
# ('Intaglio: Crescent and Five Stars', 2012)
# ('Intaglio: Uterine Symbol with Egyptian Deities', 2012)
# ('Intaglio: Rooster-Headed Anguipede', 2012)
# ('Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: Frank Blanchette. Jan. 28, 1904. Arithmetic.', 2011)
# ('Crime, Prisons: United States. Massachusetts. Charlestown. State Prison: The Mentor.: Produced by the Mimeograph-process, each character being made and printed by hand', 2011)
# ('Charity, Hospitals: United States. Massachusetts. Tewksbury. State Hospital: State Hospital Tewksbury: Infectious Ward', 2011)
# ("Recreation, Parks and Playgrounds: Holland. Amsterdam. Playgrounds: Social Conditions in Amsterdam, Holland, 1903: Childrens' playground.", 2011)
# ('Education, General: United States. Rhode Island. Providence. School Gardens: School Gardens, Rhode Island. Providence, R.I. "Portuguese Mission Garden", Gano St. In 1910 at time of planting and 6 weeks after planting.', 2011)
# ("Housing, Improved: Great Britain, Ireland. Belfast. Proposed Improvements: Improved Workmen's Housing, Ireland: Congested Districts Board for Ireland. Estates Department Plan No. 6.: Four-Room Dwelling House 1914", 2011)
# ("Charity, Hospitals: United States. Massachusetts. Tewksbury. State Hospital: State Hospital, Tewksbury: Boy's Ward", 2011)
# ('Recreation, Parks and Playgrounds: Italy. Milan. Public Park: Social Conditions in Milan, Italy, 1903: Public park.', 2011)
# ('Education, General: United States. Rhode Island. Providence. School Gardens: School Gardens, Rhode Island. Providence, R.I. "Portuguese Mission Garden", Gano St. In 1910 at time of planting and 6 weeks after planting.', 2011)
# ("Housing, Improved: Great Britain, Ireland. Belfast. Proposed Improvements: Improved Workmen's Housing, Ireland: Congested Districts Board, Plan No. 6.: Schedule of Quantities.", 2011)
# ('Charity, Hospitals: United States. Massachusetts. Tewksbury. State Hospital: State Hospital, Tewksbury: Womens Insane Wards #3, #1, #8 + #6', 2011)
# ("Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. (1) Letter Heads. (2) Inserts. (3) Subscription blanks: Fall and Winter Membership Activities 1929-1930: Boston Young Men's Christian Association", 2011)
# ('Social Settlements: United States. New York. New York City. "Christodora House": Christodora House, New York City.: City Playground In front of the settlement.', 2011)
# ("Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: Joseph McCarthy. Jan. 27, 1904. Grandma's Story.", 2011)
# ('Courtesans of the Matsubarō: Nakagawa, Utagawa, Matsukaze', 1916)
# ('Brocaded Fragment with Narrative Motifs', 1916)
# ('Reproduction of a Gold Mycenaean Bead', 1910)
# ('Reproduction of a Gold Mycenaean Bead', 1910)
# ('Reproduction of a Gold Mycenaean Bead', 1910)
# ('Reproduction of a Gold Mycenaean Ring', 1910)
# ('Reproduction of a Gold Vapheio Cup', 1901)
# ('Reproduction of a Gold Mycenaean Ornament', 1901)
# ('Reproduction of a Gold Mycenaean Pin Head', 1901)
# ('Reproduction of a Gold Mycenaean Ornament', 1901)
# ('Reproduction of a Gold Mycenaean Disc', 1901)
# ('Reproduction of a Gold Mycenaean Disc', 1901)
# ('Portrait:  Jacopo Bassano', 1892)

# %%
#5. How many artifacts are there per department?
query = """
SELECT department, COUNT(*) AS artifact_count
FROM artifact_metadata
WHERE department IS NOT NULL
GROUP BY department
ORDER BY artifact_count DESC;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# ('Department of Photographs', 1355)
# ('Department of Drawings', 1227)
# ('Department of Prints', 817)
# ('Department of Ancient and Byzantine Art & Numismatics', 562)
# ('Straus Center for Conservation and Technical Studies', 526)
# ('Busch-Reisinger Museum', 224)
# ('Department of Asian Art', 143)
# ('Department of Islamic & Later Indian Art', 72)
# ('Department of Modern & Contemporary Art', 40)
# ('Department of Paintings, Sculpture & Decorative Arts', 26)
# ('Harvard University Portrait Collection', 3)
# ('Department of American Paintings, Sculpture & Decorative Arts', 3)
# ('Archives', 2)

# %% [markdown]
# SQL OURIES FOR artifact_media

# %%
#6. Which artifacts have more than 1 image?
query = """
SELECT m.objectid, d.title, m.imagecount
FROM artifact_media AS m
JOIN artifact_metadata AS d ON m.objectid = d.id
WHERE m.imagecount > 1
ORDER BY m.imagecount DESC;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# (69421, 'Volume 4: The Antiquities of Rome, IV', 66)
# (59857, 'Volume 6: Collections of Prints', 60)
# (6262, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. Annual Reports: A Sound Investment: A Statement. 1924: North Bennet St. Industrial School', 52)
# (6875, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. Annual Reports: Only Yesterday I was a Boy', 51)
# (59886, 'Volume 5: Various Prints', 39)
# (4968, "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Winter and Spring: General Education Department Young Women's Christian Association Boston, Massachusetts", 36)
# (6176, "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. Annual Reports: Full Measure: The Greater Service of Boston's Y.W.C.A.", 36)
# (5017, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Our Citizens: North Bennet Street Industrial School', 30)
# (6218, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. Annual Reports: The Open Door: The Boys Club of Boston, Inc.', 29)
# (6261, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. Annual Reports: The New in the Old: The Work of North Bennet Street Industrial School in the North End of Boston', 29)
# (5928, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. Leaflets & Folders: What Price Silence?: The Massachusetts Society for Social Hygiene', 4)
# (6013, "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. Leaflets & Folders: Hattie B. Cooper Community Centre (Under the charge of the Woman's Home Missionary Society of the Methodist Episcopal Church)", 4)
# (6014, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. Leaflets & Folders: New England Home for Little Wanderers', 4)
# (6107, 'The Bath', 4)
# (6289, 'Sketch of a Landscape; verso: blank page', 4)
# (6738, 'Notes of Expenses and Addresses; verso: Notes on Works of Art', 4)
# (6748, 'Blank page; verso: Sketch of a Harbor', 4)
# (6749, 'Blank page; verso: Sketch of a Bay with Rocks and Sailing Boats', 4)
# (6762, 'Small Jade Sculpture in the Form of a Recumbent Ram', 4)
# (6811, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. (1) Posters and Flyers. (2) Programs with Advertisements. (3) Formal Invitations.: Justice: Published at regular intervals by the Boston Legal Aid Society', 4)
# (6839, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. (1) House Papers. (2) Newspaper Editorials. (3) Novelties, Blotters, Bookmarks, Calendars, etc.: North Bennet Street Industrial School. News Bulletin', 4)
# (6840, "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. (1) House Papers. (2) Newspaper Editorials. (3) Novelties, Blotters, Bookmarks, Calendars, etc.: Pioneer News. Boston Young Women's Christian Association", 4)
# (6850, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. (1) House Papers. (2) Newspaper Editorials. (3) Novelties, Blotters, Bookmarks, Calendars, etc.: Dates to Remember - This Month of December. Y.W.C.A.', 4)
# (6851, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work. (1) House Papers. (2) Newspaper Editorials. (3) Novelties, Blotters, Bookmarks, Calendars, etc.: The Vagabond Club 1929-1930', 4)
# (70028, 'Rolled, Encased & Sawed', 4)
# (70470, 'Roses and Wisteria by a Garden Rock', 4)
# (70508, 'Small Bowl with Flaring Lip and Partridge-Feather Mottles', 4)
# (70736, 'Aftercast of a Sestertius of Vespasian with the Colosseum by Cavino', 4)
# (70759, 'Archaic Images', 4)
# (71191, 'Streets and Canals in Venice [Calli E Canali in Venezia]', 4)
# (71266, 'Ruins of Pompeii', 4)
# (72421, 'White Envelope with Blue Ballpoint Pen Text, with Contents', 4)
# (72428, 'Intaglio: Uterine Symbol with Egyptian Deities', 4)
# (73285, 'Seal of Philotheos, monk, synkellos and higoumenos of the monastery of Nossiai (XI c.)', 4)
# (73315, 'Seal of John monk, archbishop of all Bulgaria (XI c.)', 4)
# (352844, 'Motionpicture film projector', 4)
# (352866, 'Metal box of slides', 4)
# (352870, 'Bounce flash gun', 4)
# (353007, 'Slide viewer', 4)
# (353880, 'Color movie film', 4)
# (73197, 'Seal of Niketas protospatharios and judge of the Thrakesioi (XI c.)', 3)
# (73225, 'Seal of Manuel proedros and praitor of the Armeniakoi (XI c.)', 3)
# (73266, 'Seal of Gregory (bishop) of Anaia (VII/VIII c.)', 3)
# (73278, 'Seal of John (metropolitan) of Amaseia (XI c.)', 3)
# (73296, 'Seal of Theodore imperial protospatharios, grand chartoularios of the genikon and anagrapheus of the Armenian themes (X/XI c.)', 3)
# (352837, 'Photo Lamp', 3)
# (352840, 'Cover for Reel-to-reel Tape Recorder', 3)
# (352864, 'Illuminated Slide Sorter', 3)
# (352878, 'Roll film magazine', 3)
# (352880, 'Cut film adapter', 3)
# (353008, 'Slide viewer', 3)
# (353341, 'Miter box', 3)
# (353879, 'Flashbulb', 3)
# (353882, 'Lens Paper', 3)
# (1431, 'Statement on the other side of this card', 2)
# (1434, 'San Arcangelo', 2)
# (4586, 'Streams and Mountains, from the series "Sacrifice"', 2)
# (4591, 'Games & Puzzles', 2)
# (4630, 'Portrait of a Soldier', 2)
# (4644, 'Two Standing, Bearded, Foreign Male Figures, Each Wearing a Tall Hat with Protective Neck and Ear Flaps, a Shoulder Scarf, Heavy Boots, and Spotted, Leopard-Skin Trousers, and Each with His Hands Clasped at His Chest', 2)
# (4646, 'Pair of Standing, Helmeted, Armor-Clad Guardian Warriors, Each with One Arm Raised and One at the Side, and Both Hands Clenched as if Holding Weapons, One Figure with Mouth Closed and Wearing Straw Shoes, One with Mouth Open and Wearing Pointed Boots', 2)
# (4648, 'Mystical Journey', 2)
# (4654, "Butterfly for a Valance at Dowdeswell's Gallery", 2)
# (4679, 'Poem 70-26', 2)
# (4680, 'Poem 69-8', 2)
# (4852, '“Putka”, folio from the album Fishes of India', 2)
# (4855, '“Pan”, folio from the album Fishes of India', 2)
# (4865, 'Warrior', 2)
# (4869, 'Study for "Box Smashed Flat (Vicksburg)"', 2)
# (4873, 'Mysteries', 2)
# (4901, 'Ex Libris Hildegard Heyne', 2)
# (4927, 'Landscape with Full Moon', 2)
# (4928, 'Night, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4929, 'Farmer, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4930, 'Herod, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4950, 'Death as Savior, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4951, 'Poor Family, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4952, 'On the Tracks, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4953, 'Child, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4954, 'Road, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4955, 'Sea, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4956, 'Sailors, from the portfolio "On Death, Part One, Opus XI"', 2)
# (4996, 'Title page from the portfolio "On Death, Part One, Opus XI"', 2)
# (5013, 'Circular Impressed Disk', 2)
# (5053, 'Portfolio cover from the portfolio "On Death, Part One, Opus XI"', 2)
# (5075, 'Poem 68-55', 2)
# (5076, 'Cell-A', 2)
# (5078, 'Untitled (Susanna Shahn and friend, Jersey Homesteads, New Jersey)', 2)
# (5079, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5080, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5081, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5082, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5083, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5084, 'An Ajaccio Fisherman', 2)
# (5109, 'Landscape', 2)
# (5139, 'Figure Studies (recto and verso)', 2)
# (5145, 'A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 2)
# (5203, 'Lithographs Based on Geologic Maps of Lunar Orbiter and Apollo Landing Sites', 2)
# (5222, 'Mountain Bluff, Cascading Waterfall, from the series "Sacrifice"', 2)
# (5243, 'The Natural Bridge, Virginia', 2)
# (5245, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5246, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5247, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5248, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5249, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5250, 'Untitled (children, Jersey Homesteads, New Jersey)', 2)
# (5251, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5252, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 2)
# (5277, '"Eye" Bead with Aqua and White Swirls', 2)
# (5294, '“Manua”, folio from the album Fishes of India', 2)
# (5300, 'Coin of Corinth under Claudius', 2)
# (5358, 'Christ at the Column', 2)
# (5360, 'Putto', 2)
# (5363, 'Ruin of an Aqueduct on the Road to Cori, Italy', 2)
# (5368, 'Viewing the Falls from a Mountain Pavilion, from the series "Sacrifice"', 2)
# (5495, 'Hercules with the Lion Skin', 2)
# (5496, 'Bathing Venus', 2)
# (5497, 'Hercules and the Nemean Lion', 2)
# (5546, 'Galeriae Farnesianae', 2)
# (5565, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro. Training for Commercial and Industrial Employment. Hampton Normal and Agricultural Institute, Hampton, Va.', 2)
# (5644, 'Mass. Av. S. of Harvard Sq.', 2)
# (5645, 'Main St. Progress view', 2)
# (5646, 'Main St. Pump well near Kendall Sq.', 2)
# (5647, 'Main St. Progress view', 2)
# (5649, 'Orchids and Rocks', 2)
# (5667, 'Progress tearing down buildings cor. Bay St. and Mass Av.', 2)
# (5668, 'Harvard Sq. opening in College Fence', 2)
# (5682, "Religious Agencies, Salvation Army: France, Paris. Men's Lodging House: The Salvation Army Paris, France: Cheap lodging House for men, Paris: Common Wash-Room.", 2)
# (6717, "Religious Agencies, Salvation Army: United States. Maine. Portland. Workingmen's Hotels: The Salvation Army: Workingmens' Hotel... Portland, Maine.", 2)
# (6758, 'Globular, Wide-Mouthed Jar with Two Loop Handles and Pale Lavender Splash', 2)
# (6772, 'Untitled [with Anna May Wong]', 2)
# (6791, 'Pillow in the Form of Recumbent, Addorsed Lions Supporting a Headrest with Bird-and-Flower Décor', 2)
# (6802, 'Vineyard with a View of a Bay; verso: blank page', 2)
# ...
# (59626, 'Charity, Children: United States. New York. Ogdensburg. Orphan Asylum: City Hospital and Orphanage, Ogdensburg, N.Y. (Under the direction of the Grey Nuns of the Cross): The Helen Hall Ward for Sick Women.', 2)
# (59640, "Charity, Hospitals: United States. New York. New York City. Metropolitan Hospital, Blackwell's Island: Metropolitan Hospital, New York City: Tuberculosis Infirmary.: Ward, Female.", 2)
# (59862, 'Studies of Etruscan Friezes at Chiusi', 2)
# (59885, 'Circular Eaves-End Rooftile with Lotus Design, from Minamishaga Hai-ji', 2)
# (59897, 'Pagoda', 2)
# (59902, 'Temple Rooftile with Pagoda Design, from Hōshō-ji', 2)
# (59904, 'Five-Prong Vajra (Gokosho), or Buddhist Thunderbolt', 2)
# (59905, 'Nyoirin Kannon above a Landscape', 2)
# (64557, 'Square Water Dropper with Landscape Décor', 2)
# (64604, 'Landscape', 2)
# (69677, 'Circular Eaves-End Rooftile with Design of Sanskrit Syllable for Buddha Amitabha (Amida)', 2)
# (69707, 'Seated Bodhisattva of Wisdom with Five Tufts of Hair (Gokei Monju)', 2)
# (69825, 'Fire', 2)
# (69965, 'The Walls of Babylon', 2)
# (70018, 'View of a tomb on the ancient Via Cassia', 2)
# (70022, '7 Objects/69', 2)
# (70066, 'The Mouth (outlet) of the Cloaca Maxima into the Tiber', 2)
# (70118, 'Ocean Surface', 2)
# (70150, 'Buddha at Birth (Tanjō Butsu)', 2)
# (70151, 'Chakra (Rimpō), or Wheel of the Buddhist Law', 2)
# (70240, 'Fresh', 2)
# (70471, "'Meiping' Bottle with Stylized Lotus Decor", 2)
# (70472, 'Tea Bowl with Patterned Tortoiseshell Mottles', 2)
# (70506, 'Former Prime Minister Zhang Liang (d. 189 BC) Presenting the Straw Sandal to the Sage at Yi Bridge', 2)
# (70623, 'Untitled (Cornered Construction) 3/9', 2)
# (70637, "Woman's Robe with Butterfly-Medallion Decor", 2)
# (70691, 'coin of Zeugma under Philip II', 2)
# (70724, 'Small Tripod Bowl (or Cup) with Tab Handle', 2)
# (70760, 'Landscape No. 404', 2)
# (70784, 'Landscape', 2)
# (70785, 'Globular Bottle with Squared Shoulders and Dished Mouth', 2)
# (70806, 'Two Sheets of Red-Painted Paper with Gold Text, Each Fold Once at a Third Mark of the Whole', 2)
# (71126, 'Negro Church, South Carolina', 2)
# (71176, 'Then and Now Views of Quincy Street', 2)
# (71466, "Untitled (washroom and dining area of Floyd Burroughs' Home, Hale County, Alabama)", 2)
# (71728, 'Frontispiece', 2)
# (71744, 'Triptych: Musashi no Kuni: Chōfu no Tamagawa', 2)
# (71777, 'Death as a Drummer with a Banner of Vanities, and an Owl', 2)
# (71779, 'Titlepage:Two Eagles Defying Two Lion Heads', 2)
# (71806, 'Boar and Stag Heads, a Bow, Arrows, and a Quiver', 2)
# (71820, 'Camels and Fruit Garlands', 2)
# (71863, 'Album of Views after Johann Wilhelm Baur and other artists', 2)
# (71882, 'Los Francisco San Angeles', 2)
# (71894, 'Boaters Watching a Fight', 2)
# (72026, 'The Turbaned Soldier on Horseback', 2)
# (72068, 'Decayed Corpses Ravaged by Time', 2)
# (72142, 'Boar and Stag Heads, a Club, and a Hunting Horn', 2)
# (72209, 'Seal of Leo spatharokandidatos epi ton oikeiakon, judge of the Hippodrom and of Mesopotamia (X/XI c.)', 2)
# (72251, 'Seal of N. Abalentes (?), protospatharios, exaktor, judge of the Hippodrome and of the Opsikion guarded by God (XI c.)', 2)
# (72288, 'Seal of N. protospatharios, moderator, judge of the Velum and ofthe Anatolikoi (XI c.)', 2)
# (72297, 'Seal of Constantine protospatharios and chartoularios of the genikon of the archives of the West (XI c.)', 2)
# (72299, 'Seal of N., dioiketes of Cephalonia (?) (IX c.)', 2)
# (72422, 'Intaglio: Maritime Scene', 2)
# (72424, 'Intaglio: Eagle Holding a Wreath and Perched on a Mountain', 2)
# (72427, 'Intaglio: Crescent and Five Stars', 2)
# (72429, 'Intaglio: Rooster-Headed Anguipede', 2)
# (72498, 'Seal of Sergios imperial spatharokandidatos and kommerkiarios of Cherson (X c.)', 2)
# (72499, 'Seal of Niketas imperial paraphylax of Abydos and kommerkiarios (IX c.)', 2)
# (72504, 'Seal of the imperial kommerkia of Bithynia (Phrygia), Salutaria (PHrygia), Pakatianae and Lydia (733/734)', 2)
# (72505, 'Seal of the imperial kommerkia of Mesembria (731/2)', 2)
# (72506, 'Seal of the imperial kommerkia of Thrace (747/8?)', 2)
# (72508, 'Seal of Pardos hypatos and kommerkiaros of Thessalonica (IX/X c.)', 2)
# (72509, 'Seal of Euprepios spatharokandidatos and grand kommerkiarios of the West (X/XI c.)', 2)
# (72515, 'Seal of Nikephoros proedros and praitor of the Anatolikoi (XI c.)', 2)
# (72528, 'Seal of Kosmas stratelates and general kommerkiarios of the apotheke of the Cycladic Islands (?) (687-689)', 2)
# (72551, 'Seal of George apo hypaton and general kommerkiarios of the apotheke of Karia and Lykia (an unspecified year between 691/92 and 695/96)', 2)
# (72552, 'Seal of Demetrios hypatos, imperial kommerkiarios of the abydos of Thessalonica (IX c.)', 2)
# (72556, 'Seal of Constantine bishop of Bela (X c.)', 2)
# (72583, 'Seal of Michael Judge of the Thrakesioi (XI c.)', 2)
# (72596, 'Seal of Agallianos kommerkiarios of Abydos (XI c.)', 2)
# (72599, 'Seal of Leo imperial spatharios and protonotarios of Thessalonica (X c.)', 2)
# (72602, 'Seal of John (bishop) of Raidestos (XII/XIII c.)', 2)
# (72615, 'Seal of Theodosios bishop of Athens (VII/VIII c.)', 2)
# (72633, 'Seal of N., strategos of Macedonia (VIII/IX c.)', 2)
# (72659, 'Seal of Theodore episkeptites(?) of Kastoria (XI c.)', 2)
# (72665, 'Seal of Akindynos bishop of Panidos (IX/X c.)', 2)
# (72670, 'Seal of Demetrios metropolitan of Kyzikos (X c.)', 2)
# (72685, 'Seal of Niketas archon of Skyros (IX/X c.)', 2)
# (72691, 'Seal of Nikephoros Botaneiates, kouropalates and doux of the Anatolikoi (XI c.)', 2)
# (72727, 'Seal of Theodore Proteuon, protospatharios and judge of the Kibyrraiotai (XI c.)', 2)
# (72741, 'Seal of Nikephoros Ouranos, magistros and "master" of the Orient (X/XI c.)', 2)
# (72760, 'Seal of Paul chartoularios and horreiarios of Amisus (X/XI c.)', 2)
# (72764, 'Seal of Theodore bishop of Methone (X/XI c.)', 2)
# (72779, 'Seal of Theod(....?) bishop(?) of Raidestos (X/XI c.)', 2)
# (72785, 'Seal of Eustratios bishop of Ikaria (XI c.)', 2)
# (72829, 'Seal of Nicholas Areobindenos, spatharokandidatos and protonotarios of Chaldia (X/XI c.)', 2)
# (72835, 'Seal of the monastery of Kokkinobaphos (XI/XII c.)', 2)
# (72839, 'Seal of Symbatikis imperial protospatharios and strategos of Thrace (X c.)', 2)
# (72842, 'Seal of Niketas patrikios and strategos of the Peloponnesus (XI c.)', 2)
# (72845, 'Seal of Michael (imperial) protospatharios and katepano of Pephlagonia (X c.)', 2)
# (72847, 'Seal of Stephanos archbishop of Katepano of Vaasprakania (XI c.)', 2)
# (72858, 'Seal of Euthynmios bishop of Sagalassos (X c.)', 2)
# (72869, 'Seal of George imperial spatharokandidatos and strategos of the Peloponnesos (IX c.)', 2)
# (72887, 'Seal of John Thylakes, patrikios, anthypatos, vestes, hypatos and judge of the Opsikion (XI c.)', 2)
# (72894, 'Seal of Leo imperial spatharios and protonotarios of Thessalonica (X c.)', 2)
# (72896, 'Seal of Michael imperial vestitor and protonotarios of Paphlagonia (IX c.)', 2)
# (72902, 'Seal of Joseph vestitor, epoptes of Nikopolis and epi (?) Peloponnesou (X c.)', 2)
# (72908, 'Seal of Basil (?) Bleymmydes (?), imp. protospatharios and anagrapheus of the Armeniakoi (X c.)', 2)
# (72909, 'Seal of Michael metropolitan of Karia (X c.)', 2)
# (72911, 'Seal of John Kommenos, doux of Dyrrachion, son of the Sebastokrator (XI/XII c.; shortly after 1091/2)', 2)
# (72916, 'Seal of Romanos imperial protospatharios and strategos of Mesopotamia (X/XI c.)', 2)
# (72917, 'Seal of Leo imperial protospatharios and strategos of Thrace (X c.)', 2)
# (72919, 'Seal of N. Blax, protospatharios and judge of Mesopotamia (XI c.)', 2)
# (72922, 'Seal of George imperial spatharios and tourmarches of the Boukellarioi (IX c.)', 2)
# (72925, 'Seal of Theodore archbishiop of Ephesos (VII/VIII c.)', 2)
# (72962, 'Seal of Dionysios monk and bishop of Stratonikeia (X/XI c.)', 2)
# (72994, 'Seal of Tarasios hypatos and archon of the Kyberiotai (VIII c.)', 2)
# (73023, 'Seal of Leo patrikios, imperial protospatharios and strategos of the Anatolikoi (IX c.)', 2)
# (73031, 'Seal of Sergios chartoularios and kommerkiarios of Presthlavitza (XI c.)', 2)
# (73032, 'Seal of Constantine archbishop (=metropolitan) of Herakleia (VIII/IX c.)', 2)
# (73033, 'Seal of Eustratios (Romaios?) spatharokandidatos and kommerkiarios of Persthlavitza (XI c.)', 2)
# (73034, 'Seal of Euprepios spatharokandidatos and grand kommerkiarios of the West (X/XI c.)', 2)
# (73035, 'Seal of Peter apoy hypaton and general kommerkiarios of the apotheke of [First or Fourth] Armen[ia] and.... (674-681)', 2)
# (73038, 'Seal of Ge[orge apo hyp]a[ton] and general kommerkiaros of the apotheke of Nicaea (695-697)', 2)
# (73041, 'Seal of Niketas notarios and abydikos of Thessalonica (VIII c.)', 2)
# (73042, 'Seal of Andrew imperial kommerkiarios of Thessalonica (VIII - IX c., perhaps 795/6, 810/1, 825/6)', 2)
# (73043, 'Seal of N., (proto?)spatharios and kommerkiarios of Thessalonica (X c.)', 2)
# (73044, 'Seal of Philip (or Philetos) and Niketas kommerkiarios of Abydos (XI c.)', 2)
# (73061, 'Seal of Stephanos kentarchos of Abydos (IX c.)', 2)
# (73065, 'Seal of Synetos and Niketas general kommerkiarioi of the apotheke of Mesembria (713/4)', 2)
# (73086, 'Seal of Constantine patrikios, hypatos, judge and katepano of Mesopatamia (XI c.)', 2)
# (73087, 'Seal of Mikkinos and Gregory, general kommerkiarioi of the apotheke of Honorias (673/674)', 2)
# (73088, 'Seal of Julian apo hypaton and genikos kommerkiarios of the apotheke of Lydia (687/688)', 2)
# (73089, 'Seal of Klement imperial spatharios and kommerkiarios of Thessalonica (X c.)', 2)
# (73095, 'Seal of N. patrikios and strategos of the Anatolikoi (VIII c.)', 2)
# (73113, 'Seal of the imperial kommerikia of the provinces of the imperial Opsikion guarded by God (745/746)', 2)
# (73114, 'Seal of the imperial kommerkia of Thrace and Hexamilion (751-775)', 2)
# (73124, 'Seal of Constantine patrikios, praipositios, vestarches and domestikos of the Orient (XI c.)', 2)
# (73126, 'Seal of Michael skleros, protoproedros and anagrapheus of Drougoubiteia (XI c.)', 2)
# (73128, 'Seal of N., imperial protospatharios and strategos of Dyrrachion (XI c.)', 2)
# (73136, 'Seal of the Imperial Kommerkia of the Strategia of the Thrakesioi', 2)
# (73137, 'Seal of the imperial kommerkia of Mesembria (747/8)', 2)
# (73138, 'Seal of Constantine imperial strator and kommerkiarios of the West (X c.)', 2)
# (73150, 'Seal of the protos of (Mount) Ganos (XI/XII c.)', 2)
# (73156, 'Seal of Basil .... imperial notarios and grand kourator of Derzene, Rachaba (?) and Chavzizin (XI c.)', 2)
# (73159, 'Seal of Chrisophoros imperial paraphylax of Abydos (IX c.)', 2)
# (73177, 'Seal of Basil metropolitan of Pompeioupolis (X/XI c.)', 2)
# (73180, 'Seal of Nikephoros imperial protospatharios and strategos of Cherson (X c.)', 2)
# (73183, 'Seal of Petronas patrikios and komes of the imperial Opsikion guarded by God (VIII/IX c.)', 2)
# (73189, 'Seal of John (bishop) of Atramyttion (XII c.)', 2)
# (73190, 'Seal of Michael bishop of Herakleia (X/XI c.)', 2)
# (73192, 'Seal of Peter archbishop of Thessalonica (VIII c.)', 2)
# (73200, 'Seal of Nikephoros Batatzes, magistros, vestes, and doux of all the West (XI c.)', 2)
# (73201, 'Seal of George vestitor and protonotarios of Macedonia (IX c.)', 2)
# (73202, 'Seal of Demetrios metropolitan of Herakleia (IX/X c.)', 2)
# (73218, 'Seal of Pothos [vestes?] exaktor, oikistikos of the sakelle and kommerkiarios of Chaldia (XI c.)', 2)
# (73221, 'Seal of Leo imperial spatharios and protonotarios of Thessalonica (X c.)', 2)
# (73224, 'Seal of (John) protoproedros (of the protosynkelloi and metropolitan) of Side (XI c.)', 2)
# (73235, 'Seal of Epiphanios imperial protospatharios and strategos of the Kiberraiotai (Xth c.)', 2)
# (73238, 'Seal of Nikephoros Anzas, vestes, protonotarios of the Petrion and judge of the Islands (XI c.)', 2)
# (73240, 'Seal of Theodore spatharokandidatos, askretis and judge of the Thrakesioi (X/XI c.)', 2)
# (73242, 'Seal of Aresenios bishop of Paphos (X/XI c.)', 2)
# (73243, 'Seal of Sophronois poimenarches ( = archbishop) of Cyprus (after 1191)', 2)
# (73261, 'Seal of N., patrikios, imperial protospatharios and strategos of Hellas (VIII c.)', 2)
# (73269, 'Seal of Petronas anthypatos, patrikios, imperial protospatharios and komes of the Opsikion (IX c.)', 2)
# (73283, 'Seal of David bishop of Paipert (XI c.)', 2)
# (73286, 'Seal of Nikephoros bishop of Pyrgion (XI c.)', 2)
# (73304, 'Seal of N., eparchos of Thessalonica (VIII/IX c.)', 2)
# (73316, 'Seal of the proedros (metropolitan) of Nikomedeia (VIII c.)', 2)
# (73319, 'Seal of John Skleros, patrikios, anthypatos and strategos of the Peloponnesos (XI c.)', 2)
# (73324, 'Seal of Michael patrikios, hypatos, judge of the Velum and of the Kibyrraiotai (XI c.)', 2)
# (73329, 'Seal of Nikephoros patrikios and strategos of the Kibyrraiotai (XIth c.)', 2)
# (73336, 'Seal of John imperial spatharios and protonotarios of the Peloponnesos (X c.)', 2)
# (73340, 'Seal of Nicholas metropolitan of Neokaisareia (X/XI c.)', 2)
# (73342, 'Seal of Constantine notarios and horreiarios of St. Eusebios (?) (X/XI c.)', 2)
# (350730, 'Paint roller', 2)
# (350731, 'Paint roller', 2)
# (350732, 'Paint roller', 2)
# (350739, 'Painted canvas fragment\r\n', 2)
# (350740, 'Painted canvas fragment\r\n', 2)
# (350741, 'Painted canvas fragment\r\n', 2)
# (350742, 'Painted canvas fragment\r\n', 2)
# (350743, 'Tweezers', 2)
# (350744, 'Tweezers', 2)
# (350745, 'Tweezers', 2)
# (350746, 'Tweezers', 2)
# (350747, 'Tweezers', 2)
# (350748, 'Tweezers', 2)
# (350749, 'Tweezers', 2)
# (350750, 'Tweezers', 2)
# (350751, 'Tweezers', 2)
# (350752, 'Tweezers', 2)
# (352485, 'Plaque: Wild Goat and Deer', 2)
# (352727, 'Protective goggles', 2)
# (352768, 'Canvas stretching pliers', 2)
# (352838, 'Photo Lamp', 2)
# (352839, 'Tape Recorder', 2)
# (352841, 'Film reel', 2)
# (352842, 'Empty film reel', 2)
# (352843, 'Power cord for Reel-to-reel Tape Recorder', 2)
# (352845, 'Carena Zoomex 8mm film camera', 2)
# (352849, 'China-marker', 2)
# (352850, 'Hanging hardware', 2)
# (352862, 'Ink eraser', 2)
# (352863, 'China-marker', 2)
# (352865, 'Hanging hardware', 2)
# (352871, 'Angle blow brush', 2)
# (352872, 'Original box for angle blow brush', 2)
# (352873, 'Empty box for cut film holder', 2)
# (352874, 'Camera sunshade', 2)
# (352875, 'Ground glass adapter', 2)
# (352876, 'Film cutter', 2)
# (352877, 'Camera pistol grip', 2)
# (352879, 'Magnifying hood', 2)
# (352881, 'Tape measure', 2)
# (352903, 'Leather camera case and camera release cables', 2)
# (352907, 'Exposure meter', 2)
# (352910, 'Film backs in paper envelope', 2)
# (352979, 'Box of staples', 2)
# (352994, 'Blue towel', 2)
# (353005, 'Empty box for camera lens', 2)
# (353032, 'Saw wrapped in a paper map', 2)
# (353503, 'Folding wooden ruler', 2)
# (353601, 'Staple remover', 2)
# (353852, 'Box for Hasselblad 500 C camera', 2)
# (353853, 'Cardboard sleeve with Hasselblad 500 C sticker and handwritten notations', 2)
# (353854, 'Slide box with empty slide holders', 2)
# (353855, 'Slide box with empty slide holders', 2)
# (353856, 'Slide box with empty slide holders', 2)
# (353857, 'Slide box with empty slide holders', 2)
# (353859, 'Lens filter', 2)
# (353860, 'Empty box for lens filter', 2)
# (353861, 'Lens and lens case', 2)
# (353862, 'Emtpy leather lens case', 2)
# (353863, 'Fragment from leather lens case', 2)
# (353864, 'Lens in leather case', 2)
# (353876, 'Brown leather bag with strap', 2)
# (353878, 'Empty box for lens filter', 2)
# (354646, 'Protractor', 2)
# (354709, 'Protractor / stencil', 2)
# (355039, 'Red crayon', 2)
# (355040, 'China-marker', 2)
# (355222, 'Cover for jack lift', 2)
# (355235, 'Rubber stamp', 2)
# (355236, 'Rubber stamp', 2)
# (355237, 'Rubber stamp', 2)
# (355238, 'Rubber stamp', 2)
# (355239, 'Rubber stamp', 2)
# (355240, 'Rubber stamp', 2)
# (355241, 'Rubber stamp', 2)
# (355259, 'Small metal shovel', 2)
# (355261, '35 mm negative file pack\r\n', 2)
# (355268, 'Empty box for lens adapter', 2)
# (355269, 'Lens filter', 2)
# (355270, 'Lens filter', 2)
# (355271, 'Color movie film', 2)
# (355415, 'Cardboard slide box containing 1972 Tate Gallery label', 2)
# (355419, 'Slide tray lid', 2)
# (355428, 'Metal handle or stand', 2)
# (355429, 'Empty slide package', 2)
# (355433, 'Metal handle or stand', 2)

# %%
#7. What is the average rank of all artifacts?
query = """
SELECT AVG(rank) AS average_rank
FROM artifact_media
WHERE rank IS NOT NULL;
"""

my_cursor.execute(query)
avg_rank = my_cursor.fetchone()[0]
print("Average Rank of Artifacts:", avg_rank)
# Out:
# Average Rank of Artifacts: 133053.5556

# %%
#8. Which artifacts have a higher colorcount than mediacount?
query = """
SELECT m.objectid, d.title, m.colorcount, m.mediacount
FROM artifact_media AS m
JOIN artifact_metadata AS d ON m.objectid = d.id
WHERE m.colorcount > m.mediacount;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# (1412, '[Buildings, Germany (Siemensstadt?)]', 3, 0)
# (1413, '[Buildings, Stockholm, 1936]', 8, 0)
# (1414, '[Street scene, Berlin]', 7, 0)
# (1415, '[Street scene in Berlin]', 6, 0)
# (1416, '[Shellhaus, Berlin]', 7, 0)
# (1417, '[Street scene, Berlin]', 5, 0)
# (1418, '[Clothes blowing in the wind, Berlin]', 4, 0)
# (1419, '[Building reflected in water, Deep, Baltic Coast]', 6, 0)
# (1423, 'Portrait of a Woman, after a Drawing in the Uffizi then attributed to Leonardo da Vinci', 6, 0)
# (1424, 'The Parable of the Unjust Husbandmen', 7, 0)
# (1425, 'The Virgin and Joseph at the Inn', 8, 0)
# (1427, 'The Guards of the Rose Garden', 10, 0)
# (1428, 'Battle Scene (painting, recto), folio fragment from a Bhagavata Purana series', 8, 0)
# (1429, 'What a Glorious Land!', 7, 0)
# (1430, 'Two Equestrian Figures, One Male with a Tall, Elaborately Embellished Hat, One Female with Hair in a Topknot, Both with Pointed Boots, and Hands Positioned to Hold the Reins of their Standing, Saddled Horses', 10, 0)
# (1431, 'Statement on the other side of this card', 6, 0)
# (1432, 'Two Standing Boars', 10, 0)
# (1434, 'San Arcangelo', 8, 0)
# (1436, 'Geranium Chamadryoides', 8, 0)
# (4560, '[Train and steam near Hildebrand Chocolate Company, Berlin]', 5, 0)
# (4561, '[Village in Brittany]', 3, 0)
# (4562, '[Street scene in Quimper, Brittany]', 4, 0)
# (4563, '[Harbor scene, Brittany]', 4, 0)
# (4564, '[Harbor scene, Brittany]', 2, 0)
# (4565, '[Men standing at harbor railing, Brittany]', 7, 0)
# (4566, '[Harbor scene with fisherman, Stockholm, 1936]', 4, 0)
# (4567, '[Harbor scene with boatmen, Saint-Malo, Brittany]', 5, 0)
# (4568, '[Street scene, Saint-Malo, Brittany]', 6, 0)
# (4569, '[Boats in the harbor at Saint-Malo, Brittany]', 7, 0)
# (4570, '[Harbor scene in Saint-Malo, Brittany]', 4, 0)
# (4571, '[Buildings in Paris]', 6, 0)
# (4572, '[View of barge on the Seine, with Notre-Dame Cathedral, Paris]', 2, 0)
# (4573, '[Kaiser Wilhelm Memorial Church, Berlin]', 4, 0)
# (4574, '[Transporting a boat on the road, Germany]', 4, 0)
# (4575, '[Street scene, Berlin]', 6, 0)
# (4576, '[Pedestrians walking, viewed from above, Berlin, 1933]', 4, 0)
# (4577, '[Street scene with the Kaiser Wilhelm Memorial Church, Berlin]', 5, 0)
# (4578, '[Street scene, Berlin]', 5, 0)
# (4579, '[Cityscape, Berlin]', 4, 0)
# (4580, '[Shellhaus, Berlin]', 2, 0)
# (4585, 'Rebecca, an Emancipated Slave, from New Orleans', 8, 0)
# (4586, 'Streams and Mountains, from the series "Sacrifice"', 9, 0)
# (4587, 'Two Standing Court Ladies, Each with Upturned Shoes, a High-Waisted Dress or Skirt, a Shawl, and an Elaborate Coiffure Secured by a Headband, and Each with Her Hands Clasped at the Waist and Concealed within Her Sleeves', 10, 0)
# (4588, "Two Standing Officials, Each with Upturned Shoes, a 'Liangdang' Breastplate, and a Military Official's Headgear Emblazoned with a Descending Bird, and Each with His Hands Clasped at His Waist and Concealed within His Sleeves", 10, 0)
# (4591, 'Games & Puzzles', 6, 0)
# (4592, 'Races, Immigration: United States. New York. New York City. Immigrant Station: Regulation of Immigration at the Port of Entry. United States Immigrant Station, New York City', 8, 0)
# (4593, 'Untitled Documentary Shot', 10, 0)
# (4594, 'Mirrorstage for Merce', 10, 0)
# (4602, 'Nut Bone', 8, 0)
# (4603, 'Rooster Pendant', 10, 0)
# (4606, 'The Parable of the Rich Fool', 7, 0)
# (4607, 'The Plucking of Ears of Corn on Sabbath Day', 8, 0)
# (4608, 'The Parable of the Barren Fig Tree', 8, 0)
# (4609, 'Walliser Bergriesen. Wide Horn and Company.', 7, 0)
# (4610, 'Wildpeak, the Bad and the cute little white Ball', 10, 0)
# (4611, '[Shellhaus, Berlin]', 3, 0)
# (4612, '[Railroad yard in snow, Berlin]', 5, 0)
# (4613, '[Sand dunes, Deep, Baltic Coast]', 4, 0)
# (4615, 'The Great Wall Snaking through the Mountains, from the series "Sacrifice"', 9, 0)
# (4617, 'Coin of Kassander, Macedonia', 5, 0)
# (4618, 'Obol of Himera, Sicily', 3, 0)
# (4619, 'Dufour and his Beautiful Donna Rosa', 10, 0)
# (4620, 'The Parable of the Kingdom of Heaven', 8, 0)
# (4621, 'Titlepage', 8, 0)
# (4622, 'Christ and the Woman of Samaria', 9, 0)
# (4623, 'The Good Shepherd', 8, 0)
# (4624, 'Selection of 16th century prints', 9, 0)
# (4625, 'The Ortler dreams of lost Times', 10, 0)
# (4626, 'The King of the east Alps (The King Peak)', 10, 0)
# (4627, 'Near St. Martino. Cima the Castrozza and Val di Rota.', 10, 0)
# (4629, 'Beach Scene', 5, 0)
# (4630, 'Portrait of a Soldier', 7, 0)
# (4632, 'My Personal Atlas', 3, 0)
# (4633, 'The Angel Telling Joseph to Flee and the Flight into Egypt', 8, 0)
# (4634, 'Jesus Calling the Apostles Among the Fishermen', 8, 0)
# (4635, 'The Parable of the Sower', 7, 0)
# (4636, 'The Parable of the Two Sons and the Unjust Husbandmen', 7, 0)
# (4637, 'Allegory of the Triumph of the Netherlands over Spain', 8, 0)
# (4638, 'The sweet Sugar Cone and the wild Priest', 9, 0)
# (4639, 'Cima della Pala and the Vezzana', 10, 0)
# (4640, 'Fantastic Mountains in Western China, from the series "Sacrifice"', 9, 0)
# (4641, 'Two Standing, Braying Camels, One Buff, One White, Their Backs Laden with Goods', 10, 0)
# (4642, "Four Kneeling, Female Court Musicians (One with a 'Pipa', or Lute, and One with Cymbals), Each of the Four with a High-Waisted, Striped Dress or Skirt and with Long Hair Arranged in Two Buns", 10, 0)
# (4644, 'Two Standing, Bearded, Foreign Male Figures, Each Wearing a Tall Hat with Protective Neck and Ear Flaps, a Shoulder Scarf, Heavy Boots, and Spotted, Leopard-Skin Trousers, and Each with His Hands Clasped at His Chest', 10, 0)
# (4645, 'Pair of Standing, Helmeted, Armor-Clad, Bearded Guardian Warriors, One with Mouth Open, One with Mouth Closed, Each with Pointed Boots and a Hand Raised to Waist Level as if Grasping a Lance or Spear, and Standing on a Rocky Base from which Protrude the Head and Tail of a Snake', 10, 0)
# (4646, 'Pair of Standing, Helmeted, Armor-Clad Guardian Warriors, Each with One Arm Raised and One at the Side, and Both Hands Clenched as if Holding Weapons, One Figure with Mouth Closed and Wearing Straw Shoes, One with Mouth Open and Wearing Pointed Boots', 10, 0)
# (4647, 'Study for the Mansfield Monument', 1, 0)
# (4648, 'Mystical Journey', 6, 0)
# (4651, '[Boat in water, Deep, Baltic Coast]', 8, 0)
# (4652, '[Beach scene, Deep, Baltic Coast]', 6, 0)
# (4653, 'Cloud Scissors', 4, 0)
# (4654, "Butterfly for a Valance at Dowdeswell's Gallery", 4, 0)
# (4667, '[Street scene, Germany]', 5, 0)
# (4668, '[Clothes on line, flapping in the wind, Berlin]', 3, 0)
# (4669, '["U-bahn," Berlin]', 3, 0)
# (4670, '[Julia Feininger in Berlin]', 3, 0)
# (4671, '[Siemsstadt-Berlin]', 4, 0)
# (4672, '[Building, Siemensstadt-Berlin]', 4, 0)
# (4673, '[Street scene, Berlin, 1933-1937, rephotographed as slide]', 5, 0)
# (4674, '[Wooden pilings at Deep, Baltic Coast]', 7, 0)
# (4675, '[Building with fishing nets, Deep, Baltic Coast]', 5, 0)
# (4676, 'Paper Flux Work', 4, 0)
# (4677, '"Six million farms and over in this country last census."', 6, 0)
# (4678, 'Jardinière', 10, 0)
# (4679, 'Poem 70-26', 12, 0)
# (4680, 'Poem 69-8', 12, 0)
# (4726, 'A View of Cronesteyn Castle, near Leiden', 7, 0)
# (4727, '"Nincompoopiana"', 8, 0)
# (4728, 'Ida B. Wells (1862-1931)', 10, 0)
# (4767, '[Church in Concarneau, Brittany]', 3, 0)
# (4768, '[Quimper Cathedral, Brittany]', 8, 0)
# (4769, '[Church in Brittany]', 3, 0)
# (4770, '[Street scene in Quimper, Brittany]', 3, 0)
# (4771, '[Boat in water, Brittany]', 6, 0)
# (4772, '[Church in Brittany]', 6, 0)
# (4773, '[Windmill near Quimper, Brittany]', 6, 0)
# (4774, '[Market in Quimper, Brittany]', 7, 0)
# (4775, '[Workers outside Quimper Cathedral, Brittany]', 4, 0)
# (4776, '[Street scene in Saint-Malo, Brittany]', 4, 0)
# (4777, '[Windmills near Quimper, Brittany]', 8, 0)
# (4778, '[Harbor scene in Saint-Malo, Brittany]', 6, 0)
# (4779, '[Boats in harbor, Saint-Malo, Brittany]', 4, 0)
# (4780, '[Harbor scene in Saint-Malo, Brittany]', 7, 0)
# (4781, '[Harbor scene in Saint-Malo, Brittany]', 7, 0)
# (4782, '[Ship in the harbor at Saint-Malo, Brittany]', 6, 0)
# (4783, '[Street scene, Paris]', 2, 0)
# (4784, '[Street scene, Paris]', 3, 0)
# (4785, '[Buildings, Paris]', 3, 0)
# (4786, '[Street scene, Germany]', 4, 0)
# (4835, 'Octodrachm of Alexander I of Macedonia', 6, 0)
# (4837, 'The Myths', 9, 0)
# (4838, 'Old Man and Papa Sentis', 9, 0)
# (4839, 'Diadem Band Fragment with Walking Lion and Rosette', 10, 0)
# (4842, 'Portrait of the Greek Orator Demosthenes', 10, 0)
# (4844, 'Postcard', 8, 0)
# (4845, 'Postcard', 9, 0)
# (4846, 'Postcard', 6, 0)
# (4847, 'Postcard', 5, 0)
# (4848, 'Patka (sash)', 10, 0)
# (4849, "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: How Thousands of Men Make Their Leisure Hours Count!: Some Opportunites Open to You at the Boston Young Men's Christian Association", 8, 0)
# (4850, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Volunteer Varieties: Various Vocations for Volunteers in Social Work: The Volunteer Service Bureau: Auspices of the Boston Metropolitan Chapter American Red Cross.', 9, 0)
# (4852, '“Putka”, folio from the album Fishes of India', 7, 0)
# (4855, '“Pan”, folio from the album Fishes of India', 5, 0)
# (4856, 'Cover of the album "Fishes of India"', 9, 0)
# (4857, 'Art Theory Diagrams', 6, 0)
# (4859, 'A Paraleytic Woman', 8, 0)
# (4860, 'Tetradrachm of Hyspaosines of Characene', 3, 0)
# (4861, 'Tetradrachm of Kamnaskires I of Elymais, Susa', 2, 0)
# (4862, 'Tetradrachm of Antiochos II, Antioch', 2, 0)
# (4863, 'Nomos of Kroton struck over a didrachm of Leontinoi', 2, 0)
# (4864, 'Bunnies', 1, 0)
# (4865, 'Warrior', 10, 0)
# (4866, 'Pair of Lion-Headed Earrings', 10, 0)
# (4867, 'Basin Handle with Lion and Snake Heads', 9, 0)
# (4868, 'Ram Pendant', 10, 0)
# (4869, 'Study for "Box Smashed Flat (Vicksburg)"', 2, 0)
# (4872, 'The Morning III', 10, 0)
# (4873, 'Mysteries', 10, 0)
# (4875, "My Mother's Axe", 9, 0)
# (4879, 'Color Diagram for “Composition Concrete”', 5, 0)
# (4880, 'Study for “Pochade”', 6, 0)
# (4881, 'Study for “Pochade”', 7, 0)
# (4882, 'Study for “Study for ‘Pochade’ #3”', 10, 0)
# (4883, 'Study for “Study for ‘Pochade’ #2”', 10, 0)
# (4884, 'Study for "Pochade"', 10, 0)
# (4885, 'Study for “Pochade”', 7, 0)
# (4887, 'The Morning I', 10, 0)
# (4888, 'Waste of Energy', 9, 0)
# (4893, 'Study for ”Standard Still Life”', 10, 0)
# (4894, 'Study for “Study for ‘Pochade’ #2”', 10, 0)
# (4897, 'Recreation, Parks and Playgrounds: United States. New York. New York City. Crotona Park, Vacation Playground: New York City Public Schools. Examples of the Adaptation of Education to Special City Needs: Vacation Playgrounds - Crotona Park.', 7, 0)
# (4901, 'Ex Libris Hildegard Heyne', 6, 0)
# (4902, 'Art Theory Text with Diagrams', 7, 0)
# (4903, 'Study for “’Art Digest’ Cover”', 10, 0)
# (4904, 'Art Theory Text with Sketch', 4, 0)
# (4905, 'Waste of Energy', 10, 0)
# (4906, 'On a Search', 10, 0)
# (4912, 'Study for "Pochade"', 9, 0)
# (4913, 'Art Theory Text with Sketch', 8, 0)
# (4914, 'Study for “Study for ‘Pochade’ #3”', 10, 0)
# (4915, 'Study for “Standard Still Life #2”', 10, 0)
# (4916, 'Study for “Pochade”', 10, 0)
# (4917, 'Study for “Pochade”', 8, 0)
# (4918, 'Study for “Pochade”', 1, 0)
# (4923, 'Recreation, Parks and Playgrounds: United States. New York. New York City. Brooklyn, Vacation Playground, Public School No. 45: New York City Public Schools. Examples of the Adaptation of Education to Special City Needs: Public School No. 45 Brooklyn. Vacation Playgrounds.', 4, 0)
# (4926, 'Death on a Horse', 9, 0)
# (4927, 'Landscape with Full Moon', 7, 0)
# (4928, 'Night, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4929, 'Farmer, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4930, 'Herod, from the portfolio "On Death, Part One, Opus XI"', 6, 0)
# (4931, 'A Cooper', 7, 0)
# (4934, 'Study for “Something on the 8 Ball”', 10, 0)
# (4935, 'Art Theory Text with Sketch', 8, 0)
# (4936, 'Color Diagram for “Tournos”', 4, 0)
# (4937, 'Study for “’Art Digest’ Cover”', 7, 0)
# (4938, 'Study of “Columbia Records Album Cover”', 7, 0)
# (4939, 'Study for “’Art Digest’ Cover”', 5, 0)
# (4940, 'The Morning II', 10, 0)
# (4941, 'There Are People', 8, 0)
# (4942, 'Manifesto', 10, 0)
# (4944, 'Study for “Pochade”', 6, 0)
# (4945, 'Study for “Pochade”', 10, 0)
# (4948, 'Recreation, Parks and Playgrounds: United States. New York. New York City. Bronx Park, Vacation Playground: New York City Public Schools. Examples of the Adaptation of Education to Special Needs: Vacation-Playgrounds. Bronx Park. Public School 105 Manhattan.', 6, 0)
# (4950, 'Death as Savior, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4951, 'Poor Family, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4952, 'On the Tracks, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4953, 'Child, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4954, 'Road, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4955, 'Sea, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4956, 'Sailors, from the portfolio "On Death, Part One, Opus XI"', 8, 0)
# (4961, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The Church Home Society for the Care of Children and Young People of the Protestant Episcopal Church', 7, 0)
# (4962, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Services July 1, 1927 - June 30, 1928: American Red Cross Boston Metropolitan Chapter', 10, 0)
# (4966, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Co-operative Workrooms for Handicapped Women: A brief statement of the services rendered during the fiscal year October 1, 1927 to September 30, 1928', 9, 0)
# (5016, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: A Few Words to Children about Some Other Children: Junior Division Massachusetts Society for the Prevention of Cruelty to Children', 7, 0)
# (5017, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Our Citizens: North Bennet Street Industrial School', 10, 0)
# (5018, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The New England Medical Center', 10, 0)
# (5019, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: One Dozen Ways of Using One Glass of Skim Milk: The Food Clinic of The Boston Dispensary', 8, 0)
# (5024, '[Street scene, Brittany]', 7, 0)
# (5025, '[Street scene with Quimper Cathedral, Brittany]', 3, 0)
# (5026, '[Quimper Cathedral, Brittany]', 6, 0)
# (5027, 'Street scene near the Odet River, Brittany]', 3, 0)
# (5028, '[Windmill near Quimper, Brittany]', 5, 0)
# (5029, '[Horse cart in street, Brittany]', 4, 0)
# (5030, '[Church in Brittany]', 6, 0)
# (5031, '[Village in Brittany]', 5, 0)
# (5032, '[Street scene, Brittany]', 3, 0)
# (5033, '[Street scene in Quimper, Brittany]', 4, 0)
# (5034, '[Village harbor, Brittany]', 6, 0)
# (5035, '[Buildings, Brittany]', 3, 0)
# (5036, '[Street scene with Quimper Cathedral, Brittany]', 5, 0)
# (5037, '[Street scene with Quimper Cathedral, Brittany]', 2, 0)
# (5038, '[Street scene in Quimper, Brittany]', 3, 0)
# (5039, '[Street scene, Brittany]', 2, 0)
# (5040, '[Coastal village, Brittany]', 4, 0)
# (5041, '[Riverbank with boats in Douarnenez?, Brittany]', 6, 0)
# (5042, '[Church in Brittany]', 5, 0)
# (5043, '[Harbor scene, Brittany]', 7, 0)
# (5044, '[Riverbank with boats in Douarnenez?, Brittany]', 4, 0)
# (5045, '[Harbor scene, Brittany]', 7, 0)
# (5046, '[Harbor scene, Brittany]', 6, 0)
# (5047, '[Harbor steps, Stockholm, 1936]', 3, 0)
# (5048, '[Harbor scene with men and boat, Deep, Baltic Coast]', 6, 0)
# (5049, '[Harbor scene, Saint-Malo, Brittany]', 9, 0)
# (5050, '[Laurence Feininger, Germany (Berlin?)]', 3, 0)
# (5051, '[Auto sign, Germany]', 6, 0)
# (5052, '[Street scene with church, Lübeck]', 3, 0)
# (5053, 'Portfolio cover from the portfolio "On Death, Part One, Opus XI"', 7, 0)
# (5059, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The Co-operative Workrooms for Handicapped Women', 9, 0)
# (5060, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Supposing No One Cared: Florence Crittenton League of Compassion, Inc.', 9, 0)
# (5061, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The Hospital Without Walls: Community Health Association', 7, 0)
# (5066, '[Street scene with Quimper Cathedral, Brittany]', 2, 0)
# (5067, '[Street scene in Quimper, Brittany]', 3, 0)
# (5068, '[Street scene, Brittany]', 5, 0)
# (5069, '[Street scene, Brittany]', 2, 0)
# (5070, '[Douarnenez?, Brittany]', 4, 0)
# (5071, '[Harbor scene, Brittany]', 3, 0)
# (5072, 'Untitled', 9, 0)
# (5073, 'Untitled', 9, 0)
# (5074, 'Movement in White, from the Transitions portfolio', 8, 0)
# (5075, 'Poem 68-55', 11, 0)
# (5076, 'Cell-A', 12, 0)
# (5078, 'Untitled (Susanna Shahn and friend, Jersey Homesteads, New Jersey)', 10, 0)
# (5079, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 6, 0)
# (5080, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5081, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5082, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5083, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5084, 'An Ajaccio Fisherman', 5, 0)
# (5085, '[View of harbor and ships, Brittany]', 5, 0)
# (5086, '[Street scene in Quimper, Brittany]', 2, 0)
# (5087, '[Harbor scene in Concarneau?, Brittany]', 8, 0)
# (5088, '[Harbor scene, Brittany]', 3, 0)
# (5089, '[Ship in the harbor at Saint-Malo, Brittany]', 8, 0)
# (5090, '[Coastal scene near Saint-Malo, Brittany]', 4, 0)
# (5091, '[Women in traditional dress at Saint-Malo Harbor, Brittany]', 7, 0)
# (5092, '[Boats on river, Brittany?]', 2, 0)
# (5093, '[Laurence Feininger, Germany (Berlin?)]', 4, 0)
# (5094, '[Street scene, Germany]', 4, 0)
# (5095, '[Street scene, Berlin]', 6, 0)
# (5096, '[Strand-Cafe on dock, Germany]', 6, 0)
# (5097, '[Street scene, Germany]', 2, 0)
# (5098, '[Street scene with cars, Germany]', 3, 0)
# (5099, '[Buildings, Berlin]', 3, 0)
# (5100, '[Train and steam near Hildebrand Chocolate Company, Berlin]', 5, 0)
# (5101, '[Train station in Berlin]', 4, 0)
# (5102, '[Railroad yard and buildings, Berlin]', 3, 0)
# (5103, '[Cityscape with railroad tracks, Berlin]', 3, 0)
# (5108, "Tea Bowl with Indented Lip and Subtle Hare's-Fur Markings", 10, 0)
# (5109, 'Landscape', 5, 0)
# (5115, 'Industrial Problems, Welfare Work: United States. Illinois. LeClaire. Nelson Manufacturing Company: Welfare Institutions. N.O. Nelson Co., LeClaire, Ill.', 8, 0)
# (5116, 'Industrial Problems, Welfare Work: United States. Pennsylvania. Westmoreland County. H.C. Frick Coke Company: Welfare and Educational Work for the Families of Employees: District nurses teaching mothers how to care for their babies.', 10, 0)
# (5117, 'Races, Immigration: United States. New York. New York City. Immigrant Station: Regulation of Immigration at the Port of Entry. United States Immigration Station, New York City', 9, 0)
# (5118, 'Pilze in Wasser [Mushroom in Water]', 10, 0)
# (5122, 'Sketch', 4, 0)
# (5123, 'Art Theory Text with Horses and Riders', 6, 0)
# (5124, 'Study for "Ursine Park"', 9, 0)
# (5125, 'Study for “Ursine Park”', 7, 0)
# (5126, 'Study for “Ursine Park”', 7, 0)
# (5127, 'Sketch', 5, 0)
# (5128, 'Art Theory Text with Diagram', 4, 0)
# (5129, 'Art Theory Text with Gesture Sketch', 5, 0)
# (5130, 'Art Theory Text with Gesture Sketch', 8, 0)
# (5131, 'Study for “Cliché” and “Ready-to-Wear”', 10, 0)
# (5132, 'Study for “Cliché” and “Ready-to-Wear”', 6, 0)
# (5133, 'Study for “Cliché” and “Ready-to-Wear”', 9, 0)
# (5134, 'Study for “Cliché” and “Ready-to-Wear”', 7, 0)
# (5135, 'Study for “Ready-to-Wear”', 8, 0)
# (5136, 'La belle Lili', 10, 0)
# (5137, 'Bust of Balzac', 8, 0)
# (5138, 'S. P. Drawing', 10, 0)
# (5139, 'Figure Studies (recto and verso)', 8, 0)
# (5140, 'Study of a Soldier', 10, 0)
# (5144, 'Melting-Glacier Water Cascading through a Thousand Peaks, from the series "Sacrifice"', 10, 0)
# (5145, 'A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 9, 0)
# (5146, 'Pillow, from the series "Sacrifice"', 7, 0)
# (5147, 'Study for “Cliché”', 7, 0)
# (5148, 'Art Theory Text with Sketches', 5, 0)
# (5149, 'Calligraphic Tone Diagram', 6, 0)
# (5150, 'Art Theory Text with Minimum and Maximum Ratio Differential Diagrams', 3, 0)
# (5151, 'Art Theory Text with Minimum and Maximum Ratio Differential Diagram', 3, 0)
# (5153, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea Park Band Stand.', 6, 0)
# (5154, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea - Park, Lake.', 5, 0)
# (5155, 'Recreation, Parks and Playgrounds: United States. Massachusetts. Cambridge: Playgrounds. Cambridge, Massachusetts: Competitive games, drills, dances and races in which children of all Cambridge playgrounds took part. First Municipal Play Festival, Russell Field, 1914.', 6, 0)
# (5156, 'Recreation, Parks and Playgrounds: United States. Massachusetts. Cambridge: Playgrounds. Cambridge, Massachusetts: Competitive games, drills, dances and races in which children of all Cambridge playgrounds took part. First Municipal Play Festival, Russell Field, 1914.', 7, 0)
# (5157, 'Art Theory Text with Maximum Ratio Differential Diagram', 5, 0)
# (5158, 'Art Theory Text with Star and Diagram', 6, 0)
# (5159, 'Art Theory Text with Sketches', 9, 0)
# (5160, 'A and B Figure Fields', 6, 0)
# (5161, 'Study for “UFO”', 9, 0)
# (5162, 'Sketch', 4, 0)
# (5163, 'Art Theory Text with Context Figure Diagrams', 5, 0)
# (5164, 'Art Theory Text with Diagram', 4, 0)
# (5165, 'Study for “Composition Concrete”', 6, 0)
# (5166, 'Color Diagram for “Composition Concrete”', 10, 0)
# (5167, 'Study for “Composition Concrete”', 7, 0)
# (5168, 'Study for “Composition Concrete”', 7, 0)
# (5169, 'Study for “Composition Concrete”', 6, 0)
# (5170, 'Study for “Composition Concrete”', 5, 0)
# (5171, 'Preliminary Study for “Columbia Records Album Cover”', 8, 0)
# (5172, 'Preliminary Study for “Columbia Records Album Cover”', 8, 0)
# (5179, 'Théâtre municipal Calais II', 10, 0)
# (5180, 'Engine, Frankfurt Airport, April 19, 2001', 10, 0)
# (5181, 'Untitled', 10, 0)
# (5182, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro: Hampton Normal and Agricultural Institute, Hampton, Va.', 6, 0)
# (5183, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro. Training for Commercial and Industrial Employment. Hampton Normal and Agricultural Institute, Hampton, Va.', 9, 0)
# (5184, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro. Hampton Normal and Agricultural Institute, Hampton, Va.', 8, 0)
# (5190, 'Illustrated Instructions for First Workset, Number 26:  Head Body Limbs', 4, 0)
# (5191, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 9, 0)
# (5192, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 9, 0)
# (5193, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 10, 0)
# (5194, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 10, 0)
# (5195, 'coin of Maximinus from Ancialos, Thrace', 4, 0)
# (5196, 'Coin of Athens', 3, 0)
# (5198, 'Untitled (architecture)', 5, 0)
# (5199, 'Picking Tobacco, Oklahoma', 10, 0)
# (5200, 'Design-Five Bars', 8, 0)
# (5201, 'Twenty-fourth Stater of Kyzikos', 10, 0)
# (5202, 'Hekte of Kyzikos', 8, 0)
# (5203, 'Lithographs Based on Geologic Maps of Lunar Orbiter and Apollo Landing Sites', 4, 0)
# (5204, 'Dwelling in the Mountains, from the series "Sacrifice"', 9, 0)
# (5205, 'A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 9, 0)
# (5206, '"Pushing combine.Twelve hours a day."', 4, 0)
# (5207, '"We\'ve Got Everything to Lose if You Win"', 4, 0)
# (5208, '"And Russians shucks I cant  add em all up. I can’t even [Spring?] is against you Russian scene ?"', 5, 0)
# (5209, '"And Gus Taubs boy over in the tank plan."', 7, 0)
# (5211, 'Le Marché aux Bestiaux, Dieppe', 9, 0)
# (5212, 'Untitled', 8, 0)
# (5213, 'Untitled', 9, 0)
# (5214, 'Devoted, from the Transitions portfolio', 8, 0)
# (5215, 'Forested Peaks, Distant Waterfall, from the series "Sacrifice"', 10, 0)
# (5216, 'Mists along a Mountain River, from the series "Sacrifice"', 9, 0)
# (5217, 'Secluded Mountain Temple, from the series "Sacrifice"', 10, 0)
# (5218, 'Sunrise on Towering Peaks, from the series "Sacrifice"', 9, 0)
# (5219, 'Pines on Slender Peaks, from the series "Sacrifice"', 9, 0)
# (5220, 'Bend in the Mountain River Near the Bingling-Si Cave Temples, from the series "Sacrifice"', 9, 0)
# (5221, 'Mountains and Pines in Moonlight, from the series "Sacrifice"', 10, 0)
# (5222, 'Mountain Bluff, Cascading Waterfall, from the series "Sacrifice"', 9, 0)
# (5223, '"You see farmers don\'t talk much. Delano [pot?].The wind etc...."', 7, 0)
# (5224, '"Food for all kinds of folks I\'ll never see who are fighting for our side. British children and British seamen. Chinese soldier most likely."', 5, 0)
# (5225, '"Food for the men on ships and the men in planes. Food for Ed Summers boy on his destroyer"', 7, 0)
# (5234, 'Postcard', 8, 0)
# (5235, 'Postcard', 10, 0)
# (5236, 'Postcard', 7, 0)
# (5237, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Service Continuation Fund: Boston Y.W.C.A.', 10, 0)
# (5238, 'Art Theory Text with Study for “Something on the 8 Ball”', 6, 0)
# (5239, 'Study for “Something on the 8 Ball”', 8, 0)
# (5240, 'View of Wimmis, Valley of the Simmental, Switzerland', 10, 0)
# (5241, 'Untitled', 8, 0)
# (5242, 'Trio, from the Transitions portfolio', 4, 0)
# (5243, 'The Natural Bridge, Virginia', 7, 0)
# (5244, 'Sixteen Arhats (Rakan) in a Fantastic Landscape', 7, 0)
# (5245, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 7, 0)
# (5246, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5247, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 9, 0)
# (5248, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5249, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5250, 'Untitled (children, Jersey Homesteads, New Jersey)', 10, 0)
# (5251, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5252, 'Untitled (Susanna Shahn and other children, Jersey Homesteads, New Jersey)', 10, 0)
# (5253, 'Ikat Panel', 10, 0)
# (5254, 'Ikat Panel', 10, 0)
# (5255, 'Ikat Panel', 10, 0)
# (5265, 'Saints Prosdocimus, Justina, Daniel, and Anthony of Padua in Glory with a View of the Prato della Valle, Padua', 10, 0)
# (5266, 'Method as Meaning', 7, 0)
# (5267, 'Study for “Natural Scene”', 7, 0)
# (5268, 'Study for “Tournos”', 4, 0)
# (5270, 'Postcard', 8, 0)
# (5271, 'Postcard', 7, 0)
# (5272, 'Postcard', 8, 0)
# (5273, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Adopting a Child: Blessing or Tragedy?: Massachusetts Civic League, Inc.', 9, 0)
# (5274, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Boston Metropolitan Chapter American Red Cross: A Record of the Tenth Year', 10, 0)
# (5275, 'Ikat Panel', 10, 0)
# (5276, 'Velvet Ikat Panel', 9, 0)
# (5277, '"Eye" Bead with Aqua and White Swirls', 10, 0)
# (5280, 'Preliminary Study for “’Art Digest’ Cover”', 7, 0)
# (5281, 'Sketch', 10, 0)
# (5282, 'Sequence-Object Diagrams', 4, 0)
# (5283, 'The Morning II', 10, 0)
# (5284, "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: That Meddlin' Society: The Society for the Prevention of Cruelty to Children", 10, 0)
# (5285, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Massachusetts Civic League', 9, 0)
# (5286, 'Study for “Something on the 8 Ball”', 6, 0)
# (5288, 'Velvet Ikat Panel', 10, 0)
# (5290, '“Gainchie”, folio from the album, Fishes of India', 2, 0)
# (5294, '“Manua”, folio from the album Fishes of India', 9, 0)
# (5296, 'Study for “Something on the 8 Ball”', 9, 0)
# (5297, 'Study for “Something on the 8 Ball”', 6, 0)
# (5298, 'Object-Place-Size Diagrams', 8, 0)
# (5299, 'Study for “Something on the 8 Ball”', 9, 0)
# (5300, 'Coin of Corinth under Claudius', 10, 0)
# (5301, 'Coin of Nicopolis under Geta', 2, 0)
# (5303, 'Coin of Nicopolis under Augustus', 7, 0)
# (5304, 'Hekte of Kyzikos', 9, 0)
# (5305, 'Hekte of Kyzikos', 9, 0)
# (5306, 'Tetradrachm', 5, 0)
# (5307, 'Creation of Man', 7, 0)
# (5308, 'Tetradachm of Seleukos I, Seleukeia-on-the-Tigris, second workshop', 10, 0)
# (5309, 'Virgin, Monk and Eiger', 8, 0)
# (5310, 'Bull Standard', 9, 0)
# (5311, 'Figure of a Seated Ape', 7, 0)
# (5312, 'Earrings with Three Lion Heads', 10, 0)
# (5313, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 10, 0)
# (5314, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 9, 0)
# (5315, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 10, 0)
# (5316, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 10, 0)
# (5317, 'Trial Piece for a Tetradrachm of Philip V of Macedon', 6, 0)
# (5318, 'Coin of Abydos under Caracalla (cast forgery)', 10, 0)
# (5319, 'Coin of Tarsos under Gordian III', 4, 0)
# (5320, 'Design in Movement', 2, 0)
# (5321, 'Under the Roof', 10, 0)
# (5322, 'Spill', 9, 0)
# (5323, 'Coin of Nicopolis under Augustus', 7, 0)
# (5324, 'Tetradrachm of Antiochos II, Sardis', 3, 0)
# (5325, 'In the Net', 9, 0)
# (5326, 'The Ptolemaic System', 7, 0)
# (5327, 'Lot and His Daughters', 7, 0)
# (5328, 'The Triumph of the World', 8, 0)
# (5332, "Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: Joseph McCarthy. Jan. 27, 1904. Grandma's Story.", 8, 0)
# (5336, 'Art Theory Text with Diagrams', 7, 0)
# (5337, 'Art Theory Text with Diagrams', 8, 0)
# (5338, 'Study for “Owh! in San Pão”', 10, 0)
# (5339, 'Study for “American Painting”', 8, 0)
# (5341, 'Art Theory Text with Diagrams', 4, 0)
# (5342, 'Study for “’Art Digest’ Cover”', 4, 0)
# (5343, 'Art Theory Text with Sequence Diagrams', 5, 0)
# (5344, 'Study for “Tournos”', 8, 0)
# (5353, 'Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: Henry Seeley. Jan. 25, 1904. Golden-Rod', 8, 0)
# (5358, 'Christ at the Column', 10, 0)
# (5359, 'Hercules Wrestling with a Centaur', 10, 0)
# (5360, 'Putto', 9, 0)
# (5361, 'Studies of a Rooster', 7, 0)
# (5362, 'Untitled', 2, 0)
# (5363, 'Ruin of an Aqueduct on the Road to Cori, Italy', 5, 0)
# (5364, 'Tazza', 10, 0)
# (5365, 'Lake with Sailboats', 10, 0)
# (5367, 'No title', 10, 0)
# (5368, 'Viewing the Falls from a Mountain Pavilion, from the series "Sacrifice"', 10, 0)
# (5369, 'A Thousand Peaks, from the series "Sacrifice"', 9, 0)
# (5380, 'Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: Thomas White. Jan. 26, 1904. The Pied Piper of Hamlen', 7, 0)
# (5384, 'Study for “Owh! in San Pão”', 9, 0)
# (5385, 'Study for “Owh! in San Pão”', 9, 0)
# (5386, 'Study for “Owh! in San Pão”', 8, 0)
# (5387, 'Study for “Owh! in San Pão”', 6, 0)
# (5388, 'Art Theory Text with Box Perspective Diagram', 6, 0)
# (5389, 'Art Theory Text with Box Perspective Diagram', 4, 0)
# (5390, 'Black in Front versus White in Front Sketches', 5, 0)
# (5391, 'Sketch', 3, 0)
# (5392, 'Study for ‘The Outside”', 6, 0)
# (5393, 'Study for “Nu”', 5, 0)
# (5394, 'Unit of Place Diagrams', 3, 0)
# (5395, 'Study for “Allée”', 3, 0)
# (5396, 'Art Theory Text with Maximum Ratio Differential Sketch', 9, 0)
# (5397, 'Art Theory Text with Maximum Ratio Differential Sketch', 3, 0)
# (5398, 'Art Theory Text with Maximum Ratio Differential Diagrams', 6, 0)
# (5399, 'Art Theory Text with Line Drawings', 6, 0)
# (5401, 'Art Theory Text with Sketches', 6, 0)
# (5402, 'Study for “’Art Digest’ Cover”', 8, 0)
# (5403, 'Ornaments, Lithograph Sketch', 5, 0)
# (5404, 'Lithograph Sketch', 6, 0)
# (5405, "Study for “Study after 'Landscape with Garage Lights’”", 8, 0)
# (5406, 'Study for “Arboretum by Flashbulb”', 9, 0)
# (5407, 'Study for “Ursine Park”', 7, 0)
# (5408, 'Study for "Ursine Park"', 9, 0)
# (5409, 'Study for "Ursine Park"', 8, 0)
# (5410, 'Study for “Ursine Park”', 6, 0)
# (5411, 'Study for “Ursine Park”', 7, 0)
# (5412, 'Art Theory Text with Color Diagram', 5, 0)
# (5413, 'Art Theory Text with Diagram', 4, 0)
# (5414, 'Art Theory Text with Maximum Ratio Differential Diagrams', 4, 0)
# (5415, 'Art Theory Text with Maximum Ratio Differential Sketch', 3, 0)
# (5416, 'Study for “Untitled (Black and White Variation on ‘Windshield Mirror’)”', 4, 0)
# (5417, 'Art Theory Text with Diagrams', 6, 0)
# (5418, 'Art Theory Text with Diagrams', 5, 0)
# (5419, 'Study for “Tournos”', 5, 0)
# (5420, 'Study for “Midi”', 5, 0)
# (5421, 'Color Diagram', 3, 0)
# (5422, 'Color Diagram', 3, 0)
# (5423, 'Study for “Deuce”', 4, 0)
# (5424, 'Study for “The Outside”', 5, 0)
# (5425, 'Study for “Ursine Park”', 5, 0)
# (5426, 'Art Theory Text with Sketch', 3, 0)
# (5427, 'Art Theory Text with Star and Gesture Sketch', 5, 0)
# (5428, 'Study for “Cliché” and “Ready-to-Wear”', 6, 0)
# (5429, 'Art Theory Text with Maximum Ratio Differential Diagrams', 5, 0)
# (5430, 'Art Theory Text with Diagrams', 6, 0)
# (5431, 'Study of “Salt Shaker”', 5, 0)
# (5432, 'Art Theory Text with Maximum Ratio Differential Diagrams', 6, 0)
# (5433, 'Art Theory Text with Wet Paint Figure Sketch', 8, 0)
# (5437, 'Art Theory Text with Diagram', 3, 0)
# (5439, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea - Subtropical garden.', 5, 0)
# (5440, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea - Formal flower garden in park.', 2, 0)
# (5441, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea - Park Bowling Green.', 5, 0)
# (5442, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Disused burial ground made into small park.', 6, 0)
# (5443, 'Recreation, Parks and Playgrounds: Great Britain, Scotland. Glasgow. Public Park: Social Conditions in Glasgow, Scotland, 1903: Public Park.', 6, 0)
# (5444, 'Recreation, Parks and Playgrounds: United States. New York. New York City. Bronx Park, Vacation Playground: New York City Public Schools. Examples of the Adaptation of Education to Special City Needs: Vacation- Playgrounds. Bronx-Park. Public School 105, Manhattan.', 8, 0)
# (5445, 'Recreation, Parks and Playgrounds: United States. New York. New York City. Bronx Park, Vacation Playground: New York City Public Schools. Examples of the Adaptation of Education to Special City Needs: Vacation- Playgrounds. Bronx-Park. Public School 105, Manhattan.', 7, 0)
# (5446, 'Art Theory Text with Sketch', 7, 0)
# (5447, 'Sketch', 5, 0)
# (5448, 'Color Diagram for “Composition Concrete”', 6, 0)
# (5452, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea - Public park tennis courts.', 3, 0)
# (5453, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea - Cricket pitching in park.', 6, 0)
# (5454, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea - Park Lake.', 6, 0)
# (5455, 'Recreation, Parks and Playgrounds: Great Britain, Scotland. Glasgow. Public Park: Social Conditions in Glasgow, Scotland, 1903: Public Park - Flower decoration.', 10, 0)
# (5456, 'Recreation, Parks and Playgrounds: Great Britain, Scotland. Glasgow. Public Park: Social Conditions in Glasgow, Scotland, 1903: Park - Conservatories.', 7, 0)
# (5458, 'Recreation, Parks and Playgrounds: United States. Massachusetts. Cambridge: Playgrounds. Cambridge, Massachusetts: Competitive games, drills, dances and races in which children of all Cambridge playgrounds took part. First Municipal Play Festival, Russell Field, 1914.', 6, 0)
# (5459, 'Recreation, Parks and Playgrounds: United States. Massachusetts. Cambridge: Playgrounds. Cambridge, Massachusetts: Competitive games, drills, dances and races in which children of all Cambridge playgrounds took part. First Municipal Play Festival, Russell Field, 1914.', 6, 0)
# (5460, 'Wet Figure Sketch', 8, 0)
# (5461, 'Sketch', 6, 0)
# (5462, 'The Width', 7, 0)
# (5463, 'Art Theory Text with Diagram', 6, 0)
# (5464, 'Art Theory Text with Sketch', 8, 0)
# (5468, 'Races, Immigration: United States. New York. New York City. Immigrant Station: Regulation of Immigration at the Port of Entry. United States Immigration Station, New York City: Excluded men.', 7, 0)
# (5469, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro. Development of Social Standards Among the Negroes. Hampton Normal and Agricultural Institute, Hampton, Va.: Arithmetic Class measuring brick.', 7, 0)
# (5470, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro. Development of Social Standards Among the Negroes. Hampton Normal and Agricultural Institute, Hampton, Va.', 10, 0)
# (5471, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro. Training for Commercial and Industrial Employment. Hampton Normal and Agricultural Institute, Hampton, Va.: Mattress Making.', 7, 0)
# (5472, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro: Training for Commercial and Industrial Employment. Hampton Normal and Agricultural Institute, Hampton, Va.: Cow Barn at Shellbanks Farm.', 7, 0)
# (5473, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro. Hampton Normal and Agricultural Institute, Hampton, Va.: A Meal in an Old Cabin.', 8, 0)
# (5476, 'Sketch', 7, 0)
# (5477, 'Sketch', 7, 0)
# (5478, 'Study for "Package Deal"', 7, 0)
# (5479, 'Sketch', 6, 0)
# (5480, 'Sketch', 6, 0)
# (5481, 'Calculations and Sketches', 4, 0)
# (5482, 'Study for “Package Deal”', 9, 0)
# (5483, 'Art Theory Text with Diagonal Diagram', 6, 0)
# (5484, 'X Study', 8, 0)
# (5485, 'Study for "Package Deal"', 6, 0)
# (5486, 'Sketch', 8, 0)
# (5487, 'Study for “Package Deal”', 5, 0)
# (5488, 'Text with Sketch', 6, 0)
# (5493, 'Cafe Interior', 6, 0)
# (5494, 'Head of Balzac', 9, 0)
# (5495, 'Hercules with the Lion Skin', 9, 0)
# (5496, 'Bathing Venus', 10, 0)
# (5497, 'Hercules and the Nemean Lion', 9, 0)
# (5498, 'Untitled', 1, 0)
# (5499, 'Layered Peaks and Towering Pines Overlook Distant Paddy Fields, from the series "Sacrifice"', 10, 0)
# (5500, 'Mountain Dwelling, Majestic View, from the series "Sacrifice"', 9, 0)
# (5501, 'Myriad Peaks, from the series "Sacrifice"', 9, 0)
# (5502, 'Viewing the Mountain Gorge from a Balustraded Terrace, from the series "Sacrifice"', 9, 0)
# (5503, '"You hitched up the wrong horse when you thought that farmers cant fight Adolf. Farmer are used to fighting"', 7, 0)
# (5506, 'Postcard', 8, 0)
# (5507, 'Postcard', 8, 0)
# (5508, 'Postcard', 7, 0)
# (5509, 'Postcard', 5, 0)
# (5510, 'Postcard', 7, 0)
# (5511, 'Postcard', 7, 0)
# (5512, 'Postcard', 8, 0)
# (5513, 'Postcard', 6, 0)
# (5514, 'Postcard', 7, 0)
# (5515, 'Yes! he is dead on the line; Stranger on the Shore [Danish]; Stranger on the Shore [English], from the portfolio "Hommage à Arthur Köpcke"', 5, 0)
# (5516, 'Yes! he is dead on the line; Stranger on the Shore [Danish]; Stranger on the Shore [English], from the portfolio "Hommage à Arthur Köpcke"', 4, 0)
# (5517, "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Common Sense in Preserving Good Health: Business Men's Club: Boston Young Men's Christian Association", 10, 0)
# (5518, 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The Education Bill: Massachusetts Civic League, Inc.', 8, 0)
# (5519, 'Aeolus and the Winds', 9, 0)
# (5520, 'Great Britain and Russia in Confrontation over the City of Herat, Afghanistan ("The Fight\'s Off--(For the Present)")', 10, 0)
# (5521, "Medal Commemorating the Destruction of the Duke of Alba's Statue", 9, 0)
# (5522, 'Untitled ["Suicide Notes"]', 10, 0)
# (5523, '1995-2000', 10, 0)
# (5524, 'Mountains Towering over Rural Village and Paddy fields, from the series "Sacrifice"', 9, 0)
# (5525, 'Layered Peaks, Enveloping Mists, from the series "Sacrifice"', 9, 0)
# (5526, '"We didn\'t like the way you took on about races and..... Four years ago"', 8, 0)
# (5527, '"Every time an Iowa hog puts on another pound  that pounds against you against you and all your works because... "', 5, 0)
# (5528, '"Every time a hen lays an egg that eggs against you"', 5, 0)
# (5529, "L'Espagne assassinée from Solidarité", 5, 0)
# (5530, 'Rodeo', 9, 0)
# (5533, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Battersea - Park Roadway.', 6, 0)
# (5534, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Disused burial ground made into small park.', 7, 0)
# (5535, 'Recreation, Parks and Playgrounds: Great Britain, England. London. Playgrounds and Parks: Social Conditions in London, England, 1903: Disused burial ground made into small park.', 6, 0)
# (5536, 'Art Theory Text with Stars and Sketch', 7, 0)
# (5537, 'Art Theory Text with Sketch', 5, 0)
# (5538, 'Study for “Composition Concrete”', 5, 0)
# (5539, 'Art Theory Text with Sketches', 6, 0)
# (5540, 'Sketch', 6, 0)
# (5541, 'Preliminary Study for “Columbia Records Album Cover”', 7, 0)
# (5546, 'Galeriae Farnesianae', 6, 0)
# (5547, 'Day and Dream', 7, 0)
# (5548, 'Portrait:  Jacopo Bassano', 9, 0)
# (5550, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 9, 0)
# (5551, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 10, 0)
# (5552, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 10, 0)
# (5553, 'Tetradrachm from Himera, Sicily', 5, 0)
# (5554, 'Untitled (details of Ben Shahn’s Jersey Homestead Mural and images of a child)', 10, 0)
# (5555, 'Coin of Nicopolis under Augustus', 1, 0)
# (5556, 'Father Duffy, Times Square', 10, 0)
# (5557, 'Untitled (house interior)', 6, 0)
# (5558, 'Untitled', 10, 0)
# (5559, 'Untitled', 8, 0)
# (5560, 'Merce Cunningham', 9, 0)
# (5561, 'Untitled, Memphis', 10, 0)
# (5562, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro: Development of Social Standards Among the Negroes. Hampton Normal and Agricultural Institute, Hampton, Va.: Geography - Local Industry.', 6, 0)
# (5563, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro: Development of Social Standards Among the Negroes. Hampton Normal and Agricultural Institute, Hampton, Va.', 9, 0)
# (5564, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro: Hampton Normal and Agricultural Institute, Hampton, Va.: Class in Drawing.', 7, 0)
# (5565, 'Races, Negroes: United States. Virginia. Hampton. Hampton Normal and Industrial School: Agencies Promoting Assimilation of the Negro. Training for Commercial and Industrial Employment. Hampton Normal and Agricultural Institute, Hampton, Va.', 10, 0)
# (5567, 'Study for “Egg Beater No. 4”', 7, 0)
# (5568, 'Study for “Egg Beater No. 4”', 10, 0)
# (5569, 'Study for “The Mellow Pad”', 7, 0)
# (5570, 'Study for “The Mellow Pad”', 10, 0)
# ...
# (352849, 'China-marker', 5, 0)
# (352850, 'Hanging hardware', 7, 0)
# (352852, 'Bone folder', 3, 0)
# (352853, 'Ruler', 5, 0)
# (352862, 'Ink eraser', 10, 0)
# (352863, 'China-marker', 9, 0)
# (352864, 'Illuminated Slide Sorter', 9, 0)
# (352865, 'Hanging hardware', 7, 0)
# (352866, 'Metal box of slides', 6, 0)
# (352867, 'Ruler', 5, 0)
# (352868, 'Ruler', 7, 0)
# (352870, 'Bounce flash gun', 10, 0)
# (352871, 'Angle blow brush', 10, 0)
# (352872, 'Original box for angle blow brush', 10, 0)
# (352873, 'Empty box for cut film holder', 10, 0)
# (352874, 'Camera sunshade', 9, 0)
# (352875, 'Ground glass adapter', 10, 0)
# (352876, 'Film cutter', 10, 0)
# (352877, 'Camera pistol grip', 10, 0)
# (352878, 'Roll film magazine', 8, 0)
# (352879, 'Magnifying hood', 6, 0)
# (352880, 'Cut film adapter', 10, 0)
# (352881, 'Tape measure', 6, 0)
# (352884, 'Large pipette', 8, 0)
# (352887, 'Box for magnifying hood', 10, 0)
# (352903, 'Leather camera case and camera release cables', 10, 0)
# (352907, 'Exposure meter', 10, 0)
# (352910, 'Film backs in paper envelope', 10, 0)
# (352979, 'Box of staples', 10, 0)
# (352985, 'Egg separator', 10, 0)
# (352989, 'Knife handle', 10, 0)
# (352990, 'Box for "Comet Keen-Edge Knife"', 10, 0)
# (352991, 'Magnetic wand', 10, 0)
# (352992, 'Allway Saw', 8, 0)
# (352994, 'Blue towel', 9, 0)
# (352995, 'Tinsnips', 8, 0)
# (353004, 'Burnisher or eraser', 5, 0)
# (353005, 'Empty box for camera lens', 10, 0)
# (353006, 'Unexposed film', 10, 0)
# (353007, 'Slide viewer', 10, 0)
# (353008, 'Slide viewer', 10, 0)
# (353013, 'Paint roller', 10, 0)
# (353014, 'Paint roller', 10, 0)
# (353015, 'Paint roller', 10, 0)
# (353016, 'Paint roller', 10, 0)
# (353017, 'Paint roller', 8, 0)
# (353018, 'Paint roller', 8, 0)
# (353019, 'Paint roller', 10, 0)
# (353020, 'Paint roller', 6, 0)
# (353021, 'Paint roller', 9, 0)
# (353022, 'Paint roller', 10, 0)
# (353023, 'Paint roller', 10, 0)
# (353024, 'Paint roller', 9, 0)
# (353025, 'Paint roller', 10, 0)
# (353026, 'Paint roller', 8, 0)
# (353027, 'Paint roller', 8, 0)
# (353028, 'Paint roller', 9, 0)
# (353029, 'Paint roller', 6, 0)
# (353030, 'Paint roller', 8, 0)
# (353031, 'Paint roller', 9, 0)
# (353032, 'Saw wrapped in a paper map', 10, 0)
# (353033, 'Jack', 6, 0)
# (353034, 'Jack handle', 7, 0)
# (353035, 'L-square\r\n', 7, 0)
# (353037, 'Magnet on threaded rod', 8, 0)
# (353038, 'Spray can hoses', 10, 0)
# (353039, 'Yard stick', 7, 0)
# (353040, 'Large squeegee', 9, 0)
# (353041, 'Trim guard', 8, 0)
# (353042, 'Paint roller frame', 10, 0)
# (353043, 'Paint roller frame', 10, 0)
# (353044, 'Paint roller frame', 10, 0)
# (353341, 'Miter box', 10, 0)
# (353359, 'Hanging hardware', 9, 0)
# (353360, 'Hanging hardware', 6, 0)
# (353361, 'Hanging hardware', 7, 0)
# (353425, 'Lug wrench', 7, 0)
# (353426, 'Ratchet screwdriver', 10, 0)
# (353502, 'Folding wooden ruler', 10, 0)
# (353503, 'Folding wooden ruler', 9, 0)
# (353504, 'Small hammer', 8, 0)
# (353505, 'Ruler', 7, 0)
# (353506, 'Ruler', 7, 0)
# (353507, 'Ruler', 4, 0)
# (353510, 'Clear tape', 10, 0)
# (353514, 'Lug wrench', 7, 0)
# (353517, 'Crow bar', 7, 0)
# (353601, 'Staple remover', 6, 0)
# (353602, 'Finger guard', 8, 0)
# (353603, 'Wrench', 7, 0)
# (353604, 'Screwdriver', 9, 0)
# (353606, 'Tape measure', 5, 0)
# (353607, 'Tape measure', 10, 0)
# (353608, 'Tape measure', 5, 0)
# (353609, 'Tape measure', 4, 0)
# (353610, 'Tape measure', 10, 0)
# (353611, 'Hammer head', 8, 0)
# (353612, 'Tape measure', 5, 0)
# (353613, 'Tape measure', 8, 0)
# (353614, 'Wood screws', 10, 0)
# (353615, 'Wood screws', 10, 0)
# (353616, 'Metal pulley', 10, 0)
# (353617, 'Metal pulley', 9, 0)
# (353618, 'Tweezers', 5, 0)
# (353619, 'Tweezers', 6, 0)
# (353620, 'Tweezers', 3, 0)
# (353621, 'Tweezers', 4, 0)
# (353622, 'Tweezers', 4, 0)
# (353623, 'Tweezers', 6, 0)
# (353624, 'Tweezers', 4, 0)
# (353625, 'Tweezers', 4, 0)
# (353626, 'Tweezers', 5, 0)
# (353627, 'Tweezers', 4, 0)
# (353628, 'Tweezers', 4, 0)
# (353629, 'Tweezers', 4, 0)
# (353630, 'Tweezers', 3, 0)
# (353631, 'Tweezers', 4, 0)
# (353632, 'Tweezers', 4, 0)
# (353633, 'Tweezers', 5, 0)
# (353634, 'Tweezers', 4, 0)
# (353635, 'Tweezers', 5, 0)
# (353636, 'Tweezers', 4, 0)
# (353637, 'Tweezers', 4, 0)
# (353638, 'Tweezers', 6, 0)
# (353639, 'Tweezers', 2, 0)
# (353640, 'Tweezers', 5, 0)
# (353641, 'Tweezers', 4, 0)
# (353642, 'Tweezers', 7, 0)
# (353643, 'Tweezers', 3, 0)
# (353644, 'Tweezers', 4, 0)
# (353645, 'Tweezers', 3, 0)
# (353646, 'Tweezers', 4, 0)
# (353647, 'Tweezers', 4, 0)
# (353648, 'Tweezers', 2, 0)
# (353852, 'Box for Hasselblad 500 C camera', 8, 0)
# (353853, 'Cardboard sleeve with Hasselblad 500 C sticker and handwritten notations', 10, 0)
# (353854, 'Slide box with empty slide holders', 10, 0)
# (353855, 'Slide box with empty slide holders', 10, 0)
# (353856, 'Slide box with empty slide holders', 10, 0)
# (353857, 'Slide box with empty slide holders', 10, 0)
# (353858, 'Lens hood', 10, 0)
# (353859, 'Lens filter', 10, 0)
# (353860, 'Empty box for lens filter', 10, 0)
# (353861, 'Lens and lens case', 4, 0)
# (353862, 'Emtpy leather lens case', 10, 0)
# (353863, 'Fragment from leather lens case', 10, 0)
# (353864, 'Lens in leather case', 9, 0)
# (353874, 'Lens in leather case', 7, 0)
# (353875, 'Lens brush and lens cleaning cloths', 10, 0)
# (353876, 'Brown leather bag with strap', 9, 0)
# (353877, 'Light meter', 4, 0)
# (353878, 'Empty box for lens filter', 10, 0)
# (353879, 'Flashbulb', 10, 0)
# (353880, 'Color movie film', 10, 0)
# (353881, 'Color movie film', 10, 0)
# (353882, 'Lens Paper', 10, 0)
# (354646, 'Protractor', 4, 0)
# (354648, 'Compass', 6, 0)
# (354670, 'Box for Personalized embosser', 10, 0)
# (354709, 'Protractor / stencil', 7, 0)
# (354919, 'Glass eye dropper', 6, 0)
# (354920, 'Glass eye dropper', 7, 0)
# (354921, 'Glass eye dropper', 7, 0)
# (354922, 'Glass eye dropper', 7, 0)
# (354923, 'Glass eye dropper', 6, 0)
# (354924, 'Glass eye dropper', 8, 0)
# (354925, 'Glass eye dropper', 7, 0)
# (354926, 'Glass eye dropper', 7, 0)
# (354927, 'Glass eye dropper', 6, 0)
# (354928, 'Glass eye dropper', 8, 0)
# (354929, 'Glass eye dropper', 7, 0)
# (354930, 'Glass eye dropper', 6, 0)
# (354931, 'Glass eye dropper', 6, 0)
# (354932, 'Glass eye dropper', 7, 0)
# (354933, 'Glass eye dropper', 6, 0)
# (354934, 'Glass eye dropper', 6, 0)
# (354935, 'Glass eye dropper', 6, 0)
# (355038, 'Black crayon', 10, 0)
# (355039, 'Red crayon', 10, 0)
# (355040, 'China-marker', 10, 0)
# (355222, 'Cover for jack lift', 7, 0)
# (355235, 'Rubber stamp', 10, 0)
# (355236, 'Rubber stamp', 10, 0)
# (355237, 'Rubber stamp', 10, 0)
# (355238, 'Rubber stamp', 10, 0)
# (355239, 'Rubber stamp', 10, 0)
# (355240, 'Rubber stamp', 10, 0)
# (355241, 'Rubber stamp', 10, 0)
# (355259, 'Small metal shovel', 10, 0)
# (355261, '35 mm negative file pack\r\n', 10, 0)
# (355262, 'Black and white film\r\n', 10, 0)
# (355266, 'Faux leather strap', 9, 0)
# (355268, 'Empty box for lens adapter', 10, 0)
# (355269, 'Lens filter', 10, 0)
# (355270, 'Lens filter', 10, 0)
# (355271, 'Color movie film', 10, 0)
# (355272, 'Normal Bent Flash Bar', 10, 0)
# (355273, 'Faux leather strap', 10, 0)
# (355353, 'Unexposed film', 10, 0)
# (355354, 'Unexposed film', 10, 0)
# (355355, 'Unexposed film', 10, 0)
# (355356, 'Unexposed film', 10, 0)
# (355357, 'Unexposed film', 10, 0)
# (355358, 'Unexposed film', 10, 0)
# (355359, 'Unexposed film', 10, 0)
# (355360, 'Unexposed film', 10, 0)
# (355361, 'Unexposed film', 10, 0)
# (355362, 'Camera lens filter', 10, 0)
# (355363, 'Camera lens filter', 10, 0)
# (355364, 'Camera lens filter', 8, 0)
# (355365, 'Camera lens filter', 6, 0)
# (355366, 'Box for lens filter', 10, 0)
# (355367, 'Package for turntable stylus', 10, 0)
# (355368, 'Lens cap', 4, 0)
# (355369, 'Faux leather strap', 8, 0)
# (355370, 'Camera release cable', 7, 0)
# (355373, 'Handheld air pump', 9, 0)
# (355406, 'Lens tissue', 10, 0)
# (355408, 'Quick focus handle', 7, 0)
# (355409, 'Lens hood', 5, 0)
# (355410, 'Tripod mount', 8, 0)
# (355411, 'Lens shade mask', 6, 0)
# (355412, 'Refillable film canister', 8, 0)
# (355413, 'Flashlight battery', 10, 0)
# (355414, 'Polaroid Print Coater', 8, 0)
# (355415, 'Cardboard slide box containing 1972 Tate Gallery label', 10, 0)
# (355416, 'Four flashbulbs', 10, 0)
# (355417, 'Lens cover', 4, 0)
# (355418, 'Lens cover', 3, 0)
# (355419, 'Slide tray lid', 10, 0)
# (355420, 'Original container for "Polaroid Print Coater"', 8, 0)
# (355421, 'Empty slide mount', 4, 0)
# (355422, 'Empty slide mount', 6, 0)
# (355423, 'Empty slide mount', 5, 0)
# (355424, 'Empty slide mount', 7, 0)
# (355425, 'Empty slide mount', 4, 0)
# (355426, 'Empty slide mount', 5, 0)
# (355427, 'Unused title slide', 6, 0)
# (355428, 'Metal handle or stand', 4, 0)
# (355429, 'Empty slide package', 8, 0)
# (355430, 'Unused title slide', 6, 0)
# (355431, 'Unused title slide', 7, 0)
# (355432, 'Unused title slide', 6, 0)
# (355433, 'Metal handle or stand', 5, 0)
# (356001, 'Painted canvas fragment\r\n', 10, 0)
# (356002, 'Painted canvas fragment', 10, 0)
# (356003, 'Painted canvas fragment', 10, 0)
# (356004, 'Painted canvas fragment', 10, 0)
# (356005, 'Painted canvas fragment', 10, 0)
# (356006, 'Painted canvas fragment', 9, 0)
# (356007, 'Painted canvas fragment', 10, 0)
# (356008, 'Painted canvas fragment', 6, 0)
# (356009, 'Painted canvas fragment', 10, 0)
# (356010, 'Painted canvas fragment', 10, 0)
# (356011, 'Painted canvas fragment', 10, 0)
# (356012, 'Painted canvas fragment', 10, 0)
# (356013, 'Painted canvas fragment', 10, 0)
# (356014, 'Painted canvas fragment', 10, 0)
# (356015, 'Painted canvas fragment', 10, 0)
# (356016, 'Painted canvas fragment', 10, 0)
# (356017, 'Painted canvas fragment', 10, 0)
# (356018, 'Painted canvas fragment', 5, 0)
# (356019, 'Painted canvas fragment', 8, 0)
# (356020, 'Painted canvas fragment', 10, 0)
# (356021, 'Painted canvas fragment', 10, 0)
# (356022, 'Painted canvas fragment', 10, 0)
# (356023, 'Painted canvas fragment', 9, 0)
# (356024, 'Painted canvas fragment', 10, 0)
# (356025, 'Painted canvas fragment', 10, 0)
# (356026, 'Painted canvas fragment', 9, 0)
# (356027, 'Painted canvas fragment', 10, 0)
# (356028, 'Painted canvas fragment', 9, 0)
# (356029, 'Painted canvas fragment', 10, 0)
# (356030, 'Painted canvas fragment', 10, 0)
# (356031, 'Painted canvas fragment', 10, 0)
# (356032, 'Painted canvas fragment', 8, 0)
# (356033, 'Painted canvas fragment', 10, 0)
# (356034, 'Painted canvas fragment', 10, 0)
# (356035, 'Painted canvas fragment', 10, 0)
# (356036, 'Painted canvas fragment', 10, 0)
# (356037, 'Painted canvas fragment', 10, 0)
# (356038, 'Painted canvas fragment', 10, 0)
# (356039, 'Painted canvas fragment', 9, 0)
# (356040, 'Painted canvas fragment', 10, 0)
# (356041, 'Painted canvas fragment', 10, 0)
# (356042, 'Painted canvas fragment', 9, 0)
# (356043, 'Painted canvas fragment', 6, 0)
# (356044, 'Painted canvas fragment', 6, 0)
# (356045, 'Painted canvas fragment', 7, 0)
# (356046, 'Painted canvas fragment', 10, 0)
# (356047, 'Painted canvas fragment', 9, 0)
# (356048, 'Painted canvas fragment', 10, 0)
# (356049, 'Painted canvas fragment', 10, 0)
# (356050, 'Painted canvas fragment', 9, 0)
# (356051, 'Painted canvas fragment', 9, 0)
# (356052, 'Painted canvas fragment', 7, 0)
# (356053, 'Painted canvas fragment', 10, 0)
# (356054, 'Painted canvas fragment', 10, 0)
# (356055, 'Painted canvas fragment\r\n', 5, 0)
# (356056, 'Painted canvas fragment\r\n', 9, 0)
# (356057, 'Painted canvas fragment\r\n', 10, 0)
# (356058, 'Painted canvas fragment\r\n', 10, 0)
# (356059, 'Painted canvas fragment\r\n', 10, 0)
# (356060, 'Painted canvas fragment\r\n', 10, 0)
# (356061, 'Painted canvas fragment\r\n', 8, 0)
# (356062, 'Painted canvas fragment\r\n', 10, 0)
# (356063, 'Painted canvas fragment\r\n', 6, 0)
# (356064, 'Painted canvas fragment\r\n', 10, 0)
# (356065, 'Painted canvas fragment\r\n', 10, 0)
# (356066, 'Painted canvas fragment\r\n', 9, 0)
# (356067, 'Painted canvas fragment\r\n', 10, 0)
# (356068, 'Painted canvas fragment', 10, 0)
# (356069, 'Painted canvas fragment\r\n', 10, 0)
# (356070, 'Painted canvas fragment\r\n', 9, 0)
# (356071, 'Painted canvas fragment\r\n', 10, 0)
# (356072, 'Painted canvas fragment\r\n', 7, 0)
# (356073, 'Painted canvas fragment\r\n', 10, 0)
# (356074, 'Painted canvas fragment\r\n', 9, 0)
# (356075, 'Painted canvas fragment\r\n', 7, 0)
# (356076, 'Painted canvas fragment\r\n', 10, 0)
# (356077, 'Painted canvas fragment\r\n', 10, 0)
# (356078, 'Painted canvas fragment\r\n', 10, 0)
# (356079, 'Painted canvas fragment\r\n', 10, 0)
# (356080, 'Painted canvas fragment\r\n', 8, 0)
# (356081, 'Painted canvas fragment\r\n', 6, 0)
# (356082, 'Painted canvas fragment\r\n', 9, 0)
# (356083, 'Painted canvas fragment\r\n', 10, 0)
# (356084, 'Painted canvas fragment\r\n', 8, 0)
# (356085, 'Painted canvas fragment\r\n', 10, 0)
# (356086, 'Painted canvas fragment\r\n', 10, 0)
# (356087, 'Painted canvas fragment\r\n', 10, 0)
# (356088, 'Painted canvas fragment\r\n', 10, 0)
# (356089, 'Painted canvas fragment\r\n', 8, 0)
# (356090, 'Painted canvas fragment', 10, 0)
# (356091, 'Painted canvas fragment\r\n', 9, 0)
# (356092, 'Painted canvas fragment\r\n', 7, 0)
# (356093, 'Painted canvas fragment\r\n', 9, 0)
# (356094, 'Painted canvas fragment\r\n', 9, 0)
# (356095, 'Painted canvas fragment\r\n', 9, 0)
# (356096, 'Painted canvas fragment\r\n', 10, 0)
# (356097, 'Painted canvas fragment\r\n', 9, 0)
# (356098, 'Painted canvas fragment\r\n', 7, 0)
# (356099, 'Painted canvas fragment', 10, 0)
# (356100, 'Painted canvas fragment', 10, 0)
# (356101, 'Painted canvas fragment', 10, 0)
# (356102, 'Painted canvas fragment', 9, 0)
# (356103, 'Painted canvas fragment', 9, 0)
# (356104, 'Painted canvas fragment', 7, 0)
# (356105, 'Painted canvas fragment', 10, 0)
# (356106, 'Painted canvas fragment', 10, 0)
# (356107, 'Painted canvas fragment', 8, 0)
# (356108, 'Painted canvas fragment', 7, 0)
# (356109, 'Painted canvas fragment', 10, 0)
# (356110, 'Painted canvas fragment', 9, 0)
# (356111, 'Painted canvas fragment', 8, 0)
# (356112, 'Painted canvas fragment', 10, 0)
# (356113, 'Painted canvas fragment', 7, 0)
# (356114, 'Painted canvas fragment', 7, 0)
# (356115, 'Painted canvas fragment', 4, 0)
# (356116, 'Painted canvas fragment', 5, 0)
# (356117, 'Painted canvas fragment', 10, 0)
# (356118, 'Painted canvas fragment', 7, 0)
# (356119, 'Painted canvas fragment', 5, 0)
# (356120, 'Painted canvas fragment', 10, 0)
# (356121, 'Painted canvas fragment', 6, 0)
# (356122, 'Painted canvas fragment', 10, 0)
# (356123, 'Painted canvas fragment', 9, 0)
# (356124, 'Painted canvas fragment', 5, 0)
# (356125, 'Painted canvas fragment', 10, 0)
# (356126, 'Painted canvas fragment', 10, 0)
# (356127, 'Painted canvas fragment', 7, 0)
# (356128, 'Painted canvas fragment', 10, 0)
# (356129, 'Painted canvas fragment', 8, 0)
# (356130, 'Painted canvas fragment', 10, 0)
# (356131, 'Painted canvas fragment', 10, 0)
# (356132, 'Painted canvas fragment', 7, 0)
# (356133, 'Painted canvas fragment', 6, 0)
# (356134, 'Painted canvas fragment', 6, 0)
# (356135, 'Painted canvas fragment', 8, 0)
# (356136, 'Painted canvas fragment', 8, 0)
# (356137, 'Painted canvas fragment', 7, 0)
# (356138, 'Painted canvas fragment', 7, 0)
# (356139, 'Painted canvas fragment', 10, 0)
# (356140, 'Painted canvas fragment', 10, 0)
# (356141, 'Painted canvas fragment', 10, 0)
# (356142, 'Painted canvas fragment', 10, 0)
# (356143, 'Painted canvas fragment', 7, 0)
# (356144, 'Painted canvas fragment', 8, 0)
# (356145, 'Painted canvas fragment', 10, 0)
# (356146, 'Painted canvas fragment', 10, 0)
# (356147, 'Painted canvas fragment', 10, 0)
# (356148, 'Painted canvas fragment', 10, 0)
# (356149, 'Painted canvas fragment', 10, 0)
# (356150, 'Painted canvas fragment', 7, 0)
# (356151, 'Canvas fragment', 6, 0)
# (356152, 'Canvas fragment', 7, 0)
# (356153, 'Canvas fragment', 5, 0)
# (356154, 'Canvas fragment', 6, 0)
# (356155, 'Canvas fragment', 9, 0)
# (356156, 'Canvas fragment', 7, 0)
# (356157, 'Canvas fragment', 7, 0)
# (356158, 'Canvas fragment', 7, 0)
# (356159, 'Canvas fragment', 6, 0)
# (356160, 'Canvas fragment', 7, 0)
# (356161, 'Canvas fragment', 5, 0)
# (356162, 'Canvas fragment', 5, 0)
# (356163, 'Canvas fragment', 6, 0)
# (356164, 'Canvas fragment', 6, 0)
# (356165, 'Canvas fragment', 7, 0)
# (356166, 'Canvas fragment', 7, 0)
# (356167, 'Canvas fragment', 5, 0)
# (356168, 'Canvas fragment', 6, 0)
# (356169, 'Canvas fragment', 5, 0)
# (356170, 'Canvas fragment', 5, 0)
# (356171, 'Canvas fragment', 7, 0)
# (356172, 'Canvas fragment', 4, 0)
# (356173, 'Canvas fragment', 5, 0)
# (356174, 'Canvas fragment', 4, 0)
# (356175, 'Canvas fragment', 6, 0)
# (356176, 'Painted canvas strips', 10, 0)
# (356177, 'Canvas threads', 10, 0)

# %%
#9. List all artifacts created between 1500 and 1600
query = """
SELECT m.objectid, d.title, m.datebegin, m.dateend
FROM artifact_media AS m
JOIN artifact_metadata AS d ON m.objectid = d.id
WHERE m.datebegin >= 1500 AND m.dateend <= 1600;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# (1424, 'The Parable of the Unjust Husbandmen', 1585, 1585)
# (1425, 'The Virgin and Joseph at the Inn', 1585, 1585)
# (1428, 'Battle Scene (painting, recto), folio fragment from a Bhagavata Purana series', 1535, 1545)
# (4605, 'Twelve Scenes from the Life of Christ (Emblemata Evangelica) plus title page', 1585, 1585)
# (4606, 'The Parable of the Rich Fool', 1585, 1585)
# (4607, 'The Plucking of Ears of Corn on Sabbath Day', 1585, 1585)
# (4608, 'The Parable of the Barren Fig Tree', 1585, 1585)
# (4620, 'The Parable of the Kingdom of Heaven', 1585, 1585)
# (4621, 'Titlepage', 1585, 1585)
# (4622, 'Christ and the Woman of Samaria', 1585, 1585)
# (4623, 'The Good Shepherd', 1585, 1585)
# (4624, 'Selection of 16th century prints', 1535, 1577)
# (4633, 'The Angel Telling Joseph to Flee and the Flight into Egypt', 1585, 1585)
# (4634, 'Jesus Calling the Apostles Among the Fishermen', 1585, 1585)
# (4635, 'The Parable of the Sower', 1585, 1585)
# (4636, 'The Parable of the Two Sons and the Unjust Husbandmen', 1585, 1585)
# (4637, 'Allegory of the Triumph of the Netherlands over Spain', 1600, 1600)
# (4858, 'The Cycle of Vicissitudes of Human Affairs', 1564, 1564)
# (5307, 'Creation of Man', 1589, 1589)
# (5326, 'The Ptolemaic System', 1579, 1579)
# (5327, 'Lot and His Daughters', 1581, 1581)
# (5328, 'The Triumph of the World', 1564, 1564)
# (5521, "Medal Commemorating the Destruction of the Duke of Alba's Statue", 1574, 1577)
# (59445, 'Landscape with a Horseman and His Groom', 1555, 1565)
# (69925, 'Saint Peter Preaching to the Gentiles in Caesarea, St. Paul Preaching to the Jews at the Right, in the Background Moses Inviting the Sick and the Poor', 1575, 1584)
# (69926, 'The King Casting Out the Badly Dressed Guest, in the Background the Supper at Emmaus', 1575, 1584)
# (69927, 'The Diligent Worker United with Christ after Death', 1572, 1572)
# (69928, 'Labor and Diligence Enjoying Their Simple Meal', 1572, 1572)
# (69929, 'Sad Old Age', 1596, 1596)
# (69930, 'The Temple of Diana at Ephesus', 1572, 1572)
# (69950, 'The King Sending His Servants to Invite the Guests', 1575, 1584)
# (69951, 'Man Born to Toil', 1572, 1572)
# (69952, 'The Diligent Worker Aspiring to the Righteousness of the Lord', 1572, 1572)
# (69953, 'Johannes VIII, Paleologos', 1590, 1600)
# (69954, 'Honored Maturity', 1596, 1596)
# (69955, 'The Colosseum at Rome', 1572, 1572)
# (69962, 'The Marriage of Labor and Diligence', 1572, 1572)
# (69963, 'The Lord Endowing the Diligent Worker with Food and Clothing', 1572, 1572)
# (69964, 'The Pyramids of Egypt', 1572, 1572)
# (69965, 'The Walls of Babylon', 1572, 1572)
# (69992, 'The Statue of Jupiter at Olympia', 1572, 1572)
# (69993, 'The Mausoleum at Halicarnassus', 1572, 1572)
# (70322, 'The Age of Gold', 1585, 1595)
# (70323, 'The Age of Bronze', 1585, 1595)
# (70324, 'The Age of Iron', 1585, 1595)
# (70325, 'Amorous Adolescence', 1596, 1596)
# (70326, 'Industrious Youth', 1596, 1596)
# (70327, 'The Lighthouse at Alexandria', 1572, 1572)
# (70328, 'The Colossus of Rhodes', 1572, 1572)
# (70344, 'The Age of Silver', 1585, 1595)
# (70471, "'Meiping' Bottle with Stylized Lotus Decor", 1500, 1599)
# (70541, 'Chilon', 1596, 1596)
# (70554, 'Harpocrates', 1593, 1593)
# (70555, 'Apelles Painting the Portrait of Alexander the Great', 1582, 1582)

# %%
#10.How many artifacts have no media files?
query = """
SELECT COUNT(*) AS artifacts_without_media
FROM artifact_media
WHERE mediacount = 0 OR mediacount IS NULL;
"""

my_cursor.execute(query)
count = my_cursor.fetchone()[0]
print("Artifacts without media files:", count)
# Out:
# Artifacts without media files: 5000

# %% [markdown]
# QUERIES FOR artifact_colors Table:

# %%
#11. What are all the distinct hues used in the dataset?
query = """
SELECT DISTINCT hue
FROM artifact_colors
WHERE hue IS NOT NULL
ORDER BY hue;
"""

my_cursor.execute(query)
hues = [row[0] for row in my_cursor.fetchall()]
print("Distinct Hues:", hues)
# Out:
# Distinct Hues: ['Black', 'Blue', 'Brown', 'Green', 'Grey', 'Orange', 'Red', 'Violet', 'White', 'Yellow']

# %%
#12.What are the top 5 most used colors by frequency?
query = """
SELECT color, COUNT(*) AS frequency
FROM artifact_colors
WHERE color IS NOT NULL
GROUP BY color
ORDER BY frequency DESC
LIMIT 5;
"""

my_cursor.execute(query)
top_colors = my_cursor.fetchall()
for color, freq in top_colors:
    print(color, "-", freq)
# Out:
# #969696 - 998
# #7d7d7d - 995
# #646464 - 852
# #c8c8c8 - 794
# #afafaf - 764

# %%
#13.What is the average coverage percentage for each hue?
query = """
SELECT hue, AVG(percent) AS average_coverage
FROM artifact_colors
WHERE hue IS NOT NULL
GROUP BY hue
ORDER BY average_coverage DESC;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# ('Black', 0.19689442398564866)
# ('Yellow', 0.16459173156403054)
# ('Green', 0.1611653888348463)
# ('Orange', 0.15613334523532754)
# ('Grey', 0.1446368185309742)
# ('Brown', 0.11080604475602979)
# ('White', 0.10613466868843023)
# ('Red', 0.06665090029082066)
# ('Blue', 0.04568481610363174)
# ('Violet', 0.042391512570535785)

# %%
#14.List all colors used for a given artifact ID.
artifact_id = 12345

query = f"""
SELECT color, hue, percent, css3
FROM artifact_colors
WHERE objectid = '{artifact_id}';
"""

my_cursor.execute(query)
results = my_cursor.fetchall()

if results:
    for row in results:
        print(row)
else:
    print(f"No colors found for artifact ID {artifact_id}")
# Out:
# No colors found for artifact ID 12345

# %%
#15.What is the total number of color entries in the dataset?
query = "SELECT COUNT(*) AS total_color_entries FROM artifact_colors;"
my_cursor.execute(query)
count = my_cursor.fetchone()[0]
print("Total number of color entries:", count)
# Out:
# Total number of color entries: 17010

# %% [markdown]
# JOINS BASED QUERIES:

# %%
#16.List artifact titles and hues for all artifacts belonging to the Byzantine culture.
query = """
SELECT m.title, c.hue
FROM artifact_metadata AS m
JOIN artifact_colors AS c
    ON m.id = c.objectid
WHERE m.culture = 'Byzantine'
  AND c.hue IS NOT NULL
ORDER BY m.title;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# ('Saint Andrew and Scenes from his Life', 'Brown')
# ('Saint Andrew and Scenes from his Life', 'Brown')
# ('Saint Andrew and Scenes from his Life', 'Brown')
# ('Saint Andrew and Scenes from his Life', 'Brown')
# ('Saint Andrew and Scenes from his Life', 'Yellow')
# ('Saint Andrew and Scenes from his Life', 'Brown')
# ('Saint Andrew and Scenes from his Life', 'Yellow')
# ('Saint Andrew and Scenes from his Life', 'Brown')
# ('Saint Andrew and Scenes from his Life', 'Green')
# ('Saint Andrew and Scenes from his Life', 'Orange')

# %%
#17.List each artifact title with its associated hues.
query = """
SELECT m.title, c.hue
FROM artifact_metadata AS m
JOIN artifact_colors AS c
    ON m.id = c.objectid
WHERE c.hue IS NOT NULL
ORDER BY m.title;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# ('"And Gus Taubs boy over in the tank plan."', 'Green')
# ('"And Gus Taubs boy over in the tank plan."', 'Grey')
# ('"And Gus Taubs boy over in the tank plan."', 'Grey')
# ('"And Gus Taubs boy over in the tank plan."', 'Green')
# ('"And Gus Taubs boy over in the tank plan."', 'Green')
# ('"And Gus Taubs boy over in the tank plan."', 'Grey')
# ('"And Gus Taubs boy over in the tank plan."', 'Green')
# ('"And Russians shucks I cant  add em all up. I can’t even [Spring?] is against you Russian scene ?"', 'Yellow')
# ('"And Russians shucks I cant  add em all up. I can’t even [Spring?] is against you Russian scene ?"', 'Grey')
# ('"And Russians shucks I cant  add em all up. I can’t even [Spring?] is against you Russian scene ?"', 'Green')
# ('"And Russians shucks I cant  add em all up. I can’t even [Spring?] is against you Russian scene ?"', 'Grey')
# ('"And Russians shucks I cant  add em all up. I can’t even [Spring?] is against you Russian scene ?"', 'Grey')
# ('"Every time a hen lays an egg that eggs against you"', 'Grey')
# ('"Every time a hen lays an egg that eggs against you"', 'Green')
# ('"Every time a hen lays an egg that eggs against you"', 'Green')
# ('"Every time a hen lays an egg that eggs against you"', 'Green')
# ('"Every time a hen lays an egg that eggs against you"', 'Green')
# ('"Every time an Iowa hog puts on another pound  that pounds against you against you and all your works because... "', 'Grey')
# ('"Every time an Iowa hog puts on another pound  that pounds against you against you and all your works because... "', 'Green')
# ('"Every time an Iowa hog puts on another pound  that pounds against you against you and all your works because... "', 'Green')
# ('"Every time an Iowa hog puts on another pound  that pounds against you against you and all your works because... "', 'Green')
# ('"Every time an Iowa hog puts on another pound  that pounds against you against you and all your works because... "', 'Green')
# ('"Eye" Bead with Aqua and White Swirls', 'Grey')
# ('"Eye" Bead with Aqua and White Swirls', 'Blue')
# ('"Eye" Bead with Aqua and White Swirls', 'Blue')
# ('"Eye" Bead with Aqua and White Swirls', 'Grey')
# ('"Eye" Bead with Aqua and White Swirls', 'Grey')
# ('"Eye" Bead with Aqua and White Swirls', 'Grey')
# ('"Eye" Bead with Aqua and White Swirls', 'Grey')
# ('"Eye" Bead with Aqua and White Swirls', 'Grey')
# ('"Eye" Bead with Aqua and White Swirls', 'Grey')
# ('"Eye" Bead with Aqua and White Swirls', 'Green')
# ('"Food for all kinds of folks I\'ll never see who are fighting for our side. British children and British seamen. Chinese soldier most likely."', 'Yellow')
# ('"Food for all kinds of folks I\'ll never see who are fighting for our side. British children and British seamen. Chinese soldier most likely."', 'Grey')
# ('"Food for all kinds of folks I\'ll never see who are fighting for our side. British children and British seamen. Chinese soldier most likely."', 'Green')
# ('"Food for all kinds of folks I\'ll never see who are fighting for our side. British children and British seamen. Chinese soldier most likely."', 'Grey')
# ('"Food for all kinds of folks I\'ll never see who are fighting for our side. British children and British seamen. Chinese soldier most likely."', 'Grey')
# ('"Food for the men on ships and the men in planes. Food for Ed Summers boy on his destroyer"', 'Green')
# ('"Food for the men on ships and the men in planes. Food for Ed Summers boy on his destroyer"', 'Grey')
# ('"Food for the men on ships and the men in planes. Food for Ed Summers boy on his destroyer"', 'Grey')
# ('"Food for the men on ships and the men in planes. Food for Ed Summers boy on his destroyer"', 'Green')
# ('"Food for the men on ships and the men in planes. Food for Ed Summers boy on his destroyer"', 'Green')
# ('"Food for the men on ships and the men in planes. Food for Ed Summers boy on his destroyer"', 'Grey')
# ('"Food for the men on ships and the men in planes. Food for Ed Summers boy on his destroyer"', 'Green')
# ('"Nincompoopiana"', 'Brown')
# ('"Nincompoopiana"', 'Brown')
# ('"Nincompoopiana"', 'Yellow')
# ('"Nincompoopiana"', 'Brown')
# ('"Nincompoopiana"', 'Yellow')
# ('"Nincompoopiana"', 'Brown')
# ('"Nincompoopiana"', 'Green')
# ('"Nincompoopiana"', 'Green')
# ('"Pushing combine.Twelve hours a day."', 'Grey')
# ('"Pushing combine.Twelve hours a day."', 'Grey')
# ('"Pushing combine.Twelve hours a day."', 'Green')
# ('"Pushing combine.Twelve hours a day."', 'Grey')
# ('"Six million farms and over in this country last census."', 'Brown')
# ('"Six million farms and over in this country last census."', 'Grey')
# ('"Six million farms and over in this country last census."', 'Green')
# ('"Six million farms and over in this country last census."', 'Green')
# ('"Six million farms and over in this country last census."', 'Grey')
# ('"Six million farms and over in this country last census."', 'Green')
# ('"We didn\'t like the way you took on about races and..... Four years ago"', 'Blue')
# ('"We didn\'t like the way you took on about races and..... Four years ago"', 'Blue')
# ('"We didn\'t like the way you took on about races and..... Four years ago"', 'Grey')
# ('"We didn\'t like the way you took on about races and..... Four years ago"', 'Brown')
# ('"We didn\'t like the way you took on about races and..... Four years ago"', 'Grey')
# ('"We didn\'t like the way you took on about races and..... Four years ago"', 'Blue')
# ('"We didn\'t like the way you took on about races and..... Four years ago"', 'Grey')
# ('"We didn\'t like the way you took on about races and..... Four years ago"', 'Grey')
# ('"We\'ve Got Everything to Lose if You Win"', 'Grey')
# ('"We\'ve Got Everything to Lose if You Win"', 'Grey')
# ('"We\'ve Got Everything to Lose if You Win"', 'Green')
# ('"We\'ve Got Everything to Lose if You Win"', 'Grey')
# ('"You hitched up the wrong horse when you thought that farmers cant fight Adolf. Farmer are used to fighting"', 'Grey')
# ('"You hitched up the wrong horse when you thought that farmers cant fight Adolf. Farmer are used to fighting"', 'Grey')
# ('"You hitched up the wrong horse when you thought that farmers cant fight Adolf. Farmer are used to fighting"', 'Green')
# ('"You hitched up the wrong horse when you thought that farmers cant fight Adolf. Farmer are used to fighting"', 'Green')
# ('"You hitched up the wrong horse when you thought that farmers cant fight Adolf. Farmer are used to fighting"', 'Grey')
# ('"You hitched up the wrong horse when you thought that farmers cant fight Adolf. Farmer are used to fighting"', 'Green')
# ('"You hitched up the wrong horse when you thought that farmers cant fight Adolf. Farmer are used to fighting"', 'Green')
# ('"You see farmers don\'t talk much. Delano [pot?].The wind etc...."', 'Grey')
# ('"You see farmers don\'t talk much. Delano [pot?].The wind etc...."', 'Grey')
# ('"You see farmers don\'t talk much. Delano [pot?].The wind etc...."', 'Green')
# ('"You see farmers don\'t talk much. Delano [pot?].The wind etc...."', 'Green')
# ('"You see farmers don\'t talk much. Delano [pot?].The wind etc...."', 'Grey')
# ('"You see farmers don\'t talk much. Delano [pot?].The wind etc...."', 'Green')
# ('"You see farmers don\'t talk much. Delano [pot?].The wind etc...."', 'Green')
# ('#1, from Five Aquatints with Drypoint', 'Grey')
# ('#1, from Five Aquatints with Drypoint', 'Grey')
# ('#1, from Five Aquatints with Drypoint', 'Grey')
# ('#1, from Five Aquatints with Drypoint', 'Grey')
# ('#1, from Five Aquatints with Drypoint', 'Grey')
# ('#1, from Five Aquatints with Drypoint', 'Grey')
# ('#1, from Five Aquatints with Drypoint', 'Grey')
# ('#1, from Five Aquatints with Drypoint', 'Grey')
# ('#1, from Five Aquatints with Drypoint', 'Green')
# ('#2, from Five Aquatints with Drypoint', 'Grey')
# ('#2, from Five Aquatints with Drypoint', 'Green')
# ('#2, from Five Aquatints with Drypoint', 'Green')
# ('#2, from Five Aquatints with Drypoint', 'Yellow')
# ('#2, from Five Aquatints with Drypoint', 'Green')
# ('#2, from Five Aquatints with Drypoint', 'Green')
# ('#2, from Five Aquatints with Drypoint', 'Green')
# ('#2, from Five Aquatints with Drypoint', 'Green')
# ('#2, from Five Aquatints with Drypoint', 'Green')
# ('#3, from Five Aquatints with Drypoint', 'Grey')
# ('#3, from Five Aquatints with Drypoint', 'Grey')
# ('#3, from Five Aquatints with Drypoint', 'Green')
# ('#3, from Five Aquatints with Drypoint', 'Green')
# ('#3, from Five Aquatints with Drypoint', 'Yellow')
# ('#3, from Five Aquatints with Drypoint', 'Green')
# ('#3, from Five Aquatints with Drypoint', 'Green')
# ('#3, from Five Aquatints with Drypoint', 'Green')
# ('#3, from Five Aquatints with Drypoint', 'Grey')
# ('#3, from Five Aquatints with Drypoint', 'Green')
# ('#4, from Five Aquatints with Drypoint', 'Brown')
# ('#4, from Five Aquatints with Drypoint', 'Green')
# ('#4, from Five Aquatints with Drypoint', 'Green')
# ('#4, from Five Aquatints with Drypoint', 'Yellow')
# ('#4, from Five Aquatints with Drypoint', 'Green')
# ('#4, from Five Aquatints with Drypoint', 'Green')
# ('#4, from Five Aquatints with Drypoint', 'Grey')
# ('#4, from Five Aquatints with Drypoint', 'Grey')
# ("'Pojagi' with Repeating Geometric Pattern", 'Black')
# ("'Pojagi' with Repeating Geometric Pattern", 'Violet')
# ("'Pojagi' with Repeating Geometric Pattern", 'Violet')
# ("'Pojagi' with Repeating Geometric Pattern", 'Orange')
# ("'Pojagi' with Repeating Geometric Pattern", 'Red')
# ("'Pojagi' with Repeating Geometric Pattern", 'Yellow')
# ("'Pojagi' with Repeating Geometric Pattern", 'Red')
# ("'Pojagi' with Repeating Geometric Pattern", 'Red')
# ("'Pojagi' with Repeating Geometric Pattern", 'Green')
# ("'Pojagi' with Repeating Geometric Pattern", 'Orange')
# ('1995-2000', 'Grey')
# ('1995-2000', 'Grey')
# ('1995-2000', 'Grey')
# ('1995-2000', 'Grey')
# ('1995-2000', 'Grey')
# ('1995-2000', 'Grey')
# ('1995-2000', 'Red')
# ('1995-2000', 'Orange')
# ('1995-2000', 'Grey')
# ('1995-2000', 'Grey')
# ('35 mm negative file pack\r\n', 'Grey')
# ('35 mm negative file pack\r\n', 'Grey')
# ('35 mm negative file pack\r\n', 'Brown')
# ('35 mm negative file pack\r\n', 'Grey')
# ('35 mm negative file pack\r\n', 'Grey')
# ('35 mm negative file pack\r\n', 'Yellow')
# ('35 mm negative file pack\r\n', 'Yellow')
# ('35 mm negative file pack\r\n', 'Yellow')
# ('35 mm negative file pack\r\n', 'Green')
# ('35 mm negative file pack\r\n', 'Orange')
# ('A and B Figure Fields', 'Violet')
# ('A and B Figure Fields', 'Violet')
# ('A and B Figure Fields', 'Violet')
# ('A and B Figure Fields', 'Blue')
# ('A and B Figure Fields', 'Grey')
# ('A and B Figure Fields', 'Grey')
# ('A Cooper', 'Green')
# ('A Cooper', 'Green')
# ('A Cooper', 'Yellow')
# ('A Cooper', 'Brown')
# ('A Cooper', 'Brown')
# ('A Cooper', 'Green')
# ('A Cooper', 'Green')
# ('A Hilly Road; verso: blank page', 'Grey')
# ('A Hilly Road; verso: blank page', 'Grey')
# ('A Hilly Road; verso: blank page', 'Grey')
# ('A Hilly Road; verso: blank page', 'Grey')
# ('A Hilly Road; verso: blank page', 'Grey')
# ('A Hilly Road; verso: blank page', 'Green')
# ('A Hilly Road; verso: blank page', 'Green')
# ('A Hilly Road; verso: blank page', 'Green')
# ('A Hilly Road; verso: blank page', 'Green')
# ('A Landscape with Cypresses; verso: blank page', 'Grey')
# ('A Landscape with Cypresses; verso: blank page', 'Grey')
# ('A Landscape with Cypresses; verso: blank page', 'Grey')
# ('A Landscape with Cypresses; verso: blank page', 'Grey')
# ('A Landscape with Cypresses; verso: blank page', 'Grey')
# ('A Landscape with Cypresses; verso: blank page', 'Grey')
# ('A Landscape with Cypresses; verso: blank page', 'Green')
# ('A Landscape with Cypresses; verso: blank page', 'Green')
# ('A Mediterranean Bay; verso: blank page', 'Grey')
# ('A Mediterranean Bay; verso: blank page', 'Grey')
# ('A Mediterranean Bay; verso: blank page', 'Grey')
# ('A Mediterranean Bay; verso: blank page', 'Green')
# ('A Mediterranean Bay; verso: blank page', 'Green')
# ('A Mediterranean Bay; verso: blank page', 'Green')
# ('A Paraleytic Woman', 'Grey')
# ('A Paraleytic Woman', 'Grey')
# ('A Paraleytic Woman', 'Grey')
# ('A Paraleytic Woman', 'Grey')
# ('A Paraleytic Woman', 'Grey')
# ('A Paraleytic Woman', 'Grey')
# ('A Paraleytic Woman', 'Grey')
# ('A Paraleytic Woman', 'Grey')
# ('A Ruin; verso: blank page', 'Grey')
# ('A Ruin; verso: blank page', 'Grey')
# ('A Ruin; verso: blank page', 'Grey')
# ('A Ruin; verso: blank page', 'Grey')
# ('A Ruin; verso: blank page', 'Green')
# ('A Ruin; verso: blank page', 'Green')
# ('A Ruin; verso: blank page', 'Green')
# ('A Section of the Yatsuhashi Bridge', 'Brown')
# ('A Section of the Yatsuhashi Bridge', 'Grey')
# ('A Section of the Yatsuhashi Bridge', 'Grey')
# ('A Section of the Yatsuhashi Bridge', 'Brown')
# ('A Section of the Yatsuhashi Bridge', 'Orange')
# ('A Section of the Yatsuhashi Bridge', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks and Myriad Ravines, from the series "Sacrifice"', 'White')
# ('A Thousand Peaks, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks, from the series "Sacrifice"', 'Grey')
# ('A Thousand Peaks, from the series "Sacrifice"', 'White')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'Grey')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'Grey')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'Grey')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'Grey')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'Grey')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'Grey')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'Grey')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'Grey')
# ('A Thousand Trees on Rolling Hills, from the series "Sacrifice"', 'White')
# ('A View of Cronesteyn Castle, near Leiden', 'Grey')
# ('A View of Cronesteyn Castle, near Leiden', 'Grey')
# ('A View of Cronesteyn Castle, near Leiden', 'Yellow')
# ('A View of Cronesteyn Castle, near Leiden', 'Green')
# ('A View of Cronesteyn Castle, near Leiden', 'Green')
# ('A View of Cronesteyn Castle, near Leiden', 'Green')
# ('A View of Cronesteyn Castle, near Leiden', 'Red')
# ('Aeolus and the Winds', 'Grey')
# ('Aeolus and the Winds', 'Grey')
# ('Aeolus and the Winds', 'Grey')
# ('Aeolus and the Winds', 'Grey')
# ('Aeolus and the Winds', 'Grey')
# ('Aeolus and the Winds', 'Grey')
# ('Aeolus and the Winds', 'Grey')
# ('Aeolus and the Winds', 'Grey')
# ('Aeolus and the Winds', 'Grey')
# ('Allegory of the Triumph of the Netherlands over Spain', 'Grey')
# ('Allegory of the Triumph of the Netherlands over Spain', 'Grey')
# ('Allegory of the Triumph of the Netherlands over Spain', 'Yellow')
# ('Allegory of the Triumph of the Netherlands over Spain', 'Green')
# ('Allegory of the Triumph of the Netherlands over Spain', 'Green')
# ('Allegory of the Triumph of the Netherlands over Spain', 'Red')
# ('Allegory of the Triumph of the Netherlands over Spain', 'Orange')
# ('Allegory of the Triumph of the Netherlands over Spain', 'Red')
# ('Allway Saw', 'Black')
# ('Allway Saw', 'Grey')
# ('Allway Saw', 'Grey')
# ('Allway Saw', 'Grey')
# ('Allway Saw', 'Grey')
# ('Allway Saw', 'Grey')
# ('Allway Saw', 'Grey')
# ('Allway Saw', 'Grey')
# ('Amazon', 'Black')
# ('Amazon', 'Grey')
# ('Amazon', 'Grey')
# ('Amazon', 'Grey')
# ('Amazon', 'Grey')
# ('Amazon', 'Grey')
# ('Amazon', 'Grey')
# ('Amazon', 'Grey')
# ('Amazon', 'Grey')
# ('Amazon', 'Grey')
# ('An Ajaccio Fisherman', 'Yellow')
# ('An Ajaccio Fisherman', 'Brown')
# ('An Ajaccio Fisherman', 'Brown')
# ('An Ajaccio Fisherman', 'Brown')
# ('An Ajaccio Fisherman', 'Green')
# ('Angle blow brush', 'Green')
# ('Angle blow brush', 'Grey')
# ('Angle blow brush', 'Green')
# ('Angle blow brush', 'Grey')
# ('Angle blow brush', 'Green')
# ('Angle blow brush', 'Red')
# ('Angle blow brush', 'Violet')
# ('Angle blow brush', 'Grey')
# ('Angle blow brush', 'Grey')
# ('Angle blow brush', 'Grey')
# ('Art Theory Diagrams', 'Brown')
# ('Art Theory Diagrams', 'Brown')
# ('Art Theory Diagrams', 'Brown')
# ('Art Theory Diagrams', 'Orange')
# ('Art Theory Diagrams', 'Yellow')
# ('Art Theory Diagrams', 'Grey')
# ('Art Theory Diagrams with Sketch of William Baziotes’ “Cat” ', 'Red')
# ('Art Theory Diagrams with Sketch of William Baziotes’ “Cat” ', 'Grey')
# ('Art Theory Diagrams with Sketch of William Baziotes’ “Cat” ', 'Grey')
# ('Art Theory Diagrams with Sketch of William Baziotes’ “Cat” ', 'Grey')
# ('Art Theory Diagrams with Sketch of William Baziotes’ “Cat” ', 'Grey')
# ('Art Theory Diagrams with Sketch of William Baziotes’ “Cat” ', 'Grey')
# ('Art Theory Diagrams with Sketch of William Baziotes’ “Cat” ', 'Green')
# ('Art Theory Text  with Sketches', 'Brown')
# ('Art Theory Text  with Sketches', 'Red')
# ('Art Theory Text  with Sketches', 'Brown')
# ('Art Theory Text  with Sketches', 'Yellow')
# ('Art Theory Text  with Sketches', 'Brown')
# ('Art Theory Text  with Sketches', 'Yellow')
# ('Art Theory Text  with Sketches', 'Yellow')
# ('Art Theory Text  with Sketches', 'Brown')
# ('Art Theory Text  with Sketches', 'Red')
# ('Art Theory Text  with Sketches', 'Grey')
# ('Art Theory Text with Arrow Diagram', 'Red')
# ('Art Theory Text with Arrow Diagram', 'Brown')
# ('Art Theory Text with Arrow Diagram', 'Yellow')
# ('Art Theory Text with Arrow Diagram', 'Grey')
# ('Art Theory Text with Arrow Diagram', 'Brown')
# ('Art Theory Text with Arrow Diagram', 'Grey')
# ('Art Theory Text with Box Perspective Diagram', 'Grey')
# ('Art Theory Text with Box Perspective Diagram', 'Brown')
# ('Art Theory Text with Box Perspective Diagram', 'Yellow')
# ('Art Theory Text with Box Perspective Diagram', 'Orange')
# ('Art Theory Text with Box Perspective Diagram', 'Orange')
# ('Art Theory Text with Box Perspective Diagram', 'Grey')
# ('Art Theory Text with Box Perspective Diagram', 'Brown')
# ('Art Theory Text with Box Perspective Diagram', 'Orange')
# ('Art Theory Text with Box Perspective Diagram', 'Orange')
# ('Art Theory Text with Box Perspective Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Orange')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Grey')
# ('Art Theory Text with C-Scale Object Diagram', 'Green')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Red')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Blue')
# ('Art Theory Text with Color Diagram', 'Blue')
# ('Art Theory Text with Color Diagram', 'Blue')
# ('Art Theory Text with Color Diagram', 'Blue')
# ('Art Theory Text with Color Diagram', 'Green')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Green')
# ('Art Theory Text with Color Diagram', 'Red')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Red')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagram', 'Green')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Red')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Yellow')
# ('Art Theory Text with Color Diagram', 'Brown')
# ('Art Theory Text with Color Diagram', 'Red')
# ('Art Theory Text with Color Diagram', 'Grey')
# ('Art Theory Text with Color Diagrams', 'Red')
# ('Art Theory Text with Color Diagrams', 'Brown')
# ('Art Theory Text with Color Diagrams', 'Yellow')
# ('Art Theory Text with Color Diagrams', 'Brown')
# ('Art Theory Text with Color Diagrams', 'Red')
# ('Art Theory Text with Color Diagrams', 'Grey')
# ('Art Theory Text with Color Diagrams', 'Yellow')
# ('Art Theory Text with Color Diagrams', 'Grey')
# ('Art Theory Text with Color Diagrams', 'Brown')
# ('Art Theory Text with Color Diagrams', 'Red')
# ('Art Theory Text with Color Diagrams', 'Orange')
# ('Art Theory Text with Color Diagrams', 'Yellow')
# ('Art Theory Text with Color Diagrams', 'Green')
# ('Art Theory Text with Color Diagrams', 'Yellow')
# ('Art Theory Text with Color Diagrams', 'Red')
# ('Art Theory Text with Color Diagrams', 'Grey')
# ('Art Theory Text with Color Diagrams', 'Yellow')
# ('Art Theory Text with Color Diagrams', 'Orange')
# ('Art Theory Text with Color Diagrams', 'Brown')
# ('Art Theory Text with Color Diagrams', 'Yellow')
# ('Art Theory Text with Color Diagrams', 'Brown')
# ('Art Theory Text with Color Diagrams', 'Brown')
# ('Art Theory Text with Color Diagrams', 'Grey')
# ('Art Theory Text with Color Diagrams', 'Orange')
# ('Art Theory Text with Color Diagrams', 'Grey')
# ('Art Theory Text with Color Sequence Diagram', 'Red')
# ('Art Theory Text with Color Sequence Diagram', 'Brown')
# ('Art Theory Text with Color Sequence Diagram', 'Yellow')
# ('Art Theory Text with Color Sequence Diagram', 'Green')
# ('Art Theory Text with Color Sequence Diagram', 'Blue')
# ('Art Theory Text with Color Sequence Diagram', 'Brown')
# ('Art Theory Text with Color Sequence Diagram', 'Brown')
# ('Art Theory Text with Color Sequence Diagram', 'Red')
# ('Art Theory Text with Color Sequence Diagram', 'Grey')
# ('Art Theory Text with Context Figure Diagrams', 'Blue')
# ('Art Theory Text with Context Figure Diagrams', 'Grey')
# ('Art Theory Text with Context Figure Diagrams', 'Blue')
# ('Art Theory Text with Context Figure Diagrams', 'Grey')
# ('Art Theory Text with Context Figure Diagrams', 'Grey')
# ('Art Theory Text with Diagonal Diagram', 'Blue')
# ('Art Theory Text with Diagonal Diagram', 'Blue')
# ('Art Theory Text with Diagonal Diagram', 'Brown')
# ('Art Theory Text with Diagonal Diagram', 'Grey')
# ('Art Theory Text with Diagonal Diagram', 'Green')
# ('Art Theory Text with Diagonal Diagram', 'Orange')
# ('Art Theory Text with Diagram', 'Blue')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Orange')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Red')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Orange')
# ('Art Theory Text with Diagram', 'Yellow')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Blue')
# ('Art Theory Text with Diagram', 'Blue')
# ('Art Theory Text with Diagram', 'Blue')
# ('Art Theory Text with Diagram', 'Green')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Orange')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Blue')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Green')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Yellow')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Orange')
# ('Art Theory Text with Diagram', 'Blue')
# ('Art Theory Text with Diagram', 'Violet')
# ('Art Theory Text with Diagram', 'Blue')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Green')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Orange')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Yellow')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Green')
# ('Art Theory Text with Diagram', 'Yellow')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Orange')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Yellow')
# ('Art Theory Text with Diagram', 'Yellow')
# ('Art Theory Text with Diagram', 'Blue')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Brown')
# ('Art Theory Text with Diagram', 'Grey')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Red')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Red')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Orange')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Violet')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Green')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Green')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Blue')
# ('Art Theory Text with Diagrams', 'Green')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Red')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Red')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Green')
# ('Art Theory Text with Diagrams', 'Brown')
# ('Art Theory Text with Diagrams', 'Red')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Diagrams', 'Orange')
# ('Art Theory Text with Diagrams', 'Yellow')
# ('Art Theory Text with Diagrams', 'Grey')
# ('Art Theory Text with Drawing Diagrams', 'Brown')
# ('Art Theory Text with Drawing Diagrams', 'Yellow')
# ('Art Theory Text with Drawing Diagrams', 'Brown')
# ('Art Theory Text with Drawing Diagrams', 'Yellow')
# ('Art Theory Text with Drawing Diagrams', 'Blue')
# ('Art Theory Text with Drawing Diagrams', 'Brown')
# ('Art Theory Text with Drawing Diagrams', 'Brown')
# ('Art Theory Text with Drawing Diagrams', 'Red')
# ('Art Theory Text with Drawing Diagrams', 'Grey')
# ('Art Theory Text with Faces', 'Brown')
# ('Art Theory Text with Faces', 'Yellow')
# ('Art Theory Text with Faces', 'Grey')
# ('Art Theory Text with Faces', 'Yellow')
# ('Art Theory Text with Faces', 'Grey')
# ('Art Theory Text with Faces', 'Brown')
# ('Art Theory Text with Faces', 'Grey')
# ('Art Theory Text with Faces', 'Grey')
# ('Art Theory Text with Faces', 'Brown')
# ('Art Theory Text with Faces', 'Orange')
# ('Art Theory Text with Faces', 'Yellow')
# ('Art Theory Text with Faces', 'Brown')
# ('Art Theory Text with Faces', 'Grey')
# ('Art Theory Text with Faces', 'Brown')
# ('Art Theory Text with Faces', 'Grey')
# ('Art Theory Text with Figure-Place Diagram', 'Yellow')
# ('Art Theory Text with Figure-Place Diagram', 'Grey')
# ('Art Theory Text with Figure-Place Diagram', 'Brown')
# ('Art Theory Text with Figure-Place Diagram', 'Brown')
# ('Art Theory Text with Figure-Place Diagram', 'Grey')
# ('Art Theory Text with Figure-Place Diagrams', 'Brown')
# ('Art Theory Text with Figure-Place Diagrams', 'Yellow')
# ('Art Theory Text with Figure-Place Diagrams', 'Grey')
# ('Art Theory Text with Figure-Place Diagrams', 'Brown')
# ('Art Theory Text with Figure-Place Diagrams', 'Grey')
# ('Art Theory Text with Figure-Place Diagrams', 'Yellow')
# ('Art Theory Text with Figure-Place Diagrams', 'Yellow')
# ('Art Theory Text with Figure-Place Diagrams', 'Green')
# ('Art Theory Text with Figure-Place Diagrams', 'Brown')
# ('Art Theory Text with Figure-Place Diagrams', 'Grey')
# ('Art Theory Text with Figure-Place Diagrams', 'Blue')
# ('Art Theory Text with Figure-Place Diagrams', 'Blue')
# ('Art Theory Text with Figure-Place Diagrams', 'Brown')
# ('Art Theory Text with Figure-Place Diagrams', 'Red')
# ('Art Theory Text with Figure-Place Diagrams', 'Brown')
# ('Art Theory Text with Figure-Place Diagrams', 'Yellow')
# ('Art Theory Text with Figure-Place Diagrams', 'Blue')
# ('Art Theory Text with Figure-Place Diagrams', 'Brown')
# ('Art Theory Text with Figure-Place Diagrams', 'Red')
# ('Art Theory Text with Figure-Place Diagrams', 'Grey')
# ('Art Theory Text with Gesture Sketch', 'Grey')
# ('Art Theory Text with Gesture Sketch', 'Blue')
# ('Art Theory Text with Gesture Sketch', 'Blue')
# ('Art Theory Text with Gesture Sketch', 'Blue')
# ('Art Theory Text with Gesture Sketch', 'Green')
# ('Art Theory Text with Gesture Sketch', 'Blue')
# ('Art Theory Text with Gesture Sketch', 'Grey')
# ('Art Theory Text with Gesture Sketch', 'Grey')
# ('Art Theory Text with Gesture Sketch', 'Blue')
# ('Art Theory Text with Gesture Sketch', 'Blue')
# ('Art Theory Text with Gesture Sketch', 'Blue')
# ('Art Theory Text with Gesture Sketch', 'Grey')
# ('Art Theory Text with Gesture Sketch', 'Green')
# ('Art Theory Text with Hand', 'Brown')
# ('Art Theory Text with Hand', 'Orange')
# ('Art Theory Text with Hand', 'Yellow')
# ('Art Theory Text with Hand', 'Brown')
# ('Art Theory Text with Hand', 'Brown')
# ('Art Theory Text with Hand', 'Blue')
# ('Art Theory Text with Horses and Riders', 'Yellow')
# ('Art Theory Text with Horses and Riders', 'Yellow')
# ('Art Theory Text with Horses and Riders', 'Brown')
# ('Art Theory Text with Horses and Riders', 'Orange')
# ('Art Theory Text with Horses and Riders', 'Orange')
# ('Art Theory Text with Horses and Riders', 'Grey')
# ('Art Theory Text with Line Drawings', 'Blue')
# ('Art Theory Text with Line Drawings', 'Blue')
# ('Art Theory Text with Line Drawings', 'Grey')
# ('Art Theory Text with Line Drawings', 'Grey')
# ('Art Theory Text with Line Drawings', 'Brown')
# ('Art Theory Text with Line Drawings', 'Green')
# ('Art Theory Text with Lobster', 'Yellow')
# ('Art Theory Text with Lobster', 'Brown')
# ('Art Theory Text with Lobster', 'Brown')
# ('Art Theory Text with Lobster', 'Brown')
# ('Art Theory Text with Lobster', 'Grey')
# ('Art Theory Text with Lobster', 'Orange')
# ('Art Theory Text with Maximum Ratio Differential Diagram', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagram', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Diagram', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Diagram', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Diagram', 'Green')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Green')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Green')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Green')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Green')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Violet')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Yellow')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Brown')
# ('Art Theory Text with Maximum Ratio Differential Diagrams', 'Green')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Violet')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Violet')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Green')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Green')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Blue')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Grey')
# ('Art Theory Text with Maximum Ratio Differential Sketch', 'Green')
# ('Art Theory Text with Minimum and Maximum Ratio Differential Diagram', 'Blue')
# ('Art Theory Text with Minimum and Maximum Ratio Differential Diagram', 'Blue')
# ('Art Theory Text with Minimum and Maximum Ratio Differential Diagram', 'Green')
# ('Art Theory Text with Minimum and Maximum Ratio Differential Diagrams', 'Blue')
# ('Art Theory Text with Minimum and Maximum Ratio Differential Diagrams', 'Grey')
# ('Art Theory Text with Minimum and Maximum Ratio Differential Diagrams', 'Green')
# ('Art Theory Text with Moon', 'Brown')
# ('Art Theory Text with Moon', 'Orange')
# ('Art Theory Text with Moon', 'Yellow')
# ('Art Theory Text with Moon', 'Brown')
# ('Art Theory Text with Moon', 'Yellow')
# ('Art Theory Text with Moon', 'Red')
# ('Art Theory Text with Moon', 'Blue')
# ('Art Theory Text with Motion Diagrams', 'Red')
# ('Art Theory Text with Motion Diagrams', 'Yellow')
# ('Art Theory Text with Motion Diagrams', 'Brown')
# ('Art Theory Text with Motion Diagrams', 'Yellow')
# ('Art Theory Text with Motion Diagrams', 'Yellow')
# ('Art Theory Text with Motion Diagrams', 'Blue')
# ('Art Theory Text with Motion Diagrams', 'Brown')
# ('Art Theory Text with Motion Diagrams', 'Red')
# ('Art Theory Text with Motion Diagrams', 'Grey')
# ('Art Theory Text with Scrawl and Umbrella', 'Grey')
# ('Art Theory Text with Scrawl and Umbrella', 'Brown')
# ('Art Theory Text with Scrawl and Umbrella', 'Yellow')
# ('Art Theory Text with Scrawl and Umbrella', 'Brown')
# ('Art Theory Text with Scrawl and Umbrella', 'Yellow')
# ('Art Theory Text with Scrawl and Umbrella', 'Yellow')
# ('Art Theory Text with Scrawl and Umbrella', 'Grey')
# ('Art Theory Text with Scrawl and Umbrella', 'Brown')
# ('Art Theory Text with Scrawl and Umbrella', 'Grey')
# ('Art Theory Text with Scribble', 'Red')
# ('Art Theory Text with Scribble', 'Yellow')
# ('Art Theory Text with Scribble', 'Brown')
# ('Art Theory Text with Scribble', 'Brown')
# ('Art Theory Text with Scribble', 'Red')
# ('Art Theory Text with Scribble', 'Grey')
# ('Art Theory Text with Scribble and Plus Sign', 'Brown')
# ('Art Theory Text with Scribble and Plus Sign', 'Brown')
# ('Art Theory Text with Scribble and Plus Sign', 'Brown')
# ('Art Theory Text with Scribble and Plus Sign', 'Brown')
# ('Art Theory Text with Scribble and Plus Sign', 'Orange')
# ('Art Theory Text with Scribble and Plus Sign', 'Yellow')
# ('Art Theory Text with Scribble and Plus Sign', 'Orange')
# ('Art Theory Text with Scribble and Plus Sign', 'Grey')
# ('Art Theory Text with Scribbles', 'Red')
# ('Art Theory Text with Scribbles', 'Yellow')
# ('Art Theory Text with Scribbles', 'Orange')
# ('Art Theory Text with Scribbles', 'Brown')
# ('Art Theory Text with Scribbles', 'Yellow')
# ('Art Theory Text with Scribbles', 'Yellow')
# ('Art Theory Text with Scribbles', 'Grey')
# ('Art Theory Text with Scribbles', 'Brown')
# ('Art Theory Text with Scribbles', 'Grey')
# ('Art Theory Text with Scribbles', 'Green')
# ('Art Theory Text with Scribbles', 'Yellow')
# ('Art Theory Text with Scribbles', 'Brown')
# ('Art Theory Text with Scribbles', 'Yellow')
# ('Art Theory Text with Scribbles', 'Yellow')
# ('Art Theory Text with Scribbles', 'Blue')
# ('Art Theory Text with Scribbles', 'Brown')
# ('Art Theory Text with Scribbles', 'Grey')
# ('Art Theory Text with Scribbles', 'Green')
# ('Art Theory Text with Scribbles', 'Yellow')
# ('Art Theory Text with Scribbles', 'Brown')
# ('Art Theory Text with Scribbles', 'Yellow')
# ('Art Theory Text with Scribbles', 'Brown')
# ('Art Theory Text with Scribbles', 'Brown')
# ('Art Theory Text with Scribbles', 'Grey')
# ('Art Theory Text with Scribbles and Sketches', 'Brown')
# ('Art Theory Text with Scribbles and Sketches', 'Yellow')
# ('Art Theory Text with Scribbles and Sketches', 'Brown')
# ('Art Theory Text with Scribbles and Sketches', 'Yellow')
# ('Art Theory Text with Scribbles and Sketches', 'Yellow')
# ('Art Theory Text with Scribbles and Sketches', 'Grey')
# ('Art Theory Text with Scribbles and Sketches', 'Brown')
# ('Art Theory Text with Scribbles and Sketches', 'Grey')
# ('Art Theory Text with Sequence Diagrams', 'Brown')
# ('Art Theory Text with Sequence Diagrams', 'Orange')
# ('Art Theory Text with Sequence Diagrams', 'Yellow')
# ('Art Theory Text with Sequence Diagrams', 'Orange')
# ('Art Theory Text with Sequence Diagrams', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram and Sketch', 'Brown')
# ('Art Theory Text with Sequence of Position Diagram and Sketch', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram and Sketch', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram and Sketch', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram and Sketch', 'Grey')
# ('Art Theory Text with Sequence of Position Diagram and Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Blue')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Red')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Red')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Red')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Red')
# ('Art Theory Text with Sketch', 'Red')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Blue')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Orange')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Violet')
# ('Art Theory Text with Sketch', 'Blue')
# ('Art Theory Text with Sketch', 'Blue')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Orange')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Orange')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Red')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Blue')
# ('Art Theory Text with Sketch', 'Brown')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Yellow')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Green')
# ('Art Theory Text with Sketch', 'Orange')
# ('Art Theory Text with Sketch', 'Grey')
# ('Art Theory Text with Sketch', 'Violet')
# ('Art Theory Text with Sketch', 'Blue')
# ...
# ('[Men standing at harbor railing, Brittany]', 'Grey')
# ('[Men standing at harbor railing, Brittany]', 'Grey')
# ('[Men standing at harbor railing, Brittany]', 'Grey')
# ('[Men standing at harbor railing, Brittany]', 'Grey')
# ('[Pedestrians walking, viewed from above, Berlin, 1933]', 'Black')
# ('[Pedestrians walking, viewed from above, Berlin, 1933]', 'Grey')
# ('[Pedestrians walking, viewed from above, Berlin, 1933]', 'Grey')
# ('[Pedestrians walking, viewed from above, Berlin, 1933]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Black')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Black')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Quimper Cathedral, Brittany]', 'Grey')
# ('[Railroad yard and buildings, Berlin]', 'Black')
# ('[Railroad yard and buildings, Berlin]', 'Grey')
# ('[Railroad yard and buildings, Berlin]', 'Grey')
# ('[Railroad yard in snow, Berlin]', 'Black')
# ('[Railroad yard in snow, Berlin]', 'Grey')
# ('[Railroad yard in snow, Berlin]', 'Grey')
# ('[Railroad yard in snow, Berlin]', 'Grey')
# ('[Railroad yard in snow, Berlin]', 'Grey')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Black')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Grey')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Grey')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Grey')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Grey')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Grey')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Black')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Grey')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Grey')
# ('[Riverbank with boats in Douarnenez?, Brittany]', 'Grey')
# ('[Sailboat on river in Quimper, Brittany]', 'Black')
# ('[Sailboat on river in Quimper, Brittany]', 'Grey')
# ('[Sailboat on river in Quimper, Brittany]', 'Grey')
# ('[Sailboat on river in Quimper, Brittany]', 'Grey')
# ('[Sailboat on river in Quimper, Brittany]', 'Grey')
# ('[Sailboat on river in Quimper, Brittany]', 'Grey')
# ('[Sand dunes, Deep, Baltic Coast]', 'Black')
# ('[Sand dunes, Deep, Baltic Coast]', 'Grey')
# ('[Sand dunes, Deep, Baltic Coast]', 'Grey')
# ('[Sand dunes, Deep, Baltic Coast]', 'Grey')
# ('[Shellhaus, Berlin]', 'Black')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Shellhaus, Berlin]', 'Black')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Shellhaus, Berlin]', 'Black')
# ('[Shellhaus, Berlin]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Black')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Black')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Ship in the harbor at Saint-Malo, Brittany]', 'Grey')
# ('[Siemsstadt-Berlin]', 'Black')
# ('[Siemsstadt-Berlin]', 'Grey')
# ('[Siemsstadt-Berlin]', 'Grey')
# ('[Siemsstadt-Berlin]', 'Grey')
# ('[Strand-Cafe on dock, Germany]', 'Black')
# ('[Strand-Cafe on dock, Germany]', 'Grey')
# ('[Strand-Cafe on dock, Germany]', 'Grey')
# ('[Strand-Cafe on dock, Germany]', 'Grey')
# ('[Strand-Cafe on dock, Germany]', 'Grey')
# ('[Strand-Cafe on dock, Germany]', 'Grey')
# ('[Street scene in Berlin]', 'Black')
# ('[Street scene in Berlin]', 'Grey')
# ('[Street scene in Berlin]', 'Grey')
# ('[Street scene in Berlin]', 'Grey')
# ('[Street scene in Berlin]', 'Grey')
# ('[Street scene in Berlin]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Black')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Black')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Black')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Black')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Black')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Black')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Quimper, Brittany]', 'Black')
# ('[Street scene in Quimper, Brittany]', 'Grey')
# ('[Street scene in Saint-Malo, Brittany]', 'Black')
# ('[Street scene in Saint-Malo, Brittany]', 'Grey')
# ('[Street scene in Saint-Malo, Brittany]', 'Grey')
# ('[Street scene in Saint-Malo, Brittany]', 'Grey')
# ('[Street scene with cars, Germany]', 'Black')
# ('[Street scene with cars, Germany]', 'Grey')
# ('[Street scene with cars, Germany]', 'Grey')
# ('[Street scene with church, Lübeck]', 'Black')
# ('[Street scene with church, Lübeck]', 'Grey')
# ('[Street scene with church, Lübeck]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Black')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Black')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Black')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Black')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Black')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Black')
# ('[Street scene with Quimper Cathedral, Brittany]', 'Grey')
# ('[Street scene with the Kaiser Wilhelm Memorial Church, Berlin]', 'Black')
# ('[Street scene with the Kaiser Wilhelm Memorial Church, Berlin]', 'Grey')
# ('[Street scene with the Kaiser Wilhelm Memorial Church, Berlin]', 'Grey')
# ('[Street scene with the Kaiser Wilhelm Memorial Church, Berlin]', 'Grey')
# ('[Street scene with the Kaiser Wilhelm Memorial Church, Berlin]', 'Grey')
# ('[Street scene, Berlin, 1933-1937, rephotographed as slide]', 'Black')
# ('[Street scene, Berlin, 1933-1937, rephotographed as slide]', 'Grey')
# ('[Street scene, Berlin, 1933-1937, rephotographed as slide]', 'Grey')
# ('[Street scene, Berlin, 1933-1937, rephotographed as slide]', 'Grey')
# ('[Street scene, Berlin, 1933-1937, rephotographed as slide]', 'Grey')
# ('[Street scene, Berlin]', 'Black')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Black')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Black')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Black')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Black')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Berlin]', 'Grey')
# ('[Street scene, Brittany]', 'Black')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Black')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Black')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Black')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Brittany]', 'Black')
# ('[Street scene, Brittany]', 'Grey')
# ('[Street scene, Germany]', 'Black')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Black')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Black')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Germany]', 'Black')
# ('[Street scene, Germany]', 'Grey')
# ('[Street scene, Paris]', 'Black')
# ('[Street scene, Paris]', 'Grey')
# ('[Street scene, Paris]', 'Black')
# ('[Street scene, Paris]', 'Grey')
# ('[Street scene, Paris]', 'Grey')
# ('[Street scene, Saint-Malo, Brittany]', 'Black')
# ('[Street scene, Saint-Malo, Brittany]', 'Grey')
# ('[Street scene, Saint-Malo, Brittany]', 'Grey')
# ('[Street scene, Saint-Malo, Brittany]', 'Grey')
# ('[Street scene, Saint-Malo, Brittany]', 'Grey')
# ('[Street scene, Saint-Malo, Brittany]', 'Grey')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Black')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Grey')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Grey')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Grey')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Grey')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Black')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Grey')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Grey')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Grey')
# ('[Train and steam near Hildebrand Chocolate Company, Berlin]', 'Grey')
# ('[Train station in Berlin]', 'Black')
# ('[Train station in Berlin]', 'Grey')
# ('[Train station in Berlin]', 'Grey')
# ('[Train station in Berlin]', 'Grey')
# ('[Transporting a boat on the road, Germany]', 'Black')
# ('[Transporting a boat on the road, Germany]', 'Grey')
# ('[Transporting a boat on the road, Germany]', 'Grey')
# ('[Transporting a boat on the road, Germany]', 'Grey')
# ('[View of barge on the Seine, with Notre-Dame Cathedral, Paris]', 'Black')
# ('[View of barge on the Seine, with Notre-Dame Cathedral, Paris]', 'Grey')
# ('[View of harbor and ships, Brittany]', 'Black')
# ('[View of harbor and ships, Brittany]', 'Grey')
# ('[View of harbor and ships, Brittany]', 'Grey')
# ('[View of harbor and ships, Brittany]', 'Grey')
# ('[View of harbor and ships, Brittany]', 'Grey')
# ('[Village harbor, Brittany]', 'Black')
# ('[Village harbor, Brittany]', 'Grey')
# ('[Village harbor, Brittany]', 'Grey')
# ('[Village harbor, Brittany]', 'Grey')
# ('[Village harbor, Brittany]', 'Grey')
# ('[Village harbor, Brittany]', 'Grey')
# ('[Village in Brittany]', 'Black')
# ('[Village in Brittany]', 'Grey')
# ('[Village in Brittany]', 'Grey')
# ('[Village in Brittany]', 'Grey')
# ('[Village in Brittany]', 'Grey')
# ('[Village in Brittany]', 'Black')
# ('[Village in Brittany]', 'Grey')
# ('[Village in Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Black')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Black')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Black')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmill near Quimper, Brittany]', 'Grey')
# ('[Windmills near Quimper, Brittany]', 'Black')
# ('[Windmills near Quimper, Brittany]', 'Grey')
# ('[Windmills near Quimper, Brittany]', 'Grey')
# ('[Windmills near Quimper, Brittany]', 'Grey')
# ('[Windmills near Quimper, Brittany]', 'Grey')
# ('[Windmills near Quimper, Brittany]', 'Grey')
# ('[Windmills near Quimper, Brittany]', 'Grey')
# ('[Windmills near Quimper, Brittany]', 'Grey')
# ('[Women in traditional dress at Saint-Malo Harbor, Brittany]', 'Black')
# ('[Women in traditional dress at Saint-Malo Harbor, Brittany]', 'Grey')
# ('[Women in traditional dress at Saint-Malo Harbor, Brittany]', 'Grey')
# ('[Women in traditional dress at Saint-Malo Harbor, Brittany]', 'Grey')
# ('[Women in traditional dress at Saint-Malo Harbor, Brittany]', 'Grey')
# ('[Women in traditional dress at Saint-Malo Harbor, Brittany]', 'Grey')
# ('[Women in traditional dress at Saint-Malo Harbor, Brittany]', 'Grey')
# ('[Wooden pilings at Deep, Baltic Coast]', 'Black')
# ('[Wooden pilings at Deep, Baltic Coast]', 'Grey')
# ('[Wooden pilings at Deep, Baltic Coast]', 'Grey')
# ('[Wooden pilings at Deep, Baltic Coast]', 'Grey')
# ('[Wooden pilings at Deep, Baltic Coast]', 'Grey')
# ('[Wooden pilings at Deep, Baltic Coast]', 'Grey')
# ('[Wooden pilings at Deep, Baltic Coast]', 'Grey')
# ('[Workers outside Quimper Cathedral, Brittany]', 'Black')
# ('[Workers outside Quimper Cathedral, Brittany]', 'Grey')
# ('[Workers outside Quimper Cathedral, Brittany]', 'Grey')
# ('[Workers outside Quimper Cathedral, Brittany]', 'Grey')
# ('“Gainchie”, folio from the album, Fishes of India', 'Brown')
# ('“Gainchie”, folio from the album, Fishes of India', 'Green')
# ('“Manua”, folio from the album Fishes of India', 'Grey')
# ('“Manua”, folio from the album Fishes of India', 'Green')
# ('“Manua”, folio from the album Fishes of India', 'Yellow')
# ('“Manua”, folio from the album Fishes of India', 'Green')
# ('“Manua”, folio from the album Fishes of India', 'Orange')
# ('“Manua”, folio from the album Fishes of India', 'Grey')
# ('“Manua”, folio from the album Fishes of India', 'Orange')
# ('“Manua”, folio from the album Fishes of India', 'Orange')
# ('“Manua”, folio from the album Fishes of India', 'Green')
# ('“Pan”, folio from the album Fishes of India', 'Yellow')
# ('“Pan”, folio from the album Fishes of India', 'Grey')
# ('“Pan”, folio from the album Fishes of India', 'Orange')
# ('“Pan”, folio from the album Fishes of India', 'Orange')
# ('“Pan”, folio from the album Fishes of India', 'Green')
# ('“Putka”, folio from the album Fishes of India', 'Brown')
# ('“Putka”, folio from the album Fishes of India', 'Grey')
# ('“Putka”, folio from the album Fishes of India', 'Yellow')
# ('“Putka”, folio from the album Fishes of India', 'Green')
# ('“Putka”, folio from the album Fishes of India', 'Orange')
# ('“Putka”, folio from the album Fishes of India', 'Brown')
# ('“Putka”, folio from the album Fishes of India', 'Green')

# %%
#18.Get artifact titles, cultures, and media ranks where the period is not null
query = """
SELECT m.title, m.culture, me.rank
FROM artifact_metadata AS m
JOIN artifact_media AS me
    ON m.id = me.objectid
WHERE m.period IS NOT NULL
ORDER BY me.rank DESC;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# ('Globular Jar with Rounded Bottom and Flaring Lip', 'Korean', 140317)
# ('"Eye" Bead with Aqua and White Swirls', 'Chinese', 140315)
# ('Broad-Shouldered, "Hanging Jar" with Vertical Lip, Wide Mouth, and Landscape Décor', 'Chinese', 140314)
# ('Globular, Wide-Mouthed Jar with Two Loop Handles and Pale Lavender Splash', 'Chinese', 140313)
# ('Large Circular Bowl with Five Large Russet Splashes against a Ground of Russet Flecks', 'Chinese', 140310)
# ('Small Tea Bowl with Decoration of Moon, Clouds, and Blossoming Plum', 'Chinese', 140309)
# ('Small Water Coupe in the Form of a Spotted Frog', 'Chinese', 140308)
# ('Small Jade Sculpture in the Form of a Recumbent Ram', 'Chinese', 140307)
# ('Standing Lokapala Guardian Figure with Proper Right Arm Raised', 'Chinese', 140306)
# ('Medicine Buddha (Chinese, Yaoshi Rulai) Seated on a Lotus Pedestal and Holding a Small Medicine Jar in His Left Hand', 'Chinese', 140305)
# ('Plaque: Wild Goat and Deer', 'East Asian', 140273)
# ('Large Circular Bowl', 'Chinese', 139421)
# ('Circular Covered Box with Peony Décor', 'Chinese', 139418)
# ('Frog-Shaped Water Dropper', 'Korean', 138743)
# ('Temple Rooftile with Pagoda Design, from Hōshō-ji', 'Japanese', 138720)
# ('Archiform Pendent Eaves-End Rooftile with Three-Prong Vajra (Sankosho) Design, from Rokuharamitsu-ji\r\n', 'Japanese', 138718)
# ('Circular Eaves-End Rooftile with Design of Sanskrit Syllable for Buddha Amitabha (Amida)', 'Japanese', 138717)
# ('Circular Eaves-End Rooftile with Design of Pagoda (Gorinto) and Sanskrit Syllable for Buddha Vairochana (Dainichi), from Shōtō-ji (subtemple of Hōshō-ji), Kyoto', 'Japanese', 138715)
# ('Circular Eaves-End Rooftile with Lotus Design, from Minamishaga Hai-ji', 'Japanese', 138713)
# ('Rice-Grain Pagoda with Sanskrit character for "Dainichi" written on one side, from Murō-ji', 'Japanese', 138710)
# ('Five-Part Pagoda, from Rokuharamitsu-ji', 'Japanese', 138698)
# ('Pagoda', 'Japanese', 138697)
# ('Seated Bodhisattva of Wisdom with Five Tufts of Hair (Gokei Monju)', 'Japanese', 138687)
# ('Buddha at Birth (Tanjō Butsu)', 'Japanese', 138685)
# ("Finial for a Buddhist Monk's Staff (Shakujo) with Six Pagodas", 'Japanese', 138683)
# ("Finial for a Buddhist Monk's Staff (Shakujō) with Pagodas, Vases, and Sun & Moon", 'Japanese', 138681)
# ('Five-Prong Vajra (Gokosho), or Buddhist Thunderbolt', 'Japanese', 138678)
# ('Chakra (Rimpō), or Wheel of the Buddhist Law', 'Japanese', 138676)
# ('Printed Images (Imbutsu) of Acalanâtha (Fudō Myōō), from Kyōōgokoku-ji (Tō-ji), Kyoto', 'Japanese', 138671)
# ('Printed Images (inbutsu) of Buddha Amitabha (Amida), from Jōruri-ji, Kyoto', 'Japanese', 138670)
# ('Invocation Sheet (Nembutsu)', 'Japanese', 138668)
# ('Nyoirin Kannon above a Landscape', 'Japanese', 138663)
# ('Godai Myōō with Nyōirin Kannon and Aizen Myōō', 'Japanese', 138662)
# ('Sanskrit Diamond World Mandala (Shuji Kongokai mandara)', 'Japanese', 138657)
# ('Intaglio: Rooster-Headed Anguipede', 'Roman', 137137)
# ('Intaglio: Uterine Symbol with Egyptian Deities', 'Roman', 137136)
# ('Intaglio: Crescent and Five Stars', 'Roman', 137135)
# ('Intaglio: Lion', 'Roman', 137134)
# ('Intaglio: Hanging Figure Attacked by a Lion and Eagle, with Eros', 'Roman', 137133)
# ('Intaglio: Eagle Holding a Wreath and Perched on a Mountain', 'Roman', 137132)
# ('Intaglio: Harpocrates on a Boat Surrounded by Animals', 'Roman', 137131)
# ('Intaglio: Maritime Scene', 'Roman', 137130)
# ('Circular Impressed Disk', 'Greek', 137042)
# ('Ewer with Short, Flaring Neck, Short Spout, and Handle in the Form of a Leaping Lion', 'Chinese', 134565)
# ('Pillow in the Form of Recumbent, Addorsed Lions Supporting a Headrest with Bird-and-Flower Décor', 'Chinese', 132207)
# ('Roses and Wisteria by a Garden Rock', 'Chinese', 126953)
# ('Wide-mouthed jar with pointed base', 'Chinese', 126631)
# ('Tetradachm of Seleukos I, Seleukeia-on-the-Tigris, second workshop', 'Greek', 126436)
# ('Rooster Pendant', 'Greek', 126377)
# ("'Pojagi' with Repeating Geometric Pattern", 'Korean', 126264)
# ('Obol of Himera, Sicily', 'Greek', 126243)
# ('Five-scruples coin from Vulci (?), Etruria', 'Etruscan', 126242)
# ('Tetradrachm of Antiochos II, Sardis', 'Greek', 126238)
# ('Tetradrachm of Antiochos II, Antioch', 'Greek', 126237)
# ('Octodrachm of Alexander I of Macedonia', 'Greek', 126236)
# ("Tea Bowl with Indented Lip and Subtle Hare's-Fur Markings", 'Chinese', 126207)
# ('Bottom Tier from a Set of Stacked Quatrefoil Boxes with Stylized Floral Decor', 'Chinese', 126206)
# ('Landscape', 'Korean', 126137)
# ('Rectangular Silk Panel, Possibly from a Banner, with a Buddhist Mantra Reading "Om mani padme hum"', 'Chinese', 126136)
# ('Hekte of Kyzikos', 'Greek', 126131)
# ('Earrings with Three Lion Heads', 'Hellenistic', 125772)
# ('Figure of a Seated Ape', 'Greek', 125771)
# ('Ram Pendant', 'Anatolian', 125770)
# ('Bull Standard', 'Near Eastern', 125769)
# ('Basin Handle with Lion and Snake Heads', 'Greek', 125768)
# ('Pair of Lion-Headed Earrings', 'Greek', 125767)
# ('Orchids and Rocks', 'Korean', 125763)
# ('Orchids and Rocks', 'Korean', 125762)
# ('Orchids and Rocks', 'Korean', 125761)
# ('Orchids and Rocks', 'Korean', 125759)
# ('Tetradrachm from Himera, Sicily', 'Greek', 125752)
# ('Coin of Abydos under Caracalla (cast forgery)', 'Roman Provincial', 125703)
# ('Coin of Tarsos under Gordian III', 'Roman Provincial', 125701)
# ('Sumerian Banded Agate Bead', 'Sumerian', 125228)
# ('Sumerian Banded Agate Bead', 'Sumerian', 125227)
# ('Terracotta Eye Idol, Tel Brak', 'Sumerian', 125225)
# ('Black Bowl', 'Sumerian', 125224)
# ('Selket', 'Egyptian', 125223)
# ('Egyptian Alabastron, with Two Lug Handles', 'Egyptian', 125222)
# ('Spoon', 'Parthian', 125221)
# ('Pair of Standing, Helmeted, Armor-Clad Guardian Warriors, Each with One Arm Raised and One at the Side, and Both Hands Clenched as if Holding Weapons, One Figure with Mouth Closed and Wearing Straw Shoes, One with Mouth Open and Wearing Pointed Boots', 'Chinese', 125198)
# ('Pair of Standing, Helmeted, Armor-Clad, Bearded Guardian Warriors, One with Mouth Open, One with Mouth Closed, Each with Pointed Boots and a Hand Raised to Waist Level as if Grasping a Lance or Spear, and Standing on a Rocky Base from which Protrude the Head and Tail of a Snake', 'Chinese', 125195)
# ('Two Standing Boars', 'Chinese', 125189)
# ('Two Standing, Bearded, Foreign Male Figures, Each Wearing a Tall Hat with Protective Neck and Ear Flaps, a Shoulder Scarf, Heavy Boots, and Spotted, Leopard-Skin Trousers, and Each with His Hands Clasped at His Chest', 'Chinese', 125172)
# ('Two Equestrian Figures, One Male with a Tall, Elaborately Embellished Hat, One Female with Hair in a Topknot, Both with Pointed Boots, and Hands Positioned to Hold the Reins of their Standing, Saddled Horses', 'Chinese', 125167)
# ("Four Kneeling, Female Court Musicians (One with a 'Pipa', or Lute, and One with Cymbals), Each of the Four with a High-Waisted, Striped Dress or Skirt and with Long Hair Arranged in Two Buns", 'Chinese', 125156)
# ("Two Standing Officials, Each with Upturned Shoes, a 'Liangdang' Breastplate, and a Military Official's Headgear Emblazoned with a Descending Bird, and Each with His Hands Clasped at His Waist and Concealed within His Sleeves", 'Chinese', 125147)
# ('Two Standing Court Ladies, Each with Upturned Shoes, a High-Waisted Dress or Skirt, a Shawl, and an Elaborate Coiffure Secured by a Headband, and Each with Her Hands Clasped at the Waist and Concealed within Her Sleeves', 'Chinese', 125143)
# ('Funerary Sculpture Representing a Dancing Woman Wearing a Long-Sleeved Robe', 'Chinese', 125089)
# ('A Section of the Yatsuhashi Bridge', 'Japanese', 125088)
# ('Landscape with Full Moon', 'Japanese', 125087)
# ('Tetradrachm of Abyatha, Gerrha?', 'Near Eastern', 125051)
# ('coin of Claudius II?', None, 124970)
# ('Coin of Septimius Severus', 'Roman', 124969)
# ('Coin of Constantine II', 'Roman', 124967)
# ('Coin of Constantine II', 'Roman', 124966)
# ('Coin of Trajan', None, 124962)
# ('Dupondius of Vespasian, Rome', 'Roman Imperial', 124961)
# ('Denarius of Hadrian with Africa', None, 124960)
# ('Carthaginian bronze coin', None, 124958)
# ('Denarius of Augustus (Forgery)', 'Roman Imperial', 124957)
# ('Coin of Hieron II, Tyrant of Syracuse', 'Greek', 124954)
# ('Coin of Ptolemy III of Egypt', 'Greek', 124953)
# ('Stater of Corinth (Sicilian copy)', 'Greek', 124950)
# ('Sestertius of Philip I', 'Roman', 124945)
# ('Coin of Valentinian', 'Roman Imperial', 124944)
# ('Sestertius of Philip I', 'Roman', 124943)
# ('Coin of Claudius II', 'Roman', 124942)
# ('Coin of Justin I', 'Roman', 124941)
# ('Sestertius of Gordian III', 'Roman', 124940)
# ('Sestertius of Gordian III', 'Roman', 124939)
# ('Sestertius of Macrinus (forgery)', 'Roman', 124938)
# ('Denarius of Septimius Severus', 'Roman', 124937)
# ('Sestertius of Faustina II', 'Roman', 124936)
# ('As or Dupondius of Lucilla', 'Roman', 124935)
# ('Denarius of  Antoninus Pius', 'Roman', 124934)
# ('Sestertius of Faustina I', 'Roman', 124933)
# ('Sestertius of Hadrian', 'Roman', 124932)
# ('Sestertius of Trajan', 'Roman', 124931)
# ('Denarius of Trajan, Rome', 'Roman Imperial', 124930)
# ('Sestertius of Trajan, Rome', 'Roman Imperial', 124929)
# ('As of Claudius, Rome', 'Roman Imperial', 124927)
# ('As of Tiberius, Rome', 'Roman Imperial', 124926)
# ('Denarius of Augustus, Colonia Patricia', 'Roman Imperial', 124925)
# ('Denarius of Q. Caecilius Q.f. Q.n. Metellus Pius Scipio Nasica, Africa', 'Roman Republican', 124924)
# ('Denarius of Q. Pomponius Musa, Rome', 'Roman Republican', 124923)
# ('Anonymous Denarius, Sicily', 'Roman Republican', 124922)
# ('As of Matienus, Rome', 'Roman Republican', 124921)
# ('Anonymous Semilibral Aes Grave Sextans, Rome', 'Roman Republican', 124920)
# ('Coin of Sardis', 'Greek', 124220)
# ('Coin of Alexandreia Troas under Valerian I', 'Roman Provincial', 124115)
# ('Coin of Alexandreia Troas under Trebonianus Gallus', 'Roman Provincial', 124113)
# ('Coin of Alexandreia Troas under Maximus Caesar', 'Roman Provincial', 124112)
# ('Follis of Crispus, Heraclea', 'Roman', 123297)
# ('Follis of  Licinius II, Antioch', 'Roman Imperial', 123295)
# ('Courtier Raja Anup Rai Intercepting a Lion Attack, with  Mughal Emperor Jahangir and Prince Khurram, drawing (verso); Calligraphy (recto)', 'Mughal', 121478)
# ('Former Counsellor Xu You Washing His Ears in the Ying River as the Sage Chao Fu Leads His Ox Away', 'Korean', 115790)
# ('The Sage Jiang Ziya (10th century BC) Fishing in the Wei River, Approached by Wen Wang the Ruler of Zhou', 'Korean', 115789)
# ('Former Prime Minister Zhang Liang (d. 189 BC) Presenting the Straw Sandal to the Sage at Yi Bridge', 'Korean', 115788)
# ('Laozi (c. 571-477 BC) Riding through the Pass on a Black Ox', 'Korean', 115787)
# ('The Poet Tao Yuanming (365-427) Returning to His Farm at Lili', 'Korean', 115786)
# ('Seven Miscellaneous Sherds of Minute Size', 'Chinese', 105121)
# ('Two Sections of an Architectural Frieze', 'Coptic', 92462)
# ('Coin of Perseus, Macedonia (reproduction)', 'Greek', 92372)
# ('Tetradrachm of Perseus, Macedonia (reproduction)', 'Greek', 92371)
# ('Coin of Tiberius (?) from an Uncertain Mint', 'Roman Provincial', 91992)
# ('Coin of Alexandria under the Romans', 'Roman Provincial', 91991)
# ('Coin', 'Roman', 91928)
# ('Seal of John Kommenos, doux of Dyrrachion, son of the Sebastokrator (XI/XII c.; shortly after 1091/2)', 'Byzantine', 78801)
# ('Seal of Eustratios bishop of Ikaria (XI c.)', 'Byzantine', 78791)
# ('Seal of Nikephoros archbishop of Rhizaion (X c.)', 'Byzantine', 78785)
# ('Seal of Theodore episkeptites(?) of Kastoria (XI c.)', 'Byzantine', 78781)
# ('Seal of Nikephoros Botaneiates, kouropalates and doux of the Anatolikoi (XI c.)', 'Byzantine', 78777)
# ('Seal of Niketas archon of Skyros (IX/X c.)', 'Byzantine', 78752)
# ('Seal of Theodore Proteuon, protospatharios and judge of the Kibyrraiotai (XI c.)', 'Byzantine', 78739)
# ('Seal of Theodosios bishop of Athens (VII/VIII c.)', 'Byzantine', 78735)
# ('Seal of the protos of (Mount) Ganos (XI/XII c.)', 'Byzantine', 78729)
# ('Seal of N., imperial protospatharios and strategos of Dyrrachion (XI c.)', 'Byzantine', 78712)
# ('Seal of Epiphanios archon of Demetrias (X c.)', 'Byzantine', 78710)
# ('Seal of Michael skleros, protoproedros and anagrapheus of Drougoubiteia (XI c.)', 'Byzantine', 78709)
# ('Seal of Nikephoros proedros and praitor of the Anatolikoi (XI c.)', 'Byzantine', 78692)
# ('Seal of Dionysios monk and bishop of Stratonikeia (X/XI c.)', 'Byzantine', 78689)
# ('Seal of N. patrikios and strategos of the Anatolikoi (VIII c.)', 'Byzantine', 78683)
# ('Seal of Paul archbishop of Corinth (X c.)', 'Byzantine', 78657)
# ('Seal of Tarasios hypatos and archon of the Kyberiotai (VIII c.)', 'Byzantine', 78655)
# ('Seal of Leo patrikios, imperial protospatharios and strategos of the Anatolikoi (IX c.)', 'Byzantine', 78651)
# ('Seal of Niketas patrikios and strategos of the Peloponnesus (XI c.)', 'Byzantine', 78636)
# ('Seal of Joseph vestitor, epoptes of Nikopolis and epi (?) Peloponnesou (X c.)', 'Byzantine', 78634)
# ('Seal of Nicholas Areobindenos, spatharokandidatos and protonotarios of Chaldia (X/XI c.)', 'Byzantine', 78632)
# ('Seal of Symbatikis imperial protospatharios and strategos of Thrace (X c.)', 'Byzantine', 78618)
# ('Seal of N., eparchos of Thessalonica (VIII/IX c.)', 'Byzantine', 78586)
# ('Seal of Nikephoros patrikios and strategos of the Kibyrraiotai (XIth c.)', 'Byzantine', 78569)
# ('Seal of Michael patrikios, hypatos, judge of the Velum and of the Kibyrraiotai (XI c.)', 'Byzantine', 78553)
# ('Seal of David bishop of Paipert (XI c.)', 'Byzantine', 78546)
# ('Seal of Sophronois poimenarches ( = archbishop) of Cyprus (after 1191)', 'Byzantine', 78542)
# ('Seal of Manuel proedros and praitor of the Armeniakoi (XI c.)', 'Byzantine', 78541)
# ('Seal of (John) protoproedros (of the protosynkelloi and metropolitan) of Side (XI c.)', 'Byzantine', 78539)
# ('Seal of Aresenios bishop of Paphos (X/XI c.)', 'Byzantine', 78537)
# ('Seal of Leo imperial spatharios and protonotarios of Thessalonica (X c.)', 'Byzantine', 78533)
# ('Seal of Nikephoros Anzas, vestes, protonotarios of the Petrion and judge of the Islands (XI c.)', 'Byzantine', 78526)
# ('Seal of Pothos [vestes?] exaktor, oikistikos of the sakelle and kommerkiarios of Chaldia (XI c.)', 'Byzantine', 78523)
# ('Seal of John (metropolitan) of Amaseia (XI c.)', 'Byzantine', 78519)
# ('Seal of Peter archbishop of Thessalonica (VIII c.)', 'Byzantine', 78513)
# ('Seal of Demetrios metropolitan of Herakleia (IX/X c.)', 'Byzantine', 78512)
# ('Seal of George vestitor and protonotarios of Macedonia (IX c.)', 'Byzantine', 78508)
# ('Seal of Nikephoros Batatzes, magistros, vestes, and doux of all the West (XI c.)', 'Byzantine', 78506)
# ('Seal of Constantine archbishop (=metropolitan) of Herakleia (VIII/IX c.)', 'Byzantine', 78475)
# ('Seal of Sergios chartoularios and kommerkiarios of Presthlavitza (XI c.)', 'Byzantine', 78469)
# ('Seal of Christophoros primikerios epi tou koitonos, phylax and anagrapheus of the Armeniakoi (X/XI c.)', 'Byzantine', 78468)
# ('Seal of Michael imperial vestitor and protonotarios of Paphlagonia (IX c.)', 'Byzantine', 78459)
# ('Seal of Leo imperial spatharios and protonotarios of Thessalonica (X c.)', 'Byzantine', 78455)
# ('Seal of George imperial spatharokandidatos and strategos of the Peloponnesos (IX c.)', 'Byzantine', 78452)
# ('Seal of George imperial spatharios and tourmarches of the Boukellarioi (IX c.)', 'Byzantine', 78448)
# ('Seal of Eustratios hypatos, vestes, and judge of Thrace and Macedonia (XI c.)', 'Byzantine', 78447)
# ('Seal of Anastasios judge of the Peloponnesos and Hellas (XI c.)', 'Byzantine', 78446)
# ('Seal of Theodore archbishiop of Ephesos (VII/VIII c.)', 'Byzantine', 78440)
# ('Seal of N. Blax, protospatharios and judge of Mesopotamia (XI c.)', 'Byzantine', 78434)
# ('Seal of Euthynmios bishop of Sagalassos (X c.)', 'Byzantine', 78426)
# ('Seal of Leo imperial protospatharios and strategos of Thrace (X c.)', 'Byzantine', 78425)
# ('Seal of Romanos imperial protospatharios and strategos of Mesopotamia (X/XI c.)', 'Byzantine', 78424)
# ('Seal of N., patrikios, imperial protospatharios and strategos of Hellas (VIII c.)', 'Byzantine', 78367)
# ('Seal of Epiphanios imperial protospatharios and strategos of the Kiberraiotai (Xth c.)', 'Byzantine', 78362)
# ('Seal of Theodore imperial protospatharios, grand chartoularios of the genikon and anagrapheus of the Armenian themes (X/XI c.)', 'Byzantine', 78358)
# ('Seal of Stephanos archbishop of Katepano of Vaasprakania (XI c.)', 'Byzantine', 78312)
# ('Seal of Michael (imperial) protospatharios and katepano of Pephlagonia (X c.)', 'Byzantine', 78310)
# ('Seal of Michael metropolitan of Karia (X c.)', 'Byzantine', 78309)
# ('Seal of Basil (?) Bleymmydes (?), imp. protospatharios and anagrapheus of the Armeniakoi (X c.)', 'Byzantine', 78308)
# ('Seal of Niketas metropolitan of Athens (X c., probably d. 926)', 'Byzantine', 78307)
# ('Seal of John Skleros, patrikios, anthypatos and strategos of the Peloponnesos (XI c.)', 'Byzantine', 78253)
# ('Seal of the proedros (metropolitan) of Nikomedeia (VIII c.)', 'Byzantine', 78244)
# ('Seal of Nicholas metropolitan of Neokaisareia (X/XI c.)', 'Byzantine', 78243)
# ('Seal of John monk, archbishop of all Bulgaria (XI c.)', 'Byzantine', 78241)
# ('Seal of John imperial spatharios and protonotarios of the Peloponnesos (X c.)', 'Byzantine', 78222)
# ('Seal of Michael metropolitan of Athens (before 1025-13 August 1030)', 'Byzantine', 78221)
# ('Seal of Michael bishop of Herakleia (X/XI c.)', 'Byzantine', 78202)
# ('Seal of John (bishop) of Atramyttion (XII c.)', 'Byzantine', 78197)
# ('Seal of Nikephoros imperial protospatharios and strategos of Cherson (X c.)', 'Byzantine', 78175)
# ('Seal of Basil metropolitan of Pompeioupolis (X/XI c.)', 'Byzantine', 78172)
# ('Mystical Journey', 'Persian', 73206)
# ('Triptych: Summer Evening at Ryōgoku Bridge, from the series...', 'Japanese', 59754)
# ('Enjoying the Evening Cool at Ryōgoku Bridge in Edo: A Great Display of Fireworks', 'Japanese', 57578)
# ('Triptych: Landscape', 'Japanese', 57559)
# ('Triptych: Narihira Ason shokan ryaku', 'Japanese', 57505)
# ('Diptych: Perspective View of Dancers in an Interior', 'Japanese', 57502)
# ('Boaters Watching a Fight', 'Japanese', 57494)
# ('Triptych: Courtesans Writing on Gaku as Offerings to the Temple Asakusa (Asakusa Kannon hōshoku-gaku no zu)', 'Japanese', 57486)
# ('Procession of a Ryūkyūan Ambassador', 'Japanese', 57480)
# ('Triptych: Courtesans', 'Japanese', 57472)
# ('Diptych: Kabuki Actors', 'Japanese', 57465)
# ('View of Ise Divers Processing Abalone (Ise no ama nagaawabi tsukuri no zu)', 'Japanese', 57449)
# ('Triptych: Men and Women Walking in Shrine Precinct', 'Japanese', 57430)
# ('Triptych: Actors', 'Japanese', 57414)
# ('Triptych: Courtesans with Kamuro', 'Japanese', 57382)
# ('Triptych: Courtesans with Kamuro', 'Japanese', 57378)
# ('Enoshima in Sagami Province (Sōshū Enoshima no zu)', 'Japanese', 57374)
# ('Triptych: Musashi no Kuni: Chōfu no Tamagawa', 'Japanese', 57366)
# ('Triptych: Ibaraki no keshin', 'Japanese', 57358)
# ('Triptych: Three Kabuki Actors', 'Japanese', 57350)
# ('Six Women and Child in a Snowy Garden', 'Japanese', 55428)
# ('The Battle of the Uji River', 'Japanese', 54023)
# ('Courtesans of the Matsubarō: Nakagawa, Utagawa, Matsukaze', 'Japanese', 50557)
# ('Reproduction of a Gold Mycenaean Ring', 'Mycenaean', 49901)
# ('Reproduction of a Gold Mycenaean Bead', 'Mycenaean', 49900)
# ('Reproduction of a Gold Mycenaean Bead', 'Mycenaean', 49899)
# ('Reproduction of a Gold Mycenaean Bead', 'Mycenaean', 49898)
# ('Reproduction of a Gold Mycenaean Disc', 'Mycenaean', 49517)
# ('Reproduction of a Gold Mycenaean Disc', 'Mycenaean', 49513)
# ('Reproduction of a Gold Mycenaean Ornament', 'Mycenaean', 49511)
# ('Reproduction of a Gold Mycenaean Pin Head', 'Mycenaean', 49508)
# ('Two Standing, Braying Camels, One Buff, One White, Their Backs Laden with Goods', 'Chinese', 238)
# ('Tazza', 'British', 222)

# %%
#19.Find artifact titles ranked in the top 10 that include the color hue "Grey".
query = """
SELECT m.title, me.rank, c.hue
FROM artifact_metadata AS m
JOIN artifact_media AS me ON m.id = me.objectid
JOIN artifact_colors AS c ON m.id = c.objectid
WHERE c.hue = 'Grey'
ORDER BY me.rank DESC
LIMIT 10;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# ('Portrait:  Jacopo Bassano', 270487, 'Grey')
# ('Portrait:  Jacopo Bassano', 270487, 'Grey')
# ('Portrait:  Jacopo Bassano', 270487, 'Grey')
# ('Portrait:  Jacopo Bassano', 270487, 'Grey')
# ('Portrait:  Jacopo Bassano', 270487, 'Grey')
# ('Portrait:  Jacopo Bassano', 270487, 'Grey')
# ('Portrait:  Jacopo Bassano', 270487, 'Grey')
# ('Portrait:  Jacopo Bassano', 270487, 'Grey')
# ('The Second Hour of Night', 268854, 'Grey')
# ('The Second Hour of Night', 268854, 'Grey')

# %%
#20.How many artifacts exist per classification, and what is the average media count
#for each?
query = """
SELECT 
    m.classification,
    COUNT(m.id) AS artifact_count,
    AVG(me.mediacount) AS average_media_count
FROM artifact_metadata AS m
JOIN artifact_media AS me 
    ON m.id = me.objectid
WHERE m.classification IS NOT NULL
GROUP BY m.classification
ORDER BY artifact_count DESC;
"""

my_cursor.execute(query)
for row in my_cursor.fetchall():
    print(row)
# Out:
# ('Photographs', 1170, Decimal('0.0000'))
# ('Archival Material', 960, Decimal('0.0000'))
# ('Prints', 914, Decimal('0.0000'))
# ('Drawings', 626, Decimal('0.0000'))
# ('Coins', 390, Decimal('0.0000'))
# ("Artists' Tools", 343, Decimal('0.0000'))
# ('Fragments', 196, Decimal('0.0000'))
# ('Seals', 139, Decimal('0.0000'))
# ('Paintings', 61, Decimal('0.0000'))
# ('Sculpture', 48, Decimal('0.0000'))
# ('Vessels', 30, Decimal('0.0000'))
# ('Calligraphy', 20, Decimal('0.0000'))
# ('Jewelry', 18, Decimal('0.0000'))
# ('Textile Arts', 18, Decimal('0.0000'))
# ('Multiples', 10, Decimal('0.0000'))
# ('Albums', 8, Decimal('0.0000'))
# ('Gems', 8, Decimal('0.0000'))
# ('Audiovisual Works', 7, Decimal('0.0000'))
# ('Ritual Implements', 7, Decimal('0.0000'))
# ('Architectural Elements', 7, Decimal('0.0000'))
# ('Medals and Medallions', 4, Decimal('0.0000'))
# ('Amulets', 3, Decimal('0.0000'))
# ('Boxes', 2, Decimal('0.0000'))
# ('Tools and Equipment', 2, Decimal('0.0000'))
# ('Plaques', 2, Decimal('0.0000'))
# ('Manuscripts', 1, Decimal('0.0000'))
# ('Paintings with Calligraphy', 1, Decimal('0.0000'))
# ('Furnishings', 1, Decimal('0.0000'))
# ('Weapons and Ammunition', 1, Decimal('0.0000'))
# ('Books', 1, Decimal('0.0000'))
# ('Portfolios', 1, Decimal('0.0000'))
# ('Models', 1, Decimal('0.0000'))
